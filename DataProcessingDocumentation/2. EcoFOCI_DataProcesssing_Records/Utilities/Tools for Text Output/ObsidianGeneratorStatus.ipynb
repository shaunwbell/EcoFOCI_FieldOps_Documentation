# %% [markdown]
# # Timeseries Status Plots
#
# Build timeseries of data status for various measurement types
#
# ```
# ----> temperature [xxxxxxxxxxxxxyyyyyyy]
# --------> depth 1      [xxxxxxxx]
# --------> depth 2 [xxxxxx]    [yyyyyyyy]
# ```
#
# sankey or swimlane

# %%
#load from database

import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/Users/bell/Downloads/mooringdeployedinstruments_view.csv')

# %%
for g, groups in df.groupby('MooringID'):
    print(f" - [ ] {g}")
    for r,rgroups in groups.iterrows():
        print(f"\t - [ ] {rgroups['InstID']}")
# Out:
#  - [ ] 15BS-8A
# 	 - [ ] SBE-16 7169
#  - [ ] 15BSM-2A
# 	 - [ ] ISUS 027
#  - [ ] 15CKP-2A
# 	 - [ ] SUNA 598
# 	 - [ ] SBE-16 3114
# 	 - [ ] QSP-2300 70359
#  - [ ] 16BS-ITAE
# 	 - [ ] SPN1 A1274
# 	 - [ ] Eppley 38101
# 	 - [ ] ATRH 314012044
# 	 - [ ] Windsonic 14240107
# 	 - [ ] Eppley 38100
# 	 - [ ] O4831 329
# 	 - [ ] Prawler P1
#  - [ ] 16BSM-2A
# 	 - [ ] SUNA 796
#  - [ ] 16CKIP-1A
# 	 - [ ] IPS-5 51162
#  - [ ] 16CKIP-2A
# 	 - [ ] IPS-5 51111
#  - [ ] 16CKIP-3A
# 	 - [ ] IPS-5 51178
# 	 - [ ] RCM9 858
# 	 - [ ] O4330 1032
#  - [ ] 16CKP-12A
# 	 - [ ] RCM9 730
# 	 - [ ] O4330 1033
#  - [ ] 16CKP-1A
# 	 - [ ] SUNA 647
# 	 - [ ] QSP-2300 70295
#  - [ ] 16CKP-2A
# 	 - [ ] SUNA 284
# 	 - [ ] QSP-2300 70547
#  - [ ] 16CKP-3A
# 	 - [ ] SUNA 522
#  - [ ] 17AL_AU_PH1
# 	 - [ ] SBE-37 1855
#  - [ ] 17BS-4B
# 	 - [ ] SBE-37 1679
# 	 - [ ] MTR 4033
# 	 - [ ] SBE-37 3979
#  - [ ] 17BSITAEPR-2A
# 	 - [ ] O4831 603
# 	 - [ ] Prawler 3
# 	 - [ ] Eco-Fluorometer FLNTUS 4315
# ...

# %%
rgroups['InstID']
# Out:
# 'O3835 1771'
