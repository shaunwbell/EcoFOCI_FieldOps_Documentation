# %% [markdown]
# # CTD Netcdf Meta Update
#
# unify units for erddap driven netcdf

# %%
import xarray as xa
import yaml
import os

# %%
sample_data_dir = '/Users/bell/ecoraid/2018/CTDcasts/dy1805/'

# %%
###############################################################
# edit to point to {cruise sepcific} raw datafiles 
datafile = sample_data_dir+'final_data_cf/ctd/' #<- point to cruise and process all files within
cruise_name = 'DY1805' #no hyphens
cruise_meta_file = sample_data_dir+'logs/DY1805.yaml'
inst_meta_file = sample_data_dir+'logs/FOCI_standard_CTD.yaml'
# group_meta_file = ecofocipy_dir+'staticdata/institutional_meta_example_ctd.yaml'
inst_shortname = '' #keep as placeholder for now
###############################################################

# %%
#instrument info
with open(inst_meta_file) as file:
    inst_config = yaml.full_load(file)

# %%
for filename in os.listdir(datafile):
    if 'nc' in filename:
        print(filename)
        xdf = xa.load_dataset(datafile+filename)
        for var in xdf.variables:
            try:
                xdf[var].attrs = inst_config[var]
            except KeyError:
                pass
                print('No key in config file')
        xdf.to_netcdf(datafile+filename,format="NETCDF3_CLASSIC",encoding={'time':{'units':'days since 1900-01-01'}})
# Out:
# DY1805c011_ctd.nc
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# DY1805c003_ctd.nc
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# /var/folders/6r/n_mpcj7d7pdf9ncqvjy5vb8c0000jm/T/ipykernel_94482/156470432.py:11: UserWarning: Times can't be serialized faithfully to int64 with requested units 'days since 1900-01-01'. Resolution of 'nanoseconds' needed. Serializing times to floating point instead. Set encoding['dtype'] to integer dtype to serialize to int64. Set encoding['dtype'] to floating point dtype to silence this warning.
#   xdf.to_netcdf(datafile+filename,format="NETCDF3_CLASSIC",encoding={'time':{'units':'days since 1900-01-01'}})
# /var/folders/6r/n_mpcj7d7pdf9ncqvjy5vb8c0000jm/T/ipykernel_94482/156470432.py:11: UserWarning: Times can't be serialized faithfully to int64 with requested units 'days since 1900-01-01'. Resolution of 'minutes' needed. Serializing times to floating point instead. Set encoding['dtype'] to integer dtype to serialize to int64. Set encoding['dtype'] to floating point dtype to silence this warning.
#   xdf.to_netcdf(datafile+filename,format="NETCDF3_CLASSIC",encoding={'time':{'units':'days since 1900-01-01'}})
# /var/folders/6r/n_mpcj7d7pdf9ncqvjy5vb8c0000jm/T/ipykernel_94482/156470432.py:11: UserWarning: Times can't be serialized faithfully to int64 with requested units 'days since 1900-01-01'. Resolution of 'minutes' needed. Serializing times to floating point instead. Set encoding['dtype'] to integer dtype to serialize to int64. Set encoding['dtype'] to floating point dtype to silence this warning.
#   xdf.to_netcdf(datafile+filename,format="NETCDF3_CLASSIC",encoding={'time':{'units':'days since 1900-01-01'}})
# /var/folders/6r/n_mpcj7d7pdf9ncqvjy5vb8c0000jm/T/ipykernel_94482/156470432.py:11: UserWarning: Times can't be serialized faithfully to int64 with requested units 'days since 1900-01-01'. Resolution of 'minutes' needed. Serializing times to floating point instead. Set encoding['dtype'] to integer dtype to serialize to int64. Set encoding['dtype'] to floating point dtype to silence this warning.
#   xdf.to_netcdf(datafile+filename,format="NETCDF3_CLASSIC",encoding={'time':{'units':'days since 1900-01-01'}})
# /var/folders/6r/n_mpcj7d7pdf9ncqvjy5vb8c0000jm/T/ipykernel_94482/156470432.py:11: UserWarning: Times can't be serialized faithfully to int64 with requested units 'days since 1900-01-01'. Resolution of 'minutes' needed. Serializing times to floating point instead. Set encoding['dtype'] to integer dtype to serialize to int64. Set encoding['dtype'] to floating point dtype to silence this warning.
#   xdf.to_netcdf(datafile+filename,format="NETCDF3_CLASSIC",encoding={'time':{'units':'days since 1900-01-01'}})
# /var/folders/6r/n_mpcj7d7pdf9ncqvjy5vb8c0000jm/T/ipykernel_94482/156470432.py:11: UserWarning: Times can't be serialized faithfully to int64 with requested units 'days since 1900-01-01'. Resolution of 'minutes' needed. Serializing times to floating point instead. Set encoding['dtype'] to integer dtype to serialize to int64. Set encoding['dtype'] to floating point dtype to silence this warning.
#   xdf.to_netcdf(datafile+filename,format="NETCDF3_CLASSIC",encoding={'time':{'units':'days since 1900-01-01'}})
# /var/folders/6r/n_mpcj7d7pdf9ncqvjy5vb8c0000jm/T/ipykernel_94482/156470432.py:11: UserWarning: Times can't be serialized faithfully to int64 with requested units 'days since 1900-01-01'. Resolution of 'nanoseconds' needed. Serializing times to floating point instead. Set encoding['dtype'] to integer dtype to serialize to int64. Set encoding['dtype'] to floating point dtype to silence this warning.
#   xdf.to_netcdf(datafile+filename,format="NETCDF3_CLASSIC",encoding={'time':{'units':'days since 1900-01-01'}})
# /var/folders/6r/n_mpcj7d7pdf9ncqvjy5vb8c0000jm/T/ipykernel_94482/156470432.py:11: UserWarning: Times can't be serialized faithfully to int64 with requested units 'days since 1900-01-01'. Resolution of 'minutes' needed. Serializing times to floating point instead. Set encoding['dtype'] to integer dtype to serialize to int64. Set encoding['dtype'] to floating point dtype to silence this warning.
#   xdf.to_netcdf(datafile+filename,format="NETCDF3_CLASSIC",encoding={'time':{'units':'days since 1900-01-01'}})
# /var/folders/6r/n_mpcj7d7pdf9ncqvjy5vb8c0000jm/T/ipykernel_94482/156470432.py:11: UserWarning: Times can't be serialized faithfully to int64 with requested units 'days since 1900-01-01'. Resolution of 'minutes' needed. Serializing times to floating point instead. Set encoding['dtype'] to integer dtype to serialize to int64. Set encoding['dtype'] to floating point dtype to silence this warning.
#   xdf.to_netcdf(datafile+filename,format="NETCDF3_CLASSIC",encoding={'time':{'units':'days since 1900-01-01'}})
# /var/folders/6r/n_mpcj7d7pdf9ncqvjy5vb8c0000jm/T/ipykernel_94482/156470432.py:11: UserWarning: Times can't be serialized faithfully to int64 with requested units 'days since 1900-01-01'. Resolution of 'nanoseconds' needed. Serializing times to floating point instead. Set encoding['dtype'] to integer dtype to serialize to int64. Set encoding['dtype'] to floating point dtype to silence this warning.
#   xdf.to_netcdf(datafile+filename,format="NETCDF3_CLASSIC",encoding={'time':{'units':'days since 1900-01-01'}})
# /var/folders/6r/n_mpcj7d7pdf9ncqvjy5vb8c0000jm/T/ipykernel_94482/156470432.py:11: UserWarning: Times can't be serialized faithfully to int64 with requested units 'days since 1900-01-01'. Resolution of 'minutes' needed. Serializing times to floating point instead. Set encoding['dtype'] to integer dtype to serialize to int64. Set encoding['dtype'] to floating point dtype to silence this warning.
#   xdf.to_netcdf(datafile+filename,format="NETCDF3_CLASSIC",encoding={'time':{'units':'days since 1900-01-01'}})
# /var/folders/6r/n_mpcj7d7pdf9ncqvjy5vb8c0000jm/T/ipykernel_94482/156470432.py:11: UserWarning: Times can't be serialized faithfully to int64 with requested units 'days since 1900-01-01'. Resolution of 'minutes' needed. Serializing times to floating point instead. Set encoding['dtype'] to integer dtype to serialize to int64. Set encoding['dtype'] to floating point dtype to silence this warning.
#   xdf.to_netcdf(datafile+filename,format="NETCDF3_CLASSIC",encoding={'time':{'units':'days since 1900-01-01'}})
# /var/folders/6r/n_mpcj7d7pdf9ncqvjy5vb8c0000jm/T/ipykernel_94482/156470432.py:11: UserWarning: Times can't be serialized faithfully to int64 with requested units 'days since 1900-01-01'. Resolution of 'nanoseconds' needed. Serializing times to floating point instead. Set encoding['dtype'] to integer dtype to serialize to int64. Set encoding['dtype'] to floating point dtype to silence this warning.
#   xdf.to_netcdf(datafile+filename,format="NETCDF3_CLASSIC",encoding={'time':{'units':'days since 1900-01-01'}})
# DY1805c048_ctd.nc
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# DY1805c035_ctd.nc
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# DY1805c044_ctd.nc
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# DY1805c039_ctd.nc
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# DY1805c027_ctd.nc
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# DY1805c001_ctd.nc
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# DY1805c013_ctd.nc
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# DY1805c025_ctd.nc
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# DY1805c046_ctd.nc
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# DY1805c037_ctd.nc
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# DY1805c054_ctd.nc
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# DY1805c029_ctd.nc
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# DY1805c033_ctd.nc
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# /var/folders/6r/n_mpcj7d7pdf9ncqvjy5vb8c0000jm/T/ipykernel_94482/156470432.py:11: UserWarning: Times can't be serialized faithfully to int64 with requested units 'days since 1900-01-01'. Resolution of 'minutes' needed. Serializing times to floating point instead. Set encoding['dtype'] to integer dtype to serialize to int64. Set encoding['dtype'] to floating point dtype to silence this warning.
#   xdf.to_netcdf(datafile+filename,format="NETCDF3_CLASSIC",encoding={'time':{'units':'days since 1900-01-01'}})
# /var/folders/6r/n_mpcj7d7pdf9ncqvjy5vb8c0000jm/T/ipykernel_94482/156470432.py:11: UserWarning: Times can't be serialized faithfully to int64 with requested units 'days since 1900-01-01'. Resolution of 'nanoseconds' needed. Serializing times to floating point instead. Set encoding['dtype'] to integer dtype to serialize to int64. Set encoding['dtype'] to floating point dtype to silence this warning.
#   xdf.to_netcdf(datafile+filename,format="NETCDF3_CLASSIC",encoding={'time':{'units':'days since 1900-01-01'}})
# /var/folders/6r/n_mpcj7d7pdf9ncqvjy5vb8c0000jm/T/ipykernel_94482/156470432.py:11: UserWarning: Times can't be serialized faithfully to int64 with requested units 'days since 1900-01-01'. Resolution of 'minutes' needed. Serializing times to floating point instead. Set encoding['dtype'] to integer dtype to serialize to int64. Set encoding['dtype'] to floating point dtype to silence this warning.
#   xdf.to_netcdf(datafile+filename,format="NETCDF3_CLASSIC",encoding={'time':{'units':'days since 1900-01-01'}})
# /var/folders/6r/n_mpcj7d7pdf9ncqvjy5vb8c0000jm/T/ipykernel_94482/156470432.py:11: UserWarning: Times can't be serialized faithfully to int64 with requested units 'days since 1900-01-01'. Resolution of 'minutes' needed. Serializing times to floating point instead. Set encoding['dtype'] to integer dtype to serialize to int64. Set encoding['dtype'] to floating point dtype to silence this warning.
#   xdf.to_netcdf(datafile+filename,format="NETCDF3_CLASSIC",encoding={'time':{'units':'days since 1900-01-01'}})
# /var/folders/6r/n_mpcj7d7pdf9ncqvjy5vb8c0000jm/T/ipykernel_94482/156470432.py:11: UserWarning: Times can't be serialized faithfully to int64 with requested units 'days since 1900-01-01'. Resolution of 'minutes' needed. Serializing times to floating point instead. Set encoding['dtype'] to integer dtype to serialize to int64. Set encoding['dtype'] to floating point dtype to silence this warning.
#   xdf.to_netcdf(datafile+filename,format="NETCDF3_CLASSIC",encoding={'time':{'units':'days since 1900-01-01'}})
# /var/folders/6r/n_mpcj7d7pdf9ncqvjy5vb8c0000jm/T/ipykernel_94482/156470432.py:11: UserWarning: Times can't be serialized faithfully to int64 with requested units 'days since 1900-01-01'. Resolution of 'nanoseconds' needed. Serializing times to floating point instead. Set encoding['dtype'] to integer dtype to serialize to int64. Set encoding['dtype'] to floating point dtype to silence this warning.
#   xdf.to_netcdf(datafile+filename,format="NETCDF3_CLASSIC",encoding={'time':{'units':'days since 1900-01-01'}})
# /var/folders/6r/n_mpcj7d7pdf9ncqvjy5vb8c0000jm/T/ipykernel_94482/156470432.py:11: UserWarning: Times can't be serialized faithfully to int64 with requested units 'days since 1900-01-01'. Resolution of 'minutes' needed. Serializing times to floating point instead. Set encoding['dtype'] to integer dtype to serialize to int64. Set encoding['dtype'] to floating point dtype to silence this warning.
#   xdf.to_netcdf(datafile+filename,format="NETCDF3_CLASSIC",encoding={'time':{'units':'days since 1900-01-01'}})
# /var/folders/6r/n_mpcj7d7pdf9ncqvjy5vb8c0000jm/T/ipykernel_94482/156470432.py:11: UserWarning: Times can't be serialized faithfully to int64 with requested units 'days since 1900-01-01'. Resolution of 'minutes' needed. Serializing times to floating point instead. Set encoding['dtype'] to integer dtype to serialize to int64. Set encoding['dtype'] to floating point dtype to silence this warning.
#   xdf.to_netcdf(datafile+filename,format="NETCDF3_CLASSIC",encoding={'time':{'units':'days since 1900-01-01'}})
# /var/folders/6r/n_mpcj7d7pdf9ncqvjy5vb8c0000jm/T/ipykernel_94482/156470432.py:11: UserWarning: Times can't be serialized faithfully to int64 with requested units 'days since 1900-01-01'. Resolution of 'minutes' needed. Serializing times to floating point instead. Set encoding['dtype'] to integer dtype to serialize to int64. Set encoding['dtype'] to floating point dtype to silence this warning.
#   xdf.to_netcdf(datafile+filename,format="NETCDF3_CLASSIC",encoding={'time':{'units':'days since 1900-01-01'}})
# /var/folders/6r/n_mpcj7d7pdf9ncqvjy5vb8c0000jm/T/ipykernel_94482/156470432.py:11: UserWarning: Times can't be serialized faithfully to int64 with requested units 'days since 1900-01-01'. Resolution of 'minutes' needed. Serializing times to floating point instead. Set encoding['dtype'] to integer dtype to serialize to int64. Set encoding['dtype'] to floating point dtype to silence this warning.
#   xdf.to_netcdf(datafile+filename,format="NETCDF3_CLASSIC",encoding={'time':{'units':'days since 1900-01-01'}})
# /var/folders/6r/n_mpcj7d7pdf9ncqvjy5vb8c0000jm/T/ipykernel_94482/156470432.py:11: UserWarning: Times can't be serialized faithfully to int64 with requested units 'days since 1900-01-01'. Resolution of 'hours' needed. Serializing times to floating point instead. Set encoding['dtype'] to integer dtype to serialize to int64. Set encoding['dtype'] to floating point dtype to silence this warning.
#   xdf.to_netcdf(datafile+filename,format="NETCDF3_CLASSIC",encoding={'time':{'units':'days since 1900-01-01'}})
# /var/folders/6r/n_mpcj7d7pdf9ncqvjy5vb8c0000jm/T/ipykernel_94482/156470432.py:11: UserWarning: Times can't be serialized faithfully to int64 with requested units 'days since 1900-01-01'. Resolution of 'minutes' needed. Serializing times to floating point instead. Set encoding['dtype'] to integer dtype to serialize to int64. Set encoding['dtype'] to floating point dtype to silence this warning.
#   xdf.to_netcdf(datafile+filename,format="NETCDF3_CLASSIC",encoding={'time':{'units':'days since 1900-01-01'}})
# DY1805c050_ctd.nc
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# DY1805c017_ctd.nc
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# DY1805c009_ctd.nc
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# DY1805c005_ctd.nc
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# DY1805c040_ctd.nc
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# DY1805c023_ctd.nc
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# DY1805c052_ctd.nc
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# DY1805c031_ctd.nc
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# DY1805c019_ctd.nc
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# DY1805c007_ctd.nc
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# DY1805c015_ctd.nc
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# DY1805c034_ctd.nc
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# /var/folders/6r/n_mpcj7d7pdf9ncqvjy5vb8c0000jm/T/ipykernel_94482/156470432.py:11: UserWarning: Times can't be serialized faithfully to int64 with requested units 'days since 1900-01-01'. Resolution of 'nanoseconds' needed. Serializing times to floating point instead. Set encoding['dtype'] to integer dtype to serialize to int64. Set encoding['dtype'] to floating point dtype to silence this warning.
#   xdf.to_netcdf(datafile+filename,format="NETCDF3_CLASSIC",encoding={'time':{'units':'days since 1900-01-01'}})
# /var/folders/6r/n_mpcj7d7pdf9ncqvjy5vb8c0000jm/T/ipykernel_94482/156470432.py:11: UserWarning: Times can't be serialized faithfully to int64 with requested units 'days since 1900-01-01'. Resolution of 'minutes' needed. Serializing times to floating point instead. Set encoding['dtype'] to integer dtype to serialize to int64. Set encoding['dtype'] to floating point dtype to silence this warning.
#   xdf.to_netcdf(datafile+filename,format="NETCDF3_CLASSIC",encoding={'time':{'units':'days since 1900-01-01'}})
# /var/folders/6r/n_mpcj7d7pdf9ncqvjy5vb8c0000jm/T/ipykernel_94482/156470432.py:11: UserWarning: Times can't be serialized faithfully to int64 with requested units 'days since 1900-01-01'. Resolution of 'minutes' needed. Serializing times to floating point instead. Set encoding['dtype'] to integer dtype to serialize to int64. Set encoding['dtype'] to floating point dtype to silence this warning.
#   xdf.to_netcdf(datafile+filename,format="NETCDF3_CLASSIC",encoding={'time':{'units':'days since 1900-01-01'}})
# /var/folders/6r/n_mpcj7d7pdf9ncqvjy5vb8c0000jm/T/ipykernel_94482/156470432.py:11: UserWarning: Times can't be serialized faithfully to int64 with requested units 'days since 1900-01-01'. Resolution of 'minutes' needed. Serializing times to floating point instead. Set encoding['dtype'] to integer dtype to serialize to int64. Set encoding['dtype'] to floating point dtype to silence this warning.
#   xdf.to_netcdf(datafile+filename,format="NETCDF3_CLASSIC",encoding={'time':{'units':'days since 1900-01-01'}})
# /var/folders/6r/n_mpcj7d7pdf9ncqvjy5vb8c0000jm/T/ipykernel_94482/156470432.py:11: UserWarning: Times can't be serialized faithfully to int64 with requested units 'days since 1900-01-01'. Resolution of 'minutes' needed. Serializing times to floating point instead. Set encoding['dtype'] to integer dtype to serialize to int64. Set encoding['dtype'] to floating point dtype to silence this warning.
#   xdf.to_netcdf(datafile+filename,format="NETCDF3_CLASSIC",encoding={'time':{'units':'days since 1900-01-01'}})
# /var/folders/6r/n_mpcj7d7pdf9ncqvjy5vb8c0000jm/T/ipykernel_94482/156470432.py:11: UserWarning: Times can't be serialized faithfully to int64 with requested units 'days since 1900-01-01'. Resolution of 'minutes' needed. Serializing times to floating point instead. Set encoding['dtype'] to integer dtype to serialize to int64. Set encoding['dtype'] to floating point dtype to silence this warning.
#   xdf.to_netcdf(datafile+filename,format="NETCDF3_CLASSIC",encoding={'time':{'units':'days since 1900-01-01'}})
# /var/folders/6r/n_mpcj7d7pdf9ncqvjy5vb8c0000jm/T/ipykernel_94482/156470432.py:11: UserWarning: Times can't be serialized faithfully to int64 with requested units 'days since 1900-01-01'. Resolution of 'minutes' needed. Serializing times to floating point instead. Set encoding['dtype'] to integer dtype to serialize to int64. Set encoding['dtype'] to floating point dtype to silence this warning.
#   xdf.to_netcdf(datafile+filename,format="NETCDF3_CLASSIC",encoding={'time':{'units':'days since 1900-01-01'}})
# /var/folders/6r/n_mpcj7d7pdf9ncqvjy5vb8c0000jm/T/ipykernel_94482/156470432.py:11: UserWarning: Times can't be serialized faithfully to int64 with requested units 'days since 1900-01-01'. Resolution of 'minutes' needed. Serializing times to floating point instead. Set encoding['dtype'] to integer dtype to serialize to int64. Set encoding['dtype'] to floating point dtype to silence this warning.
#   xdf.to_netcdf(datafile+filename,format="NETCDF3_CLASSIC",encoding={'time':{'units':'days since 1900-01-01'}})
# /var/folders/6r/n_mpcj7d7pdf9ncqvjy5vb8c0000jm/T/ipykernel_94482/156470432.py:11: UserWarning: Times can't be serialized faithfully to int64 with requested units 'days since 1900-01-01'. Resolution of 'minutes' needed. Serializing times to floating point instead. Set encoding['dtype'] to integer dtype to serialize to int64. Set encoding['dtype'] to floating point dtype to silence this warning.
#   xdf.to_netcdf(datafile+filename,format="NETCDF3_CLASSIC",encoding={'time':{'units':'days since 1900-01-01'}})
# /var/folders/6r/n_mpcj7d7pdf9ncqvjy5vb8c0000jm/T/ipykernel_94482/156470432.py:11: UserWarning: Times can't be serialized faithfully to int64 with requested units 'days since 1900-01-01'. Resolution of 'minutes' needed. Serializing times to floating point instead. Set encoding['dtype'] to integer dtype to serialize to int64. Set encoding['dtype'] to floating point dtype to silence this warning.
#   xdf.to_netcdf(datafile+filename,format="NETCDF3_CLASSIC",encoding={'time':{'units':'days since 1900-01-01'}})
# /var/folders/6r/n_mpcj7d7pdf9ncqvjy5vb8c0000jm/T/ipykernel_94482/156470432.py:11: UserWarning: Times can't be serialized faithfully to int64 with requested units 'days since 1900-01-01'. Resolution of 'minutes' needed. Serializing times to floating point instead. Set encoding['dtype'] to integer dtype to serialize to int64. Set encoding['dtype'] to floating point dtype to silence this warning.
#   xdf.to_netcdf(datafile+filename,format="NETCDF3_CLASSIC",encoding={'time':{'units':'days since 1900-01-01'}})
# /var/folders/6r/n_mpcj7d7pdf9ncqvjy5vb8c0000jm/T/ipykernel_94482/156470432.py:11: UserWarning: Times can't be serialized faithfully to int64 with requested units 'days since 1900-01-01'. Resolution of 'minutes' needed. Serializing times to floating point instead. Set encoding['dtype'] to integer dtype to serialize to int64. Set encoding['dtype'] to floating point dtype to silence this warning.
#   xdf.to_netcdf(datafile+filename,format="NETCDF3_CLASSIC",encoding={'time':{'units':'days since 1900-01-01'}})
# /var/folders/6r/n_mpcj7d7pdf9ncqvjy5vb8c0000jm/T/ipykernel_94482/156470432.py:11: UserWarning: Times can't be serialized faithfully to int64 with requested units 'days since 1900-01-01'. Resolution of 'nanoseconds' needed. Serializing times to floating point instead. Set encoding['dtype'] to integer dtype to serialize to int64. Set encoding['dtype'] to floating point dtype to silence this warning.
#   xdf.to_netcdf(datafile+filename,format="NETCDF3_CLASSIC",encoding={'time':{'units':'days since 1900-01-01'}})
# DY1805c049_ctd.nc
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# DY1805c026_ctd.nc
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# DY1805c038_ctd.nc
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# DY1805c045_ctd.nc
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# DY1805c010_ctd.nc
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# DY1805c002_ctd.nc
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# DY1805c047_ctd.nc
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# DY1805c024_ctd.nc
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# DY1805c028_ctd.nc
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# DY1805c036_ctd.nc
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# DY1805c012_ctd.nc
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# DY1805c008_ctd.nc
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# DY1805c016_ctd.nc
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# DY1805c004_ctd.nc
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# DY1805c051_ctd.nc
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# DY1805c032_ctd.nc
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# DY1805c020_ctd.nc
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# DY1805c006_ctd.nc
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# DY1805c018_ctd.nc
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# DY1805c014_ctd.nc
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# DY1805c022_ctd.nc
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# DY1805c041_ctd.nc
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# DY1805c030_ctd.nc
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# DY1805c053_ctd.nc
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# No key in config file
# /var/folders/6r/n_mpcj7d7pdf9ncqvjy5vb8c0000jm/T/ipykernel_94482/156470432.py:11: UserWarning: Times can't be serialized faithfully to int64 with requested units 'days since 1900-01-01'. Resolution of 'minutes' needed. Serializing times to floating point instead. Set encoding['dtype'] to integer dtype to serialize to int64. Set encoding['dtype'] to floating point dtype to silence this warning.
#   xdf.to_netcdf(datafile+filename,format="NETCDF3_CLASSIC",encoding={'time':{'units':'days since 1900-01-01'}})
# /var/folders/6r/n_mpcj7d7pdf9ncqvjy5vb8c0000jm/T/ipykernel_94482/156470432.py:11: UserWarning: Times can't be serialized faithfully to int64 with requested units 'days since 1900-01-01'. Resolution of 'minutes' needed. Serializing times to floating point instead. Set encoding['dtype'] to integer dtype to serialize to int64. Set encoding['dtype'] to floating point dtype to silence this warning.
#   xdf.to_netcdf(datafile+filename,format="NETCDF3_CLASSIC",encoding={'time':{'units':'days since 1900-01-01'}})
# /var/folders/6r/n_mpcj7d7pdf9ncqvjy5vb8c0000jm/T/ipykernel_94482/156470432.py:11: UserWarning: Times can't be serialized faithfully to int64 with requested units 'days since 1900-01-01'. Resolution of 'minutes' needed. Serializing times to floating point instead. Set encoding['dtype'] to integer dtype to serialize to int64. Set encoding['dtype'] to floating point dtype to silence this warning.
#   xdf.to_netcdf(datafile+filename,format="NETCDF3_CLASSIC",encoding={'time':{'units':'days since 1900-01-01'}})
# /var/folders/6r/n_mpcj7d7pdf9ncqvjy5vb8c0000jm/T/ipykernel_94482/156470432.py:11: UserWarning: Times can't be serialized faithfully to int64 with requested units 'days since 1900-01-01'. Resolution of 'minutes' needed. Serializing times to floating point instead. Set encoding['dtype'] to integer dtype to serialize to int64. Set encoding['dtype'] to floating point dtype to silence this warning.
#   xdf.to_netcdf(datafile+filename,format="NETCDF3_CLASSIC",encoding={'time':{'units':'days since 1900-01-01'}})
# /var/folders/6r/n_mpcj7d7pdf9ncqvjy5vb8c0000jm/T/ipykernel_94482/156470432.py:11: UserWarning: Times can't be serialized faithfully to int64 with requested units 'days since 1900-01-01'. Resolution of 'minutes' needed. Serializing times to floating point instead. Set encoding['dtype'] to integer dtype to serialize to int64. Set encoding['dtype'] to floating point dtype to silence this warning.
#   xdf.to_netcdf(datafile+filename,format="NETCDF3_CLASSIC",encoding={'time':{'units':'days since 1900-01-01'}})
# /var/folders/6r/n_mpcj7d7pdf9ncqvjy5vb8c0000jm/T/ipykernel_94482/156470432.py:11: UserWarning: Times can't be serialized faithfully to int64 with requested units 'days since 1900-01-01'. Resolution of 'minutes' needed. Serializing times to floating point instead. Set encoding['dtype'] to integer dtype to serialize to int64. Set encoding['dtype'] to floating point dtype to silence this warning.
#   xdf.to_netcdf(datafile+filename,format="NETCDF3_CLASSIC",encoding={'time':{'units':'days since 1900-01-01'}})
# /var/folders/6r/n_mpcj7d7pdf9ncqvjy5vb8c0000jm/T/ipykernel_94482/156470432.py:11: UserWarning: Times can't be serialized faithfully to int64 with requested units 'days since 1900-01-01'. Resolution of 'nanoseconds' needed. Serializing times to floating point instead. Set encoding['dtype'] to integer dtype to serialize to int64. Set encoding['dtype'] to floating point dtype to silence this warning.
#   xdf.to_netcdf(datafile+filename,format="NETCDF3_CLASSIC",encoding={'time':{'units':'days since 1900-01-01'}})
# /var/folders/6r/n_mpcj7d7pdf9ncqvjy5vb8c0000jm/T/ipykernel_94482/156470432.py:11: UserWarning: Times can't be serialized faithfully to int64 with requested units 'days since 1900-01-01'. Resolution of 'minutes' needed. Serializing times to floating point instead. Set encoding['dtype'] to integer dtype to serialize to int64. Set encoding['dtype'] to floating point dtype to silence this warning.
#   xdf.to_netcdf(datafile+filename,format="NETCDF3_CLASSIC",encoding={'time':{'units':'days since 1900-01-01'}})
# /var/folders/6r/n_mpcj7d7pdf9ncqvjy5vb8c0000jm/T/ipykernel_94482/156470432.py:11: UserWarning: Times can't be serialized faithfully to int64 with requested units 'days since 1900-01-01'. Resolution of 'nanoseconds' needed. Serializing times to floating point instead. Set encoding['dtype'] to integer dtype to serialize to int64. Set encoding['dtype'] to floating point dtype to silence this warning.
#   xdf.to_netcdf(datafile+filename,format="NETCDF3_CLASSIC",encoding={'time':{'units':'days since 1900-01-01'}})
# /var/folders/6r/n_mpcj7d7pdf9ncqvjy5vb8c0000jm/T/ipykernel_94482/156470432.py:11: UserWarning: Times can't be serialized faithfully to int64 with requested units 'days since 1900-01-01'. Resolution of 'minutes' needed. Serializing times to floating point instead. Set encoding['dtype'] to integer dtype to serialize to int64. Set encoding['dtype'] to floating point dtype to silence this warning.
#   xdf.to_netcdf(datafile+filename,format="NETCDF3_CLASSIC",encoding={'time':{'units':'days since 1900-01-01'}})
# /var/folders/6r/n_mpcj7d7pdf9ncqvjy5vb8c0000jm/T/ipykernel_94482/156470432.py:11: UserWarning: Times can't be serialized faithfully to int64 with requested units 'days since 1900-01-01'. Resolution of 'nanoseconds' needed. Serializing times to floating point instead. Set encoding['dtype'] to integer dtype to serialize to int64. Set encoding['dtype'] to floating point dtype to silence this warning.
#   xdf.to_netcdf(datafile+filename,format="NETCDF3_CLASSIC",encoding={'time':{'units':'days since 1900-01-01'}})
# /var/folders/6r/n_mpcj7d7pdf9ncqvjy5vb8c0000jm/T/ipykernel_94482/156470432.py:11: UserWarning: Times can't be serialized faithfully to int64 with requested units 'days since 1900-01-01'. Resolution of 'minutes' needed. Serializing times to floating point instead. Set encoding['dtype'] to integer dtype to serialize to int64. Set encoding['dtype'] to floating point dtype to silence this warning.
#   xdf.to_netcdf(datafile+filename,format="NETCDF3_CLASSIC",encoding={'time':{'units':'days since 1900-01-01'}})
