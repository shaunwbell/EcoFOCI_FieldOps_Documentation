# %% [markdown]
# # Using EcoFOCIpy to process raw field data - NW2401
#
# *NW2401*
#
# **Processed by Shaun Bell**
#
# A duplicate column of Fluorescence shows up
# ## CTD / Profile Data
#
# Basic workflow for each instrument grouping is *(initial archive level)*:
# - SBE workflow must happen first **done (performed on seperate windows system to convert to cnv)**
# - output initial files (pandas->csv) **ERDDAP NRT** when no meta data is added.  Good for quick analysis
#
# Other than hosting on an erddap server, the above can be done at sea
#
# For furthur processing, QC and archiving, the following tasks are to be done *(working or final data level)*:
# - Add metadata from cruise yaml files created from cast logs
# - apply any calibrations or corrections
#     + field corrections
#     + offsets
#     + spike analysis
#     + some QC were available... this would be old-school simple bounds mostly
# - save as CF netcdf via xarray or potentially csv file: so many of the steps above are optional
#     + **ERDDAP NRT** if no corrections, offsets or time bounds are applied but some meta data is (can be csv as this is useful at sea)
#     + **Working and awaiting QC** has no ERDDAP representation and is a holding spot
#     + **ERDDAP Final** fully calibrated, qc'd and populated with meta information
#
# Plot for preview and QC
# - TSSigma, TOXYChlor, TurbParTrans

# %%
import yaml
import glob

import EcoFOCIpy.io.sbe_ctd_parser as sbe_ctd_parser #<- instrument specific
import EcoFOCIpy.io.ncCFsave as ncCFsave
import EcoFOCIpy.metaconfig.load_config as load_config
import EcoFOCIpy.math.geotools as geotools

# %% [markdown]
# ## At Sea NRT Processing

# %%
sample_data_dir = '/Users/bell/ecoraid/2024/CTDcasts/nw2401/' #root path to cruise directory
ecofocipy_dir = '/Users/bell/Programs/EcoFOCIpy/'

# %%
###############################################################
# edit to point to {cruise sepcific} raw datafiles 
datafile = sample_data_dir+'rawconverted-calswap/' #<- point to cruise and process all files within
cruise_name = 'NW2401' #no hyphens
inst_meta_file = sample_data_dir+'logs/EMA_standard_CTD.yaml'
###############################################################

#init and load data
cruise = sbe_ctd_parser.sbe9_11p()
filename_list = sorted(glob.glob(datafile + '*.cnv'))

(cruise_data,cruise_header) = cruise.parse(filename_list)

# %%
cruise_header
# Out:
# {'dnw240101.cnv': {'header': ['* Sea-Bird SBE 9 Data File:\n',
#    '* FileName = C:\\Users\\emafield\\Desktop\\NBS-2024\\NW240101.hex\n',
#    '* Software Version Seasave V 7.26.7.121\n',
#    '* Temperature SN = 4354\n',
#    '* Conductivity SN = 3072\n',
#    '* Number of Bytes Per Scan = 30\n',
#    '* Number of Voltage Words = 4\n',
#    '* Number of Scans Averaged by the Deck Unit = 1\n',
#    '* System UpLoad Time = Sep 02 2024 15:57:47\n',
#    '* SBE 11plus V 5.2\n',
#    '* number of scans to average = 1\n',
#    '* pressure baud rate = 9600\n',
#    '* NMEA baud rate = 4800\n',
#    '* GPIB address = 1\n',
#    '* advance primary conductivity  0.073 seconds\n',
#    '* advance secondary conductivity  0.073 seconds\n',
#    '* autorun on power up is disabled\n',
#    '* S>\n',
#    '** Survey:\n',
#    '** Station:\n',
#    '* System UTC = Sep 02 2024 15:57:47\n',
#    '# nquan = 21                                \n',
#    '# nvalues = 31556                       \n',
#    '# units = specified\n',
#    '# name 0 = c0mS/cm: Conductivity [mS/cm]\n',
#    '# name 1 = c1mS/cm: Conductivity, 2 [mS/cm]\n',
#    '# name 2 = flECO-AFL: Fluorescence, WET Labs ECO-AFL/FL [mg/m^3]\n',
#    '# name 3 = sbeox0V: Oxygen raw, SBE 43 [V]\n',
#    '# name 4 = sbeox1V: Oxygen raw, SBE 43, 2 [V]\n',
#    '# name 5 = t090C: Temperature [ITS-90, deg C]\n',
#    '# name 6 = t190C: Temperature, 2 [ITS-90, deg C]\n',
#    '# name 7 = turbWETntu0: Turbidity, WET Labs ECO [NTU]\n',
#    '# name 8 = par: PAR/Irradiance, Biospherical/Licor [umol photons/m^2/sec]\n',
#    '# name 9 = prDM: Pressure, Digiquartz [db]\n',
#    '# name 10 = sal00: Salinity, Practical [PSU]\n',
#    '# name 11 = sal11: Salinity, Practical, 2 [PSU]\n',
#    '# name 12 = sbeox0Mg/L: Oxygen, SBE 43 [mg/l], WS = 2\n',
#    '# name 13 = sbeox0PS: Oxygen, SBE 43 [% saturation], WS = 2\n',
#    '# name 14 = sbox0Mm/Kg: Oxygen, SBE 43 [umol/kg], WS = 2\n',
#    '# name 15 = sbeox1Mg/L: Oxygen, SBE 43, 2 [mg/l], WS = 2\n',
#    '# name 16 = sbeox1PS: Oxygen, SBE 43, 2 [% saturation], WS = 2\n',
#    '# name 17 = sbox1Mm/Kg: Oxygen, SBE 43, 2 [umol/kg], WS = 2\n',
#    '# name 18 = sigma-t00: Density [sigma-t, kg/m^3 ]\n',
#    '# name 19 = sigma-t11: Density, 2 [sigma-t, kg/m^3 ]\n',
#    '# name 20 = flag: flag\n',
#    '# span 0 =  -0.066545,  31.188212       \n',
#    '# span 1 =  -0.003515,  31.025895       \n',
#    '# span 2 =    -0.1042,     1.5368       \n',
#    '# span 3 =     1.5824,     2.5128       \n',
#    '# span 4 =     2.2405,     2.7424       \n',
#    '# span 5 =     6.3129,     7.7416       \n',
#    '# span 6 =     6.3421,     7.9468       \n',
#    '# span 7 =     0.1220,     9.8680       \n',
#    '# span 8 = 1.0000e-12, 2.9087e-03       \n',
#    '# span 9 =      0.267,     21.359       \n',
#    '# span 10 =     0.0000,    30.3814      \n',
#    '# span 11 =     0.0000,    30.1712      \n',
#    '# span 12 =     6.1278,    11.1811      \n',
#    '# span 13 =     50.328,     94.884      \n',
#    '# span 14 =    191.509,    349.438      \n',
#    '# span 15 =     8.3664,    13.0417      \n',
#    '# span 16 =     81.758,    106.077      \n',
#    '# span 17 =    256.383,    407.583      \n',
#    '# span 18 =    -0.1156,    23.7634      \n',
#    '# span 19 =    -0.1458,    23.5915      \n',
#    '# span 20 = 0.0000e+00, 0.0000e+00      \n',
#    '# interval = seconds: 0.0416667\n',
#    '# start_time = Sep 02 2024 15:57:47 [System UTC, header]\n',
#    '# bad_flag = -9.990e-29\n',
#    '# <Sensors count="13" >\n',
#    '#   <sensor Channel="1" >\n',
#    '#     <!-- Frequency 0, Temperature -->\n',
#    '#     <TemperatureSensor SensorID="55" >\n',
#    '#       <SerialNumber>4354</SerialNumber>\n',
#    '#       <CalibrationDate>11-May-23</CalibrationDate>\n',
#    '#       <UseG_J>1</UseG_J>\n',
#    '#       <A>0.00000000e+000</A>\n',
#    '#       <B>0.00000000e+000</B>\n',
#    '#       <C>0.00000000e+000</C>\n',
#    '#       <D>0.00000000e+000</D>\n',
#    '#       <F0_Old>0.000</F0_Old>\n',
#    '#       <G>4.34852058e-003</G>\n',
#    '#       <H>6.36569482e-004</H>\n',
#    '#       <I>2.19345844e-005</I>\n',
#    '#       <J>1.98995503e-006</J>\n',
#    '#       <F0>1000.000</F0>\n',
#    '#       <Slope>1.00000000</Slope>\n',
#    '#       <Offset>0.0000</Offset>\n',
#    '#     </TemperatureSensor>\n',
#    '#   </sensor>\n',
#    '#   <sensor Channel="2" >\n',
#    '#     <!-- Frequency 1, Conductivity -->\n',
#    '#     <ConductivitySensor SensorID="3" >\n',
#    '#       <SerialNumber>3072</SerialNumber>\n',
#    '#       <CalibrationDate>26-Apr-23</CalibrationDate>\n',
#    '#       <UseG_J>1</UseG_J>\n',
#    '#       <!-- Cell const and series R are applicable only for wide range sensors. -->\n',
#    '#       <SeriesR>0.0000</SeriesR>\n',
#    '#       <CellConst>2000.0000</CellConst>\n',
#    '#       <ConductivityType>0</ConductivityType>\n',
#    '#       <Coefficients equation="0" >\n',
#    '#         <A>0.00000000e+000</A>\n',
#    '#         <B>0.00000000e+000</B>\n',
#    '#         <C>0.00000000e+000</C>\n',
#    '#         <D>0.00000000e+000</D>\n',
#    '#         <M>0.0</M>\n',
#    '#         <CPcor>-9.57000000e-008</CPcor>\n',
#    '#       </Coefficients>\n',
#    '#       <Coefficients equation="1" >\n',
#    '#         <G>-9.78106359e+000</G>\n',
#    '#         <H>1.33765522e+000</H>\n',
#    '#         <I>7.09945466e-004</I>\n',
#    '#         <J>2.14300155e-005</J>\n',
#    '#         <CPcor>-9.57000000e-008</CPcor>\n',
#    '#         <CTcor>3.2500e-006</CTcor>\n',
#    '#         <!-- WBOTC not applicable unless ConductivityType = 1. -->\n',
#    '#         <WBOTC>0.00000000e+000</WBOTC>\n',
#    '#       </Coefficients>\n',
#    '#       <Slope>1.00000000</Slope>\n',
#    '#       <Offset>0.00000</Offset>\n',
#    '#     </ConductivitySensor>\n',
#    '#   </sensor>\n',
#    '#   <sensor Channel="3" >\n',
#    '#     <!-- Frequency 2, Pressure, Digiquartz with TC -->\n',
#    '#     <PressureSensor SensorID="45" >\n',
#    '#       <SerialNumber>0775</SerialNumber>\n',
#    '#       <CalibrationDate>14-Apr-23</CalibrationDate>\n',
#    '#       <C1>-4.207550e+004</C1>\n',
#    '#       <C2>-7.186518e-001</C2>\n',
#    '#       <C3>1.164310e-002</C3>\n',
#    '#       <D1>3.533500e-002</D1>\n',
#    '#       <D2>0.000000e+000</D2>\n',
#    '#       <T1>3.008985e+001</T1>\n',
#    '#       <T2>-5.064140e-004</T2>\n',
#    '#       <T3>4.126460e-006</T3>\n',
#    '#       <T4>6.565360e-010</T4>\n',
#    '#       <Slope>0.99980379</Slope>\n',
#    '#       <Offset>0.71774</Offset>\n',
#    '#       <T5>0.000000e+000</T5>\n',
#    '#       <AD590M>1.280410e-002</AD590M>\n',
#    '#       <AD590B>-8.261400e+000</AD590B>\n',
#    '#     </PressureSensor>\n',
#    '#   </sensor>\n',
#    '#   <sensor Channel="4" >\n',
#    '#     <!-- Frequency 3, Temperature, 2 -->\n',
#    '#     <TemperatureSensor SensorID="55" >\n',
#    '#       <SerialNumber>4394</SerialNumber>\n',
#    '#       <CalibrationDate>13-May-23</CalibrationDate>\n',
#    '#       <UseG_J>1</UseG_J>\n',
#    '#       <A>0.00000000e+000</A>\n',
#    '#       <B>0.00000000e+000</B>\n',
#    '#       <C>0.00000000e+000</C>\n',
#    '#       <D>0.00000000e+000</D>\n',
#    '#       <F0_Old>0.000</F0_Old>\n',
#    '#       <G>4.35777370e-003</G>\n',
#    '#       <H>6.44786944e-004</H>\n',
#    '#       <I>2.22424806e-005</I>\n',
#    '#       <J>1.80325050e-006</J>\n',
#    '#       <F0>1000.000</F0>\n',
#    '#       <Slope>1.00000000</Slope>\n',
#    '#       <Offset>0.0000</Offset>\n',
#    '#     </TemperatureSensor>\n',
#    '#   </sensor>\n',
#    '#   <sensor Channel="5" >\n',
#    '#     <!-- Frequency 4, Conductivity, 2 -->\n',
#    '#     <ConductivitySensor SensorID="3" >\n',
#    '#       <SerialNumber>2879</SerialNumber>\n',
#    '#       <CalibrationDate>26-Apr-23</CalibrationDate>\n',
#    '#       <UseG_J>1</UseG_J>\n',
#    '#       <!-- Cell const and series R are applicable only for wide range sensors. -->\n',
#    '#       <SeriesR>0.0000</SeriesR>\n',
#    '#       <CellConst>2000.0000</CellConst>\n',
#    '#       <ConductivityType>0</ConductivityType>\n',
#    '#       <Coefficients equation="0" >\n',
#    '#         <A>0.00000000e+000</A>\n',
#    '#         <B>0.00000000e+000</B>\n',
#    '#         <C>0.00000000e+000</C>\n',
#    '#         <D>0.00000000e+000</D>\n',
#    '#         <M>0.0</M>\n',
#    '#         <CPcor>-9.57000000e-008</CPcor>\n',
#    '#       </Coefficients>\n',
#    '#       <Coefficients equation="1" >\n',
#    '#         <G>-1.02061711e+001</G>\n',
#    '#         <H>1.40171143e+000</H>\n',
#    '#         <I>1.17328370e-003</I>\n',
#    '#         <J>-1.30258422e-006</J>\n',
#    '#         <CPcor>-9.57000000e-008</CPcor>\n',
#    '#         <CTcor>3.2500e-006</CTcor>\n',
#    '#         <!-- WBOTC not applicable unless ConductivityType = 1. -->\n',
#    '#         <WBOTC>0.00000000e+000</WBOTC>\n',
#    '#       </Coefficients>\n',
#    '#       <Slope>1.00000000</Slope>\n',
#    '#       <Offset>0.00000</Offset>\n',
#    '#     </ConductivitySensor>\n',
#    '#   </sensor>\n',
#    '#   <sensor Channel="6" >\n',
#    '#     <!-- A/D voltage 0, Oxygen, SBE 43 -->\n',
#    '#     <OxygenSensor SensorID="38" >\n',
#    '#       <SerialNumber>0804</SerialNumber>\n',
#    '#       <CalibrationDate>27-Apr-23</CalibrationDate>\n',
#    '#       <Use2007Equation>1</Use2007Equation>\n',
#    '#       <CalibrationCoefficients equation="0" >\n',
#    '#         <!-- Coefficients for Owens-Millard equation. -->\n',
#    '#         <Boc>0.0000</Boc>\n',
#    '#         <Soc>0.0000e+000</Soc>\n',
#    '#         <offset>0.0000</offset>\n',
#    '#         <Pcor>0.00e+000</Pcor>\n',
#    '#         <Tcor>0.0000</Tcor>\n',
#    '#         <Tau>0.0</Tau>\n',
#    '#       </CalibrationCoefficients>\n',
#    '#       <CalibrationCoefficients equation="1" >\n',
#    '#         <!-- Coefficients for Sea-Bird equation - SBE calibration in 2007 and later. -->\n',
#    '#         <Soc>4.7104e-001</Soc>\n',
#    '#         <offset>-0.4892</offset>\n',
#    '#         <A>-4.1124e-003</A>\n',
#    '#         <B> 1.6563e-004</B>\n',
#    '#         <C>-2.5102e-006</C>\n',
#    '#         <D0> 2.5826e+000</D0>\n',
#    '#         <D1> 1.92634e-004</D1>\n',
#    '#         <D2>-4.64803e-002</D2>\n',
#    '#         <E> 3.6000e-002</E>\n',
#    '#         <Tau20> 0.9400</Tau20>\n',
#    '#         <H1>-3.3000e-002</H1>\n',
#    '#         <H2> 5.0000e+003</H2>\n',
#    '#         <H3> 1.4500e+003</H3>\n',
#    '#       </CalibrationCoefficients>\n',
#    '#     </OxygenSensor>\n',
#    '#   </sensor>\n',
#    '#   <sensor Channel="7" >\n',
#    '#     <!-- A/D voltage 1, Oxygen, SBE 43, 2 -->\n',
#    '#     <OxygenSensor SensorID="38" >\n',
#    '#       <SerialNumber>1301</SerialNumber>\n',
#    '#       <CalibrationDate>03-May-23</CalibrationDate>\n',
#    '#       <Use2007Equation>1</Use2007Equation>\n',
#    '#       <CalibrationCoefficients equation="0" >\n',
#    '#         <!-- Coefficients for Owens-Millard equation. -->\n',
#    '#         <Boc>0.0000</Boc>\n',
#    '#         <Soc>0.0000e+000</Soc>\n',
#    '#         <offset>0.0000</offset>\n',
#    '#         <Pcor>0.00e+000</Pcor>\n',
#    '#         <Tcor>0.0000</Tcor>\n',
#    '#         <Tau>0.0</Tau>\n',
#    '#       </CalibrationCoefficients>\n',
#    '#       <CalibrationCoefficients equation="1" >\n',
#    '#         <!-- Coefficients for Sea-Bird equation - SBE calibration in 2007 and later. -->\n',
#    '#         <Soc>4.7840e-001</Soc>\n',
#    '#         <offset>-0.4916</offset>\n',
#    '#         <A>-4.0592e-003</A>\n',
#    '#         <B> 1.8162e-004</B>\n',
#    '#         <C>-2.5361e-006</C>\n',
#    '#         <D0> 2.5826e+000</D0>\n',
#    '#         <D1> 1.92634e-004</D1>\n',
#    '#         <D2>-4.64803e-002</D2>\n',
#    '#         <E> 3.6000e-002</E>\n',
#    '#         <Tau20> 1.0800</Tau20>\n',
#    '#         <H1>-3.3000e-002</H1>\n',
#    '#         <H2> 5.0000e+003</H2>\n',
#    '#         <H3> 1.4500e+003</H3>\n',
#    '#       </CalibrationCoefficients>\n',
#    '#     </OxygenSensor>\n',
#    '#   </sensor>\n',
#    '#   <sensor Channel="8" >\n',
#    '#     <!-- A/D voltage 2, Fluorometer, WET Labs ECO-AFL/FL -->\n',
#    '#     <FluoroWetlabECO_AFL_FL_Sensor SensorID="20" >\n',
#    '#       <SerialNumber>FLNTURT-8441</SerialNumber>\n',
#    '#       <CalibrationDate>Aug 15,2023</CalibrationDate>\n',
#    '#       <ScaleFactor>6.00000000e+000</ScaleFactor>\n',
#    '#       <!-- Dark output -->\n',
#    '#       <Vblank>0.0540</Vblank>\n',
#    '#     </FluoroWetlabECO_AFL_FL_Sensor>\n',
#    '#   </sensor>\n',
#    '#   <sensor Channel="9" >\n',
#    '#     <!-- A/D voltage 3, Turbidity Meter, WET Labs, ECO-NTU -->\n',
#    '#     <TurbidityMeter SensorID="67" >\n',
#    '#       <SerialNumber>FLNTURT-8441</SerialNumber>\n',
#    '#       <CalibrationDate>August 15,2023</CalibrationDate>\n',
#    '#       <ScaleFactor>2.000000</ScaleFactor>\n',
#    '#       <!-- Dark output -->\n',
#    '#       <DarkVoltage>0.066000</DarkVoltage>\n',
#    '#     </TurbidityMeter>\n',
#    '#   </sensor>\n',
#    '#   <sensor Channel="10" >\n',
#    '#     <!-- A/D voltage 4, PAR/Irradiance, Biospherical/Licor -->\n',
#    '#     <PAR_BiosphericalLicorChelseaSensor SensorID="42" >\n',
#    '#       <SerialNumber>70750</SerialNumber>\n',
#    '#       <CalibrationDate>5/2/22</CalibrationDate>\n',
#    '#       <M>1.00000000</M>\n',
#    '#       <B>0.00000000</B>\n',
#    '#       <CalibrationConstant>100000000000000.00000000</CalibrationConstant>\n',
#    '#       <ConversionUnits>1</ConversionUnits>\n',
#    '#       <Multiplier>1.00000000</Multiplier>\n',
#    '#       <Offset>-0.00001011</Offset>\n',
#    '#     </PAR_BiosphericalLicorChelseaSensor>\n',
#    '#   </sensor>\n',
#    '#   <sensor Channel="11" >\n',
#    '#     <!-- A/D voltage 5, Transmissometer, WET Labs C-Star -->\n',
#    '#     <WET_LabsCStar SensorID="71" >\n',
#    '#       <SerialNumber>CST-676PR</SerialNumber>\n',
#    '#       <CalibrationDate>May 10, 2023</CalibrationDate>\n',
#    '#       <M>21.2400</M>\n',
#    '#       <B>-0.1274</B>\n',
#    '#       <PathLength>0.250</PathLength>\n',
#    '#     </WET_LabsCStar>\n',
#    '#   </sensor>\n',
#    '#   <sensor Channel="12" >\n',
#    '#     <!-- A/D voltage 6, Free -->\n',
#    '#   </sensor>\n',
#    '#   <sensor Channel="13" >\n',
#    '#     <!-- A/D voltage 7, Free -->\n',
#    '#   </sensor>\n',
#    '# </Sensors>\n',
#    '# datcnv_date = Aug 01 2025 08:47:47, 7.26.7.129 [datcnv_vars = 10]\n',
#    '# datcnv_in = c:\\data\\ctd\\2024\\nw2401\\raw-calswap\\nw240101.hex c:\\data\\ctd\\2024\\nw2401\\raw-calswap\\nw240101.XMLCON\n',
#    '# datcnv_skipover = 0\n',
#    '# datcnv_ox_hysteresis_correction = yes\n',
#    '# wildedit_date = Aug 01 2025 08:47:50, 7.26.7.129\n',
#    '# wildedit_in = c:\\data\\ctd\\2024\\nw2401\\raw-calswap\\nw240101.cnv\n',
#    '# wildedit_pass1_nstd = 2.0\n',
#    '# wildedit_pass2_nstd = 20.0\n',
#    '# wildedit_pass2_mindelta = 0.000e+000\n',
#    '# wildedit_npoint = 100\n',
#    '# wildedit_vars = c0mS/cm c1mS/cm flECO-AFL sbeox0V sbeox1V t090C t190C par prDM\n',
#    '# wildedit_excl_bad_scans = yes\n',
#    '# alignctd_date = Aug 01 2025 08:47:51, 7.26.7.129\n',
#    '# alignctd_in = c:\\data\\ctd\\2024\\nw2401\\raw-calswap\\nw240101.cnv\n',
#    '# alignctd_adv = sbeox0V 3.000, sbeox1V 3.000                                                                                                                                                                                        \n',
#    '# celltm_date = Aug 01 2025 08:47:51, 7.26.7.129\n',
#    '# celltm_in = c:\\data\\ctd\\2024\\nw2401\\raw-calswap\\nw240101.cnv\n',
#    '# celltm_alpha = 0.0300, 0.0300\n',
#    '# celltm_tau = 7.0000, 7.0000\n',
#    '# celltm_temp_sensor_use_for_cond = primary, secondary\n',
#    '# filter_date = Aug 01 2025 08:47:52, 7.26.7.129\n',
#    '# filter_in = c:\\data\\ctd\\2024\\nw2401\\raw-calswap\\nw240101.cnv\n',
#    '# filter_low_pass_tc_A = 0.030\n',
#    '# filter_low_pass_tc_B = 0.150\n',
#    '# filter_low_pass_A_vars =\n',
#    '# filter_low_pass_B_vars = prDM\n',
#    '# loopedit_date = Aug 01 2025 08:47:54, 7.26.7.129\n',
#    '# loopedit_in = c:\\data\\ctd\\2024\\nw2401\\raw-calswap\\nw240101.cnv\n',
#    '# loopedit_percentMeanSpeed: minV = 0.250, ws = 120, percent = 20.00                                                      \n',
#    '# loopedit_surfaceSoak: minDepth = 5.0, maxDepth = 20, useDeckPress = 0                                                   \n',
#    '# loopedit_excl_bad_scans = yes\n',
#    '# Derive_date = Aug 01 2025 08:47:55, 7.26.7.129 [derive_vars = 10]\n',
#    '# Derive_in = c:\\data\\ctd\\2024\\nw2401\\raw-calswap\\nw240101.cnv c:\\data\\ctd\\2024\\nw2401\\raw-calswap\\nw240101.XMLCON\n',
#    '# derive_time_window_docdt = seconds: 2\n',
#    '# derive_ox_tau_correction = yes\n',
#    '# split_date = Aug 01 2025 08:47:57, 7.26.7.129\n',
#    '# split_in = c:\\data\\ctd\\2024\\nw2401\\raw-calswap\\nw240101.cnv\n',
#    '# split_excl_bad_scans = yes\n',
#    '# file_type = ascii\n',
#    '*END*\n'],
#   'headercount': 351,
#   'varnames': {0: 'c0mS/cm',
#    1: 'c1mS/cm',
#    2: 'flECO-AFL',
#    3: 'sbeox0V',
#    4: 'sbeox1V',
#    5: 't090C',
#    6: 't190C',
#    7: 'turbWETntu0',
#    8: 'par',
#    9: 'prDM',
#    10: 'sal00',
#    11: 'sal11',
#    12: 'sbeox0Mg/L',
#    13: 'sbeox0PS',
#    14: 'sbox0Mm/Kg',
#    15: 'sbeox1Mg/L',
#    16: 'sbeox1PS',
#    17: 'sbox1Mm/Kg',
#    18: 'sigma-t00',
#    19: 'sigma-t11',
#    20: 'flag'},
#   'SYSTEMtime': 'Sep 02 2024 15:57:47',
#   'NMEAtime': [],
#   'NMEALat': [],
#   'NMEALon': []},
#  'dnw240102.cnv': {'header': ['* Sea-Bird SBE 9 Data File:\n',
#    '* FileName = C:\\Users\\emafield\\Desktop\\NBS-2024\\NW240102.hex\n',
#    '* Software Version Seasave V 7.26.7.121\n',
#    '* Temperature SN = 4354\n',
#    '* Conductivity SN = 3072\n',
#    '* Number of Bytes Per Scan = 30\n',
#    '* Number of Voltage Words = 4\n',
#    '* Number of Scans Averaged by the Deck Unit = 1\n',
#    '* System UpLoad Time = Sep 02 2024 21:07:00\n',
#    '* SBE 11plus V 5.2\n',
#    '* number of scans to average = 1\n',
#    '* pressure baud rate = 9600\n',
#    '* NMEA baud rate = 4800\n',
#    '* GPIB address = 1\n',
#    '* advance primary conductivity  0.073 seconds\n',
#    '* advance secondary conductivity  0.073 seconds\n',
#    '* autorun on power up is disabled\n',
#    '* S>\n',
#    '** Survey:\n',
#    '** Station:\n',
#    '* System UTC = Sep 02 2024 21:07:00\n',
#    '# nquan = 21                                \n',
#    '# nvalues = 5794                        \n',
#    '# units = specified\n',
#    '# name 0 = c0mS/cm: Conductivity [mS/cm]\n',
#    '# name 1 = c1mS/cm: Conductivity, 2 [mS/cm]\n',
#    '# name 2 = flECO-AFL: Fluorescence, WET Labs ECO-AFL/FL [mg/m^3]\n',
#    '# name 3 = sbeox0V: Oxygen raw, SBE 43 [V]\n',
#    '# name 4 = sbeox1V: Oxygen raw, SBE 43, 2 [V]\n',
#    '# name 5 = t090C: Temperature [ITS-90, deg C]\n',
#    '# name 6 = t190C: Temperature, 2 [ITS-90, deg C]\n',
#    '# name 7 = turbWETntu0: Turbidity, WET Labs ECO [NTU]\n',
#    '# name 8 = par: PAR/Irradiance, Biospherical/Licor [umol photons/m^2/sec]\n',
#    '# name 9 = prDM: Pressure, Digiquartz [db]\n',
#    '# name 10 = sal00: Salinity, Practical [PSU]\n',
#    '# name 11 = sal11: Salinity, Practical, 2 [PSU]\n',
#    '# name 12 = sbeox0Mg/L: Oxygen, SBE 43 [mg/l], WS = 2\n',
#    '# name 13 = sbeox0PS: Oxygen, SBE 43 [% saturation], WS = 2\n',
#    '# name 14 = sbox0Mm/Kg: Oxygen, SBE 43 [umol/kg], WS = 2\n',
#    '# name 15 = sbeox1Mg/L: Oxygen, SBE 43, 2 [mg/l], WS = 2\n',
#    '# name 16 = sbeox1PS: Oxygen, SBE 43, 2 [% saturation], WS = 2\n',
#    '# name 17 = sbox1Mm/Kg: Oxygen, SBE 43, 2 [umol/kg], WS = 2\n',
#    '# name 18 = sigma-t00: Density [sigma-t, kg/m^3 ]\n',
#    '# name 19 = sigma-t11: Density, 2 [sigma-t, kg/m^3 ]\n',
#    '# name 20 = flag: flag\n',
#    '# span 0 =  -0.000469,  31.259127       \n',
#    '# span 1 =   5.553488,  31.206533       \n',
#    '# span 2 =    -0.0236,     0.9874       \n',
#    '# span 3 =     1.7912,     2.9927       \n',
#    '# span 4 =     1.9744,     2.7155       \n',
#    '# span 5 =     6.5202,     6.7591       \n',
#    '# span 6 =     6.4261,     6.7830       \n',
#    '# span 7 =    -0.0123,     0.5151       \n',
#    '# span 8 = 1.5576e-04, 1.9036e-01       \n',
#    '# span 9 =      0.362,     34.981       \n',
#    '# span 10 =     0.0000,    30.8777      \n',
#    '# span 11 =     0.0000,    30.7531      \n',
#    '# span 12 =     6.0130,    12.5008      \n',
#    '# span 13 =     60.177,    117.214      \n',
#    '# span 14 =    183.469,    390.685      \n',
#    '# span 15 =     6.8798,    12.3384      \n',
#    '# span 16 =     68.951,    104.732      \n',
#    '# span 17 =    209.942,    384.166      \n',
#    '# span 18 =    -0.0803,    24.2179      \n',
#    '# span 19 =    -0.0739,    24.1108      \n',
#    '# span 20 = 0.0000e+00, 0.0000e+00      \n',
#    '# interval = seconds: 0.0416667\n',
#    '# start_time = Sep 02 2024 21:07:00 [System UTC, header]\n',
#    '# bad_flag = -9.990e-29\n',
#    '# <Sensors count="13" >\n',
#    '#   <sensor Channel="1" >\n',
#    '#     <!-- Frequency 0, Temperature -->\n',
#    '#     <TemperatureSensor SensorID="55" >\n',
#    '#       <SerialNumber>4354</SerialNumber>\n',
#    '#       <CalibrationDate>11-May-23</CalibrationDate>\n',
#    '#       <UseG_J>1</UseG_J>\n',
#    '#       <A>0.00000000e+000</A>\n',
#    '#       <B>0.00000000e+000</B>\n',
#    '#       <C>0.00000000e+000</C>\n',
#    '#       <D>0.00000000e+000</D>\n',
#    '#       <F0_Old>0.000</F0_Old>\n',
#    '#       <G>4.34852058e-003</G>\n',
#    '#       <H>6.36569482e-004</H>\n',
#    '#       <I>2.19345844e-005</I>\n',
#    '#       <J>1.98995503e-006</J>\n',
#    '#       <F0>1000.000</F0>\n',
#    '#       <Slope>1.00000000</Slope>\n',
#    '#       <Offset>0.0000</Offset>\n',
#    '#     </TemperatureSensor>\n',
#    '#   </sensor>\n',
#    '#   <sensor Channel="2" >\n',
#    '#     <!-- Frequency 1, Conductivity -->\n',
#    '#     <ConductivitySensor SensorID="3" >\n',
#    '#       <SerialNumber>3072</SerialNumber>\n',
#    '#       <CalibrationDate>26-Apr-23</CalibrationDate>\n',
#    '#       <UseG_J>1</UseG_J>\n',
#    '#       <!-- Cell const and series R are applicable only for wide range sensors. -->\n',
#    '#       <SeriesR>0.0000</SeriesR>\n',
#    '#       <CellConst>2000.0000</CellConst>\n',
#    '#       <ConductivityType>0</ConductivityType>\n',
#    '#       <Coefficients equation="0" >\n',
#    '#         <A>0.00000000e+000</A>\n',
#    '#         <B>0.00000000e+000</B>\n',
#    '#         <C>0.00000000e+000</C>\n',
#    '#         <D>0.00000000e+000</D>\n',
#    '#         <M>0.0</M>\n',
#    '#         <CPcor>-9.57000000e-008</CPcor>\n',
#    '#       </Coefficients>\n',
#    '#       <Coefficients equation="1" >\n',
#    '#         <G>-9.78106359e+000</G>\n',
#    '#         <H>1.33765522e+000</H>\n',
#    '#         <I>7.09945466e-004</I>\n',
#    '#         <J>2.14300155e-005</J>\n',
#    '#         <CPcor>-9.57000000e-008</CPcor>\n',
#    '#         <CTcor>3.2500e-006</CTcor>\n',
#    '#         <!-- WBOTC not applicable unless ConductivityType = 1. -->\n',
#    '#         <WBOTC>0.00000000e+000</WBOTC>\n',
#    '#       </Coefficients>\n',
#    '#       <Slope>1.00000000</Slope>\n',
#    '#       <Offset>0.00000</Offset>\n',
#    '#     </ConductivitySensor>\n',
#    '#   </sensor>\n',
#    '#   <sensor Channel="3" >\n',
#    '#     <!-- Frequency 2, Pressure, Digiquartz with TC -->\n',
#    '#     <PressureSensor SensorID="45" >\n',
#    '#       <SerialNumber>0775</SerialNumber>\n',
#    '#       <CalibrationDate>14-Apr-23</CalibrationDate>\n',
#    '#       <C1>-4.207550e+004</C1>\n',
#    '#       <C2>-7.186518e-001</C2>\n',
#    '#       <C3>1.164310e-002</C3>\n',
#    '#       <D1>3.533500e-002</D1>\n',
#    '#       <D2>0.000000e+000</D2>\n',
#    '#       <T1>3.008985e+001</T1>\n',
#    '#       <T2>-5.064140e-004</T2>\n',
#    '#       <T3>4.126460e-006</T3>\n',
#    '#       <T4>6.565360e-010</T4>\n',
#    '#       <Slope>0.99980379</Slope>\n',
#    '#       <Offset>0.71774</Offset>\n',
#    '#       <T5>0.000000e+000</T5>\n',
#    '#       <AD590M>1.280410e-002</AD590M>\n',
#    '#       <AD590B>-8.261400e+000</AD590B>\n',
#    '#     </PressureSensor>\n',
#    '#   </sensor>\n',
#    '#   <sensor Channel="4" >\n',
#    '#     <!-- Frequency 3, Temperature, 2 -->\n',
#    '#     <TemperatureSensor SensorID="55" >\n',
#    '#       <SerialNumber>4394</SerialNumber>\n',
#    '#       <CalibrationDate>13-May-23</CalibrationDate>\n',
#    '#       <UseG_J>1</UseG_J>\n',
#    '#       <A>0.00000000e+000</A>\n',
#    '#       <B>0.00000000e+000</B>\n',
#    '#       <C>0.00000000e+000</C>\n',
#    '#       <D>0.00000000e+000</D>\n',
#    '#       <F0_Old>0.000</F0_Old>\n',
#    '#       <G>4.35777370e-003</G>\n',
#    '#       <H>6.44786944e-004</H>\n',
#    '#       <I>2.22424806e-005</I>\n',
#    '#       <J>1.80325050e-006</J>\n',
#    '#       <F0>1000.000</F0>\n',
#    '#       <Slope>1.00000000</Slope>\n',
#    '#       <Offset>0.0000</Offset>\n',
#    '#     </TemperatureSensor>\n',
#    '#   </sensor>\n',
#    '#   <sensor Channel="5" >\n',
#    '#     <!-- Frequency 4, Conductivity, 2 -->\n',
#    '#     <ConductivitySensor SensorID="3" >\n',
#    '#       <SerialNumber>2879</SerialNumber>\n',
#    '#       <CalibrationDate>26-Apr-23</CalibrationDate>\n',
#    '#       <UseG_J>1</UseG_J>\n',
#    '#       <!-- Cell const and series R are applicable only for wide range sensors. -->\n',
#    '#       <SeriesR>0.0000</SeriesR>\n',
#    '#       <CellConst>2000.0000</CellConst>\n',
#    '#       <ConductivityType>0</ConductivityType>\n',
#    '#       <Coefficients equation="0" >\n',
#    '#         <A>0.00000000e+000</A>\n',
#    '#         <B>0.00000000e+000</B>\n',
#    '#         <C>0.00000000e+000</C>\n',
#    '#         <D>0.00000000e+000</D>\n',
#    '#         <M>0.0</M>\n',
#    '#         <CPcor>-9.57000000e-008</CPcor>\n',
#    '#       </Coefficients>\n',
#    '#       <Coefficients equation="1" >\n',
#    '#         <G>-1.02061711e+001</G>\n',
#    '#         <H>1.40171143e+000</H>\n',
#    '#         <I>1.17328370e-003</I>\n',
#    '#         <J>-1.30258422e-006</J>\n',
#    '#         <CPcor>-9.57000000e-008</CPcor>\n',
#    '#         <CTcor>3.2500e-006</CTcor>\n',
#    '#         <!-- WBOTC not applicable unless ConductivityType = 1. -->\n',
#    '#         <WBOTC>0.00000000e+000</WBOTC>\n',
#    '#       </Coefficients>\n',
#    '#       <Slope>1.00000000</Slope>\n',
#    '#       <Offset>0.00000</Offset>\n',
#    '#     </ConductivitySensor>\n',
#    '#   </sensor>\n',
#    '#   <sensor Channel="6" >\n',
#    '#     <!-- A/D voltage 0, Oxygen, SBE 43 -->\n',
#    '#     <OxygenSensor SensorID="38" >\n',
#    '#       <SerialNumber>0804</SerialNumber>\n',
#    '#       <CalibrationDate>27-Apr-23</CalibrationDate>\n',
#    '#       <Use2007Equation>1</Use2007Equation>\n',
#    '#       <CalibrationCoefficients equation="0" >\n',
#    '#         <!-- Coefficients for Owens-Millard equation. -->\n',
#    '#         <Boc>0.0000</Boc>\n',
#    '#         <Soc>0.0000e+000</Soc>\n',
#    '#         <offset>0.0000</offset>\n',
#    '#         <Pcor>0.00e+000</Pcor>\n',
#    '#         <Tcor>0.0000</Tcor>\n',
#    '#         <Tau>0.0</Tau>\n',
#    '#       </CalibrationCoefficients>\n',
#    '#       <CalibrationCoefficients equation="1" >\n',
#    '#         <!-- Coefficients for Sea-Bird equation - SBE calibration in 2007 and later. -->\n',
#    '#         <Soc>4.7104e-001</Soc>\n',
#    '#         <offset>-0.4892</offset>\n',
#    '#         <A>-4.1124e-003</A>\n',
#    '#         <B> 1.6563e-004</B>\n',
#    '#         <C>-2.5102e-006</C>\n',
#    '#         <D0> 2.5826e+000</D0>\n',
#    '#         <D1> 1.92634e-004</D1>\n',
#    '#         <D2>-4.64803e-002</D2>\n',
#    '#         <E> 3.6000e-002</E>\n',
#    '#         <Tau20> 0.9400</Tau20>\n',
#    '#         <H1>-3.3000e-002</H1>\n',
#    '#         <H2> 5.0000e+003</H2>\n',
#    '#         <H3> 1.4500e+003</H3>\n',
#    '#       </CalibrationCoefficients>\n',
#    '#     </OxygenSensor>\n',
#    '#   </sensor>\n',
#    '#   <sensor Channel="7" >\n',
#    '#     <!-- A/D voltage 1, Oxygen, SBE 43, 2 -->\n',
#    '#     <OxygenSensor SensorID="38" >\n',
#    '#       <SerialNumber>1301</SerialNumber>\n',
#    '#       <CalibrationDate>03-May-23</CalibrationDate>\n',
#    '#       <Use2007Equation>1</Use2007Equation>\n',
#    '#       <CalibrationCoefficients equation="0" >\n',
#    '#         <!-- Coefficients for Owens-Millard equation. -->\n',
#    '#         <Boc>0.0000</Boc>\n',
#    '#         <Soc>0.0000e+000</Soc>\n',
#    '#         <offset>0.0000</offset>\n',
#    '#         <Pcor>0.00e+000</Pcor>\n',
#    '#         <Tcor>0.0000</Tcor>\n',
#    '#         <Tau>0.0</Tau>\n',
#    '#       </CalibrationCoefficients>\n',
#    '#       <CalibrationCoefficients equation="1" >\n',
#    '#         <!-- Coefficients for Sea-Bird equation - SBE calibration in 2007 and later. -->\n',
#    '#         <Soc>4.7840e-001</Soc>\n',
#    '#         <offset>-0.4916</offset>\n',
#    '#         <A>-4.0592e-003</A>\n',
#    '#         <B> 1.8162e-004</B>\n',
#    '#         <C>-2.5361e-006</C>\n',
#    '#         <D0> 2.5826e+000</D0>\n',
#    '#         <D1> 1.92634e-004</D1>\n',
#    '#         <D2>-4.64803e-002</D2>\n',
#    '#         <E> 3.6000e-002</E>\n',
#    '#         <Tau20> 1.0800</Tau20>\n',
#    '#         <H1>-3.3000e-002</H1>\n',
#    '#         <H2> 5.0000e+003</H2>\n',
#    '#         <H3> 1.4500e+003</H3>\n',
#    '#       </CalibrationCoefficients>\n',
#    '#     </OxygenSensor>\n',
#    '#   </sensor>\n',
#    '#   <sensor Channel="8" >\n',
#    '#     <!-- A/D voltage 2, Fluorometer, WET Labs ECO-AFL/FL -->\n',
#    '#     <FluoroWetlabECO_AFL_FL_Sensor SensorID="20" >\n',
#    '#       <SerialNumber>FLNTURT-8441</SerialNumber>\n',
#    '#       <CalibrationDate>Aug 15,2023</CalibrationDate>\n',
#    '#       <ScaleFactor>6.00000000e+000</ScaleFactor>\n',
#    '#       <!-- Dark output -->\n',
#    '#       <Vblank>0.0540</Vblank>\n',
#    '#     </FluoroWetlabECO_AFL_FL_Sensor>\n',
#    '#   </sensor>\n',
#    '#   <sensor Channel="9" >\n',
#    '#     <!-- A/D voltage 3, Turbidity Meter, WET Labs, ECO-NTU -->\n',
#    '#     <TurbidityMeter SensorID="67" >\n',
#    '#       <SerialNumber>FLNTURT-8441</SerialNumber>\n',
#    '#       <CalibrationDate>August 15,2023</CalibrationDate>\n',
#    '#       <ScaleFactor>2.000000</ScaleFactor>\n',
#    '#       <!-- Dark output -->\n',
#    '#       <DarkVoltage>0.066000</DarkVoltage>\n',
#    '#     </TurbidityMeter>\n',
#    '#   </sensor>\n',
#    '#   <sensor Channel="10" >\n',
#    '#     <!-- A/D voltage 4, PAR/Irradiance, Biospherical/Licor -->\n',
#    '#     <PAR_BiosphericalLicorChelseaSensor SensorID="42" >\n',
#    '#       <SerialNumber>70750</SerialNumber>\n',
#    '#       <CalibrationDate>5/2/22</CalibrationDate>\n',
#    '#       <M>1.00000000</M>\n',
#    '#       <B>0.00000000</B>\n',
#    '#       <CalibrationConstant>100000000000000.00000000</CalibrationConstant>\n',
#    '#       <ConversionUnits>1</ConversionUnits>\n',
#    '#       <Multiplier>1.00000000</Multiplier>\n',
#    '#       <Offset>-0.00001011</Offset>\n',
#    '#     </PAR_BiosphericalLicorChelseaSensor>\n',
#    '#   </sensor>\n',
#    '#   <sensor Channel="11" >\n',
#    '#     <!-- A/D voltage 5, Transmissometer, WET Labs C-Star -->\n',
#    '#     <WET_LabsCStar SensorID="71" >\n',
#    '#       <SerialNumber>CST-676PR</SerialNumber>\n',
#    '#       <CalibrationDate>May 10, 2023</CalibrationDate>\n',
#    '#       <M>21.2400</M>\n',
#    '#       <B>-0.1274</B>\n',
#    '#       <PathLength>0.250</PathLength>\n',
#    '#     </WET_LabsCStar>\n',
#    '#   </sensor>\n',
#    '#   <sensor Channel="12" >\n',
#    '#     <!-- A/D voltage 6, Free -->\n',
#    '#   </sensor>\n',
#    '#   <sensor Channel="13" >\n',
#    '#     <!-- A/D voltage 7, Free -->\n',
#    '#   </sensor>\n',
#    '# </Sensors>\n',
#    '# datcnv_date = Aug 01 2025 08:48:01, 7.26.7.129 [datcnv_vars = 10]\n',
#    '# datcnv_in = c:\\data\\ctd\\2024\\nw2401\\raw-calswap\\nw240102.hex c:\\data\\ctd\\2024\\nw2401\\raw-calswap\\nw240102.XMLCON\n',
#    '# datcnv_skipover = 0\n',
#    '# datcnv_ox_hysteresis_correction = yes\n',
#    '# wildedit_date = Aug 01 2025 08:48:03, 7.26.7.129\n',
#    '# wildedit_in = c:\\data\\ctd\\2024\\nw2401\\raw-calswap\\nw240102.cnv\n',
#    '# wildedit_pass1_nstd = 2.0\n',
#    '# wildedit_pass2_nstd = 20.0\n',
#    '# wildedit_pass2_mindelta = 0.000e+000\n',
#    '# wildedit_npoint = 100\n',
#    '# wildedit_vars = c0mS/cm c1mS/cm flECO-AFL sbeox0V sbeox1V t090C t190C par prDM\n',
#    '# wildedit_excl_bad_scans = yes\n',
#    '# alignctd_date = Aug 01 2025 08:48:03, 7.26.7.129\n',
#    '# alignctd_in = c:\\data\\ctd\\2024\\nw2401\\raw-calswap\\nw240102.cnv\n',
#    '# alignctd_adv = sbeox0V 3.000, sbeox1V 3.000                                                                                                                                                                                        \n',
#    '# celltm_date = Aug 01 2025 08:48:04, 7.26.7.129\n',
#    '# celltm_in = c:\\data\\ctd\\2024\\nw2401\\raw-calswap\\nw240102.cnv\n',
#    '# celltm_alpha = 0.0300, 0.0300\n',
#    '# celltm_tau = 7.0000, 7.0000\n',
#    '# celltm_temp_sensor_use_for_cond = primary, secondary\n',
#    '# filter_date = Aug 01 2025 08:48:04, 7.26.7.129\n',
#    '# filter_in = c:\\data\\ctd\\2024\\nw2401\\raw-calswap\\nw240102.cnv\n',
#    '# filter_low_pass_tc_A = 0.030\n',
#    '# filter_low_pass_tc_B = 0.150\n',
#    '# filter_low_pass_A_vars =\n',
#    '# filter_low_pass_B_vars = prDM\n',
#    '# loopedit_date = Aug 01 2025 08:48:05, 7.26.7.129\n',
#    '# loopedit_in = c:\\data\\ctd\\2024\\nw2401\\raw-calswap\\nw240102.cnv\n',
#    '# loopedit_percentMeanSpeed: minV = 0.250, ws = 120, percent = 20.00                                                      \n',
#    '# loopedit_surfaceSoak: minDepth = 5.0, maxDepth = 20, useDeckPress = 0                                                   \n',
#    '# loopedit_excl_bad_scans = yes\n',
#    '# Derive_date = Aug 01 2025 08:48:06, 7.26.7.129 [derive_vars = 10]\n',
#    '# Derive_in = c:\\data\\ctd\\2024\\nw2401\\raw-calswap\\nw240102.cnv c:\\data\\ctd\\2024\\nw2401\\raw-calswap\\nw240102.XMLCON\n',
#    '# derive_time_window_docdt = seconds: 2\n',
#    '# derive_ox_tau_correction = yes\n',
#    '# split_date = Aug 01 2025 08:48:06, 7.26.7.129\n',
#    '# split_in = c:\\data\\ctd\\2024\\nw2401\\raw-calswap\\nw240102.cnv\n',
#    '# split_excl_bad_scans = yes\n',
#    '# file_type = ascii\n',
#    '*END*\n'],
#   'headercount': 351,
#   'varnames': {0: 'c0mS/cm',
#    1: 'c1mS/cm',
#    2: 'flECO-AFL',
#    3: 'sbeox0V',
#    4: 'sbeox1V',
#    5: 't090C',
#    6: 't190C',
#    7: 'turbWETntu0',
#    8: 'par',
#    9: 'prDM',
#    10: 'sal00',
#    11: 'sal11',
#    12: 'sbeox0Mg/L',
#    13: 'sbeox0PS',
#    14: 'sbox0Mm/Kg',
#    15: 'sbeox1Mg/L',
#    16: 'sbeox1PS',
#    17: 'sbox1Mm/Kg',
#    18: 'sigma-t00',
#    19: 'sigma-t11',
#    20: 'flag'},
#   'SYSTEMtime': 'Sep 02 2024 21:07:00',
#   'NMEAtime': [],
#   'NMEALat': [],
#   'NMEALon': []},
#  'dnw240103.cnv': {'header': ['* Sea-Bird SBE 9 Data File:\n',
#    '* FileName = C:\\Users\\emafield\\Desktop\\NBS-2024\\NW240103.hex\n',
#    '* Software Version Seasave V 7.26.7.121\n',
#    '* Temperature SN = 4354\n',
#    '* Conductivity SN = 3072\n',
#    '* Number of Bytes Per Scan = 30\n',
#    '* Number of Voltage Words = 4\n',
#    '* Number of Scans Averaged by the Deck Unit = 1\n',
#    '* System UpLoad Time = Sep 03 2024 01:46:29\n',
#    '* SBE 11plus V 5.2\n',
#    '* number of scans to average = 1\n',
#    '* pressure baud rate = 9600\n',
#    '* NMEA baud rate = 4800\n',
#    '* GPIB address = 1\n',
#    '* advance primary conductivity  0.073 seconds\n',
#    '* advance secondary conductivity  0.073 seconds\n',
#    '* autorun on power up is disabled\n',
#    '* S>\n',
#    '** Survey:\n',
#    '** Station:\n',
#    '* System UTC = Sep 03 2024 01:46:29\n',
#    '# nquan = 21                                \n',
#    '# nvalues = 4538                        \n',
#    '# units = specified\n',
#    '# name 0 = c0mS/cm: Conductivity [mS/cm]\n',
#    '# name 1 = c1mS/cm: Conductivity, 2 [mS/cm]\n',
#    '# name 2 = flECO-AFL: Fluorescence, WET Labs ECO-AFL/FL [mg/m^3]\n',
#    '# name 3 = sbeox0V: Oxygen raw, SBE 43 [V]\n',
#    '# name 4 = sbeox1V: Oxygen raw, SBE 43, 2 [V]\n',
#    '# name 5 = t090C: Temperature [ITS-90, deg C]\n',
#    '# name 6 = t190C: Temperature, 2 [ITS-90, deg C]\n',
#    '# name 7 = turbWETntu0: Turbidity, WET Labs ECO [NTU]\n',
#    '# name 8 = par: PAR/Irradiance, Biospherical/Licor [umol photons/m^2/sec]\n',
#    '# name 9 = prDM: Pressure, Digiquartz [db]\n',
#    '# name 10 = sal00: Salinity, Practical [PSU]\n',
#    '# name 11 = sal11: Salinity, Practical, 2 [PSU]\n',
#    '# name 12 = sbeox0Mg/L: Oxygen, SBE 43 [mg/l], WS = 2\n',
#    '# name 13 = sbeox0PS: Oxygen, SBE 43 [% saturation], WS = 2\n',
#    '# name 14 = sbox0Mm/Kg: Oxygen, SBE 43 [umol/kg], WS = 2\n',
#    '# name 15 = sbeox1Mg/L: Oxygen, SBE 43, 2 [mg/l], WS = 2\n',
#    '# name 16 = sbeox1PS: Oxygen, SBE 43, 2 [% saturation], WS = 2\n',
#    '# name 17 = sbox1Mm/Kg: Oxygen, SBE 43, 2 [umol/kg], WS = 2\n',
#    '# name 18 = sigma-t00: Density [sigma-t, kg/m^3 ]\n',
#    '# name 19 = sigma-t11: Density, 2 [sigma-t, kg/m^3 ]\n',
#    '# name 20 = flag: flag\n',
#    '# span 0 =  29.719541,  31.807041       \n',
#    '# span 1 =  30.302157,  31.860901       \n',
#    '# span 2 =    -0.0236,     3.5075       \n',
#    '# span 3 =     1.9170,     2.3077       \n',
#    '# span 4 =     2.0745,     2.7436       \n',
#    '# span 5 =     4.3719,     7.0851       \n',
#    '# span 6 =     4.3619,     7.1443       \n',
#    '# span 7 =    -0.0123,     0.5933       \n',
#    '# span 8 = 1.0000e-12, 1.2106e-01       \n',
#    '# span 9 =      1.179,     51.272       \n',
#    '# span 10 =    31.0778,    31.5130      \n',
#    '# span 11 =    31.0967,    33.1256      \n',
#    '# span 12 =     6.5523,     8.6054      \n',
#    '# span 13 =     65.598,     85.417      \n',
#    '# span 14 =    199.887,    262.473      \n',
#    '# span 15 =     7.2731,    10.5370      \n',
#    '# span 16 =     73.701,    105.678      \n',
#    '# span 17 =    221.881,    321.433      \n',
#    '# span 18 =    24.3382,    24.7825      \n',
#    '# span 19 =    24.3420,    26.2553      \n',
#    '# span 20 = 0.0000e+00, 0.0000e+00      \n',
#    '# interval = seconds: 0.0416667\n',
#    '# start_time = Sep 03 2024 01:46:29 [System UTC, header]\n',
#    '# bad_flag = -9.990e-29\n',
#    '# <Sensors count="13" >\n',
#    '#   <sensor Channel="1" >\n',
#    '#     <!-- Frequency 0, Temperature -->\n',
#    '#     <TemperatureSensor SensorID="55" >\n',
#    '#       <SerialNumber>4354</SerialNumber>\n',
#    '#       <CalibrationDate>11-May-23</CalibrationDate>\n',
#    '#       <UseG_J>1</UseG_J>\n',
#    '#       <A>0.00000000e+000</A>\n',
#    '#       <B>0.00000000e+000</B>\n',
#    '#       <C>0.00000000e+000</C>\n',
#    '#       <D>0.00000000e+000</D>\n',
#    '#       <F0_Old>0.000</F0_Old>\n',
#    '#       <G>4.34852058e-003</G>\n',
#    '#       <H>6.36569482e-004</H>\n',
#    '#       <I>2.19345844e-005</I>\n',
#    '#       <J>1.98995503e-006</J>\n',
#    '#       <F0>1000.000</F0>\n',
#    '#       <Slope>1.00000000</Slope>\n',
#    '#       <Offset>0.0000</Offset>\n',
#    '#     </TemperatureSensor>\n',
#    '#   </sensor>\n',
#    '#   <sensor Channel="2" >\n',
#    '#     <!-- Frequency 1, Conductivity -->\n',
#    '#     <ConductivitySensor SensorID="3" >\n',
#    '#       <SerialNumber>3072</SerialNumber>\n',
#    '#       <CalibrationDate>26-Apr-23</CalibrationDate>\n',
#    '#       <UseG_J>1</UseG_J>\n',
#    '#       <!-- Cell const and series R are applicable only for wide range sensors. -->\n',
#    '#       <SeriesR>0.0000</SeriesR>\n',
#    '#       <CellConst>2000.0000</CellConst>\n',
#    '#       <ConductivityType>0</ConductivityType>\n',
#    '#       <Coefficients equation="0" >\n',
#    '#         <A>0.00000000e+000</A>\n',
#    '#         <B>0.00000000e+000</B>\n',
#    '#         <C>0.00000000e+000</C>\n',
#    '#         <D>0.00000000e+000</D>\n',
#    '#         <M>0.0</M>\n',
#    '#         <CPcor>-9.57000000e-008</CPcor>\n',
#    '#       </Coefficients>\n',
#    '#       <Coefficients equation="1" >\n',
#    '#         <G>-9.78106359e+000</G>\n',
#    '#         <H>1.33765522e+000</H>\n',
#    '#         <I>7.09945466e-004</I>\n',
#    '#         <J>2.14300155e-005</J>\n',
#    '#         <CPcor>-9.57000000e-008</CPcor>\n',
#    '#         <CTcor>3.2500e-006</CTcor>\n',
#    '#         <!-- WBOTC not applicable unless ConductivityType = 1. -->\n',
#    '#         <WBOTC>0.00000000e+000</WBOTC>\n',
#    '#       </Coefficients>\n',
#    '#       <Slope>1.00000000</Slope>\n',
#    '#       <Offset>0.00000</Offset>\n',
#    '#     </ConductivitySensor>\n',
#    '#   </sensor>\n',
#    '#   <sensor Channel="3" >\n',
#    '#     <!-- Frequency 2, Pressure, Digiquartz with TC -->\n',
#    '#     <PressureSensor SensorID="45" >\n',
#    '#       <SerialNumber>0775</SerialNumber>\n',
#    '#       <CalibrationDate>14-Apr-23</CalibrationDate>\n',
#    '#       <C1>-4.207550e+004</C1>\n',
#    '#       <C2>-7.186518e-001</C2>\n',
#    '#       <C3>1.164310e-002</C3>\n',
#    '#       <D1>3.533500e-002</D1>\n',
#    '#       <D2>0.000000e+000</D2>\n',
#    '#       <T1>3.008985e+001</T1>\n',
#    '#       <T2>-5.064140e-004</T2>\n',
#    '#       <T3>4.126460e-006</T3>\n',
#    '#       <T4>6.565360e-010</T4>\n',
#    '#       <Slope>0.99980379</Slope>\n',
#    '#       <Offset>0.71774</Offset>\n',
#    '#       <T5>0.000000e+000</T5>\n',
#    '#       <AD590M>1.280410e-002</AD590M>\n',
#    '#       <AD590B>-8.261400e+000</AD590B>\n',
#    '#     </PressureSensor>\n',
#    '#   </sensor>\n',
#    '#   <sensor Channel="4" >\n',
#    '#     <!-- Frequency 3, Temperature, 2 -->\n',
#    '#     <TemperatureSensor SensorID="55" >\n',
#    '#       <SerialNumber>4394</SerialNumber>\n',
#    '#       <CalibrationDate>13-May-23</CalibrationDate>\n',
#    '#       <UseG_J>1</UseG_J>\n',
#    '#       <A>0.00000000e+000</A>\n',
#    '#       <B>0.00000000e+000</B>\n',
#    '#       <C>0.00000000e+000</C>\n',
#    '#       <D>0.00000000e+000</D>\n',
#    '#       <F0_Old>0.000</F0_Old>\n',
#    '#       <G>4.35777370e-003</G>\n',
#    '#       <H>6.44786944e-004</H>\n',
#    '#       <I>2.22424806e-005</I>\n',
#    '#       <J>1.80325050e-006</J>\n',
#    '#       <F0>1000.000</F0>\n',
#    '#       <Slope>1.00000000</Slope>\n',
#    '#       <Offset>0.0000</Offset>\n',
#    '#     </TemperatureSensor>\n',
#    '#   </sensor>\n',
#    '#   <sensor Channel="5" >\n',
#    '#     <!-- Frequency 4, Conductivity, 2 -->\n',
#    '#     <ConductivitySensor SensorID="3" >\n',
#    '#       <SerialNumber>2879</SerialNumber>\n',
#    '#       <CalibrationDate>26-Apr-23</CalibrationDate>\n',
#    '#       <UseG_J>1</UseG_J>\n',
#    '#       <!-- Cell const and series R are applicable only for wide range sensors. -->\n',
#    '#       <SeriesR>0.0000</SeriesR>\n',
#    '#       <CellConst>2000.0000</CellConst>\n',
#    '#       <ConductivityType>0</ConductivityType>\n',
#    '#       <Coefficients equation="0" >\n',
#    '#         <A>0.00000000e+000</A>\n',
#    '#         <B>0.00000000e+000</B>\n',
#    '#         <C>0.00000000e+000</C>\n',
#    '#         <D>0.00000000e+000</D>\n',
#    '#         <M>0.0</M>\n',
#    '#         <CPcor>-9.57000000e-008</CPcor>\n',
#    '#       </Coefficients>\n',
#    '#       <Coefficients equation="1" >\n',
#    '#         <G>-1.02061711e+001</G>\n',
#    '#         <H>1.40171143e+000</H>\n',
#    '#         <I>1.17328370e-003</I>\n',
#    '#         <J>-1.30258422e-006</J>\n',
#    '#         <CPcor>-9.57000000e-008</CPcor>\n',
#    '#         <CTcor>3.2500e-006</CTcor>\n',
#    '#         <!-- WBOTC not applicable unless ConductivityType = 1. -->\n',
#    '#         <WBOTC>0.00000000e+000</WBOTC>\n',
#    '#       </Coefficients>\n',
#    '#       <Slope>1.00000000</Slope>\n',
#    '#       <Offset>0.00000</Offset>\n',
#    '#     </ConductivitySensor>\n',
#    '#   </sensor>\n',
#    '#   <sensor Channel="6" >\n',
#    '#     <!-- A/D voltage 0, Oxygen, SBE 43 -->\n',
#    '#     <OxygenSensor SensorID="38" >\n',
#    '#       <SerialNumber>0804</SerialNumber>\n',
#    '#       <CalibrationDate>27-Apr-23</CalibrationDate>\n',
#    '#       <Use2007Equation>1</Use2007Equation>\n',
#    '#       <CalibrationCoefficients equation="0" >\n',
#    '#         <!-- Coefficients for Owens-Millard equation. -->\n',
#    '#         <Boc>0.0000</Boc>\n',
#    '#         <Soc>0.0000e+000</Soc>\n',
#    '#         <offset>0.0000</offset>\n',
#    '#         <Pcor>0.00e+000</Pcor>\n',
#    '#         <Tcor>0.0000</Tcor>\n',
#    '#         <Tau>0.0</Tau>\n',
#    '#       </CalibrationCoefficients>\n',
#    '#       <CalibrationCoefficients equation="1" >\n',
#    '#         <!-- Coefficients for Sea-Bird equation - SBE calibration in 2007 and later. -->\n',
#    '#         <Soc>4.7104e-001</Soc>\n',
#    '#         <offset>-0.4892</offset>\n',
#    '#         <A>-4.1124e-003</A>\n',
#    '#         <B> 1.6563e-004</B>\n',
#    '#         <C>-2.5102e-006</C>\n',
#    '#         <D0> 2.5826e+000</D0>\n',
#    '#         <D1> 1.92634e-004</D1>\n',
#    '#         <D2>-4.64803e-002</D2>\n',
#    '#         <E> 3.6000e-002</E>\n',
#    '#         <Tau20> 0.9400</Tau20>\n',
#    '#         <H1>-3.3000e-002</H1>\n',
#    '#         <H2> 5.0000e+003</H2>\n',
#    '#         <H3> 1.4500e+003</H3>\n',
#    '#       </CalibrationCoefficients>\n',
#    '#     </OxygenSensor>\n',
#    '#   </sensor>\n',
#    '#   <sensor Channel="7" >\n',
#    '#     <!-- A/D voltage 1, Oxygen, SBE 43, 2 -->\n',
#    '#     <OxygenSensor SensorID="38" >\n',
#    '#       <SerialNumber>1301</SerialNumber>\n',
#    '#       <CalibrationDate>03-May-23</CalibrationDate>\n',
#    '#       <Use2007Equation>1</Use2007Equation>\n',
#    '#       <CalibrationCoefficients equation="0" >\n',
#    '#         <!-- Coefficients for Owens-Millard equation. -->\n',
#    '#         <Boc>0.0000</Boc>\n',
#    '#         <Soc>0.0000e+000</Soc>\n',
#    '#         <offset>0.0000</offset>\n',
#    '#         <Pcor>0.00e+000</Pcor>\n',
#    '#         <Tcor>0.0000</Tcor>\n',
#    '#         <Tau>0.0</Tau>\n',
#    '#       </CalibrationCoefficients>\n',
#    '#       <CalibrationCoefficients equation="1" >\n',
#    '#         <!-- Coefficients for Sea-Bird equation - SBE calibration in 2007 and later. -->\n',
#    '#         <Soc>4.7840e-001</Soc>\n',
#    '#         <offset>-0.4916</offset>\n',
#    '#         <A>-4.0592e-003</A>\n',
#    '#         <B> 1.8162e-004</B>\n',
#    '#         <C>-2.5361e-006</C>\n',
#    '#         <D0> 2.5826e+000</D0>\n',
#    '#         <D1> 1.92634e-004</D1>\n',
#    '#         <D2>-4.64803e-002</D2>\n',
#    '#         <E> 3.6000e-002</E>\n',
#    '#         <Tau20> 1.0800</Tau20>\n',
#    '#         <H1>-3.3000e-002</H1>\n',
#    '#         <H2> 5.0000e+003</H2>\n',
#    '#         <H3> 1.4500e+003</H3>\n',
#    '#       </CalibrationCoefficients>\n',
#    '#     </OxygenSensor>\n',
#    '#   </sensor>\n',
#    '#   <sensor Channel="8" >\n',
#    '#     <!-- A/D voltage 2, Fluorometer, WET Labs ECO-AFL/FL -->\n',
#    '#     <FluoroWetlabECO_AFL_FL_Sensor SensorID="20" >\n',
#    '#       <SerialNumber>FLNTURT-8441</SerialNumber>\n',
#    '#       <CalibrationDate>Aug 15,2023</CalibrationDate>\n',
#    '#       <ScaleFactor>6.00000000e+000</ScaleFactor>\n',
#    '#       <!-- Dark output -->\n',
#    '#       <Vblank>0.0540</Vblank>\n',
#    '#     </FluoroWetlabECO_AFL_FL_Sensor>\n',
#    '#   </sensor>\n',
#    '#   <sensor Channel="9" >\n',
#    '#     <!-- A/D voltage 3, Turbidity Meter, WET Labs, ECO-NTU -->\n',
#    '#     <TurbidityMeter SensorID="67" >\n',
#    '#       <SerialNumber>FLNTURT-8441</SerialNumber>\n',
#    '#       <CalibrationDate>August 15,2023</CalibrationDate>\n',
#    '#       <ScaleFactor>2.000000</ScaleFactor>\n',
#    '#       <!-- Dark output -->\n',
#    '#       <DarkVoltage>0.066000</DarkVoltage>\n',
#    '#     </TurbidityMeter>\n',
#    '#   </sensor>\n',
#    '#   <sensor Channel="10" >\n',
#    '#     <!-- A/D voltage 4, PAR/Irradiance, Biospherical/Licor -->\n',
#    '#     <PAR_BiosphericalLicorChelseaSensor SensorID="42" >\n',
#    '#       <SerialNumber>70750</SerialNumber>\n',
#    '#       <CalibrationDate>5/2/22</CalibrationDate>\n',
#    '#       <M>1.00000000</M>\n',
#    '#       <B>0.00000000</B>\n',
#    '#       <CalibrationConstant>100000000000000.00000000</CalibrationConstant>\n',
#    '#       <ConversionUnits>1</ConversionUnits>\n',
#    '#       <Multiplier>1.00000000</Multiplier>\n',
#    '#       <Offset>-0.00001011</Offset>\n',
#    '#     </PAR_BiosphericalLicorChelseaSensor>\n',
#    '#   </sensor>\n',
#    '#   <sensor Channel="11" >\n',
#    '#     <!-- A/D voltage 5, Transmissometer, WET Labs C-Star -->\n',
#    '#     <WET_LabsCStar SensorID="71" >\n',
#    '#       <SerialNumber>CST-676PR</SerialNumber>\n',
#    '#       <CalibrationDate>May 10, 2023</CalibrationDate>\n',
#    '#       <M>21.2400</M>\n',
#    '#       <B>-0.1274</B>\n',
#    '#       <PathLength>0.250</PathLength>\n',
#    '#     </WET_LabsCStar>\n',
#    '#   </sensor>\n',
#    '#   <sensor Channel="12" >\n',
# ...
#    '# name 3 = sbeox0V: Oxygen raw, SBE 43 [V]\n',
#    '# name 4 = sbeox1V: Oxygen raw, SBE 43, 2 [V]\n',
#    '# name 5 = t090C: Temperature [ITS-90, deg C]\n',
#    '# name 6 = t190C: Temperature, 2 [ITS-90, deg C]\n',
#    '# name 7 = turbWETntu0: Turbidity, WET Labs ECO [NTU]\n',
#    '# name 8 = par: PAR/Irradiance, Biospherical/Licor [umol photons/m^2/sec]\n',
#    '# name 9 = prDM: Pressure, Digiquartz [db]\n',
#    '# name 10 = sal00: Salinity, Practical [PSU]\n',
#    '# name 11 = sal11: Salinity, Practical, 2 [PSU]\n',
#    '# name 12 = sbeox0Mg/L: Oxygen, SBE 43 [mg/l], WS = 2\n',
#    '# name 13 = sbeox0PS: Oxygen, SBE 43 [% saturation], WS = 2\n',
#    '# name 14 = sbox0Mm/Kg: Oxygen, SBE 43 [umol/kg], WS = 2\n',
#    '# name 15 = sbeox1Mg/L: Oxygen, SBE 43, 2 [mg/l], WS = 2\n',
#    '# name 16 = sbeox1PS: Oxygen, SBE 43, 2 [% saturation], WS = 2\n',
#    '# name 17 = sbox1Mm/Kg: Oxygen, SBE 43, 2 [umol/kg], WS = 2\n',
#    '# name 18 = sigma-t00: Density [sigma-t, kg/m^3 ]\n',
#    '# name 19 = sigma-t11: Density, 2 [sigma-t, kg/m^3 ]\n',
#    '# name 20 = flag: flag\n',
#    '# span 0 =  26.512996,  30.809169       \n',
#    '# span 1 =  26.684884,  30.174907       \n',
#    '# span 2 =    -0.0896,     1.2584       \n',
#    '# span 3 =     2.0574,     2.2002       \n',
#    '# span 4 =     2.2564,     2.5678       \n',
#    '# span 5 =     9.5490,     9.7769       \n',
#    '# span 6 =     9.6502,     9.8571       \n',
#    '# span 7 =    -0.0514,     5.2013       \n',
#    '# span 8 = 1.0000e-12, 1.7243e-02       \n',
#    '# span 9 =      2.240,     19.347       \n',
#    '# span 10 =    23.7340,    27.9058      \n',
#    '# span 11 =    23.8310,    27.1367      \n',
#    '# span 12 =     6.7695,     7.8931      \n',
#    '# span 13 =     71.198,     80.562      \n',
#    '# span 14 =    207.133,    242.244      \n',
#    '# span 15 =     7.8435,     9.4739      \n',
#    '# span 16 =     82.350,     97.001      \n',
#    '# span 17 =    240.112,    290.744      \n',
#    '# span 18 =    18.2365,    21.4697      \n',
#    '# span 19 =    18.2966,    20.8423      \n',
#    '# span 20 = 0.0000e+00, 0.0000e+00      \n',
#    '# interval = seconds: 0.0416667\n',
#    '# start_time = Sep 19 2024 00:25:03 [System UTC, header]\n',
#    '# bad_flag = -9.990e-29\n',
#    '# <Sensors count="13" >\n',
#    '#   <sensor Channel="1" >\n',
#    '#     <!-- Frequency 0, Temperature -->\n',
#    '#     <TemperatureSensor SensorID="55" >\n',
#    '#       <SerialNumber>4354</SerialNumber>\n',
#    '#       <CalibrationDate>11-May-23</CalibrationDate>\n',
#    '#       <UseG_J>1</UseG_J>\n',
#    '#       <A>0.00000000e+000</A>\n',
#    '#       <B>0.00000000e+000</B>\n',
#    '#       <C>0.00000000e+000</C>\n',
#    '#       <D>0.00000000e+000</D>\n',
#    '#       <F0_Old>0.000</F0_Old>\n',
#    '#       <G>4.34852058e-003</G>\n',
#    '#       <H>6.36569482e-004</H>\n',
#    '#       <I>2.19345844e-005</I>\n',
#    '#       <J>1.98995503e-006</J>\n',
#    '#       <F0>1000.000</F0>\n',
#    '#       <Slope>1.00000000</Slope>\n',
#    '#       <Offset>0.0000</Offset>\n',
#    '#     </TemperatureSensor>\n',
#    '#   </sensor>\n',
#    '#   <sensor Channel="2" >\n',
#    '#     <!-- Frequency 1, Conductivity -->\n',
#    '#     <ConductivitySensor SensorID="3" >\n',
#    '#       <SerialNumber>3072</SerialNumber>\n',
#    '#       <CalibrationDate>26-Apr-23</CalibrationDate>\n',
#    '#       <UseG_J>1</UseG_J>\n',
#    '#       <!-- Cell const and series R are applicable only for wide range sensors. -->\n',
#    '#       <SeriesR>0.0000</SeriesR>\n',
#    '#       <CellConst>2000.0000</CellConst>\n',
#    '#       <ConductivityType>0</ConductivityType>\n',
#    '#       <Coefficients equation="0" >\n',
#    '#         <A>0.00000000e+000</A>\n',
#    '#         <B>0.00000000e+000</B>\n',
#    '#         <C>0.00000000e+000</C>\n',
#    '#         <D>0.00000000e+000</D>\n',
#    '#         <M>0.0</M>\n',
#    '#         <CPcor>-9.57000000e-008</CPcor>\n',
#    '#       </Coefficients>\n',
#    '#       <Coefficients equation="1" >\n',
#    '#         <G>-9.78106359e+000</G>\n',
#    '#         <H>1.33765522e+000</H>\n',
#    '#         <I>7.09945466e-004</I>\n',
#    '#         <J>2.14300155e-005</J>\n',
#    '#         <CPcor>-9.57000000e-008</CPcor>\n',
#    '#         <CTcor>3.2500e-006</CTcor>\n',
#    '#         <!-- WBOTC not applicable unless ConductivityType = 1. -->\n',
#    '#         <WBOTC>0.00000000e+000</WBOTC>\n',
#    '#       </Coefficients>\n',
#    '#       <Slope>1.00000000</Slope>\n',
#    '#       <Offset>0.00000</Offset>\n',
#    '#     </ConductivitySensor>\n',
#    '#   </sensor>\n',
#    '#   <sensor Channel="3" >\n',
#    '#     <!-- Frequency 2, Pressure, Digiquartz with TC -->\n',
#    '#     <PressureSensor SensorID="45" >\n',
#    '#       <SerialNumber>0775</SerialNumber>\n',
#    '#       <CalibrationDate>14-Apr-23</CalibrationDate>\n',
#    '#       <C1>-4.207550e+004</C1>\n',
#    '#       <C2>-7.186518e-001</C2>\n',
#    '#       <C3>1.164310e-002</C3>\n',
#    '#       <D1>3.533500e-002</D1>\n',
#    '#       <D2>0.000000e+000</D2>\n',
#    '#       <T1>3.008985e+001</T1>\n',
#    '#       <T2>-5.064140e-004</T2>\n',
#    '#       <T3>4.126460e-006</T3>\n',
#    '#       <T4>6.565360e-010</T4>\n',
#    '#       <Slope>0.99980379</Slope>\n',
#    '#       <Offset>0.71774</Offset>\n',
#    '#       <T5>0.000000e+000</T5>\n',
#    '#       <AD590M>1.280410e-002</AD590M>\n',
#    '#       <AD590B>-8.261400e+000</AD590B>\n',
#    '#     </PressureSensor>\n',
#    '#   </sensor>\n',
#    '#   <sensor Channel="4" >\n',
#    '#     <!-- Frequency 3, Temperature, 2 -->\n',
#    '#     <TemperatureSensor SensorID="55" >\n',
#    '#       <SerialNumber>4394</SerialNumber>\n',
#    '#       <CalibrationDate>13-May-23</CalibrationDate>\n',
#    '#       <UseG_J>1</UseG_J>\n',
#    '#       <A>0.00000000e+000</A>\n',
#    '#       <B>0.00000000e+000</B>\n',
#    '#       <C>0.00000000e+000</C>\n',
#    '#       <D>0.00000000e+000</D>\n',
#    '#       <F0_Old>0.000</F0_Old>\n',
#    '#       <G>4.35777370e-003</G>\n',
#    '#       <H>6.44786944e-004</H>\n',
#    '#       <I>2.22424806e-005</I>\n',
#    '#       <J>1.80325050e-006</J>\n',
#    '#       <F0>1000.000</F0>\n',
#    '#       <Slope>1.00000000</Slope>\n',
#    '#       <Offset>0.0000</Offset>\n',
#    '#     </TemperatureSensor>\n',
#    '#   </sensor>\n',
#    '#   <sensor Channel="5" >\n',
#    '#     <!-- Frequency 4, Conductivity, 2 -->\n',
#    '#     <ConductivitySensor SensorID="3" >\n',
#    '#       <SerialNumber>2879</SerialNumber>\n',
#    '#       <CalibrationDate>26-Apr-23</CalibrationDate>\n',
#    '#       <UseG_J>1</UseG_J>\n',
#    '#       <!-- Cell const and series R are applicable only for wide range sensors. -->\n',
#    '#       <SeriesR>0.0000</SeriesR>\n',
#    '#       <CellConst>2000.0000</CellConst>\n',
#    '#       <ConductivityType>0</ConductivityType>\n',
#    '#       <Coefficients equation="0" >\n',
#    '#         <A>0.00000000e+000</A>\n',
#    '#         <B>0.00000000e+000</B>\n',
#    '#         <C>0.00000000e+000</C>\n',
#    '#         <D>0.00000000e+000</D>\n',
#    '#         <M>0.0</M>\n',
#    '#         <CPcor>-9.57000000e-008</CPcor>\n',
#    '#       </Coefficients>\n',
#    '#       <Coefficients equation="1" >\n',
#    '#         <G>-1.02061711e+001</G>\n',
#    '#         <H>1.40171143e+000</H>\n',
#    '#         <I>1.17328370e-003</I>\n',
#    '#         <J>-1.30258422e-006</J>\n',
#    '#         <CPcor>-9.57000000e-008</CPcor>\n',
#    '#         <CTcor>3.2500e-006</CTcor>\n',
#    '#         <!-- WBOTC not applicable unless ConductivityType = 1. -->\n',
#    '#         <WBOTC>0.00000000e+000</WBOTC>\n',
#    '#       </Coefficients>\n',
#    '#       <Slope>1.00000000</Slope>\n',
#    '#       <Offset>0.00000</Offset>\n',
#    '#     </ConductivitySensor>\n',
#    '#   </sensor>\n',
#    '#   <sensor Channel="6" >\n',
#    '#     <!-- A/D voltage 0, Oxygen, SBE 43 -->\n',
#    '#     <OxygenSensor SensorID="38" >\n',
#    '#       <SerialNumber>0804</SerialNumber>\n',
#    '#       <CalibrationDate>27-Apr-23</CalibrationDate>\n',
#    '#       <Use2007Equation>1</Use2007Equation>\n',
#    '#       <CalibrationCoefficients equation="0" >\n',
#    '#         <!-- Coefficients for Owens-Millard equation. -->\n',
#    '#         <Boc>0.0000</Boc>\n',
#    '#         <Soc>0.0000e+000</Soc>\n',
#    '#         <offset>0.0000</offset>\n',
#    '#         <Pcor>0.00e+000</Pcor>\n',
#    '#         <Tcor>0.0000</Tcor>\n',
#    '#         <Tau>0.0</Tau>\n',
#    '#       </CalibrationCoefficients>\n',
#    '#       <CalibrationCoefficients equation="1" >\n',
#    '#         <!-- Coefficients for Sea-Bird equation - SBE calibration in 2007 and later. -->\n',
#    '#         <Soc>4.7104e-001</Soc>\n',
#    '#         <offset>-0.4892</offset>\n',
#    '#         <A>-4.1124e-003</A>\n',
#    '#         <B> 1.6563e-004</B>\n',
#    '#         <C>-2.5102e-006</C>\n',
#    '#         <D0> 2.5826e+000</D0>\n',
#    '#         <D1> 1.92634e-004</D1>\n',
#    '#         <D2>-4.64803e-002</D2>\n',
#    '#         <E> 3.6000e-002</E>\n',
#    '#         <Tau20> 0.9400</Tau20>\n',
#    '#         <H1>-3.3000e-002</H1>\n',
#    '#         <H2> 5.0000e+003</H2>\n',
#    '#         <H3> 1.4500e+003</H3>\n',
#    '#       </CalibrationCoefficients>\n',
#    '#     </OxygenSensor>\n',
#    '#   </sensor>\n',
#    '#   <sensor Channel="7" >\n',
#    '#     <!-- A/D voltage 1, Oxygen, SBE 43, 2 -->\n',
#    '#     <OxygenSensor SensorID="38" >\n',
#    '#       <SerialNumber>1301</SerialNumber>\n',
#    '#       <CalibrationDate>03-May-23</CalibrationDate>\n',
#    '#       <Use2007Equation>1</Use2007Equation>\n',
#    '#       <CalibrationCoefficients equation="0" >\n',
#    '#         <!-- Coefficients for Owens-Millard equation. -->\n',
#    '#         <Boc>0.0000</Boc>\n',
#    '#         <Soc>0.0000e+000</Soc>\n',
#    '#         <offset>0.0000</offset>\n',
#    '#         <Pcor>0.00e+000</Pcor>\n',
#    '#         <Tcor>0.0000</Tcor>\n',
#    '#         <Tau>0.0</Tau>\n',
#    '#       </CalibrationCoefficients>\n',
#    '#       <CalibrationCoefficients equation="1" >\n',
#    '#         <!-- Coefficients for Sea-Bird equation - SBE calibration in 2007 and later. -->\n',
#    '#         <Soc>4.7840e-001</Soc>\n',
#    '#         <offset>-0.4916</offset>\n',
#    '#         <A>-4.0592e-003</A>\n',
#    '#         <B> 1.8162e-004</B>\n',
#    '#         <C>-2.5361e-006</C>\n',
#    '#         <D0> 2.5826e+000</D0>\n',
#    '#         <D1> 1.92634e-004</D1>\n',
#    '#         <D2>-4.64803e-002</D2>\n',
#    '#         <E> 3.6000e-002</E>\n',
#    '#         <Tau20> 1.0800</Tau20>\n',
#    '#         <H1>-3.3000e-002</H1>\n',
#    '#         <H2> 5.0000e+003</H2>\n',
#    '#         <H3> 1.4500e+003</H3>\n',
#    '#       </CalibrationCoefficients>\n',
#    '#     </OxygenSensor>\n',
#    '#   </sensor>\n',
#    '#   <sensor Channel="8" >\n',
#    '#     <!-- A/D voltage 2, Fluorometer, WET Labs ECO-AFL/FL -->\n',
#    '#     <FluoroWetlabECO_AFL_FL_Sensor SensorID="20" >\n',
#    '#       <SerialNumber>FLNTURT-8441</SerialNumber>\n',
#    '#       <CalibrationDate>Aug 15,2023</CalibrationDate>\n',
#    '#       <ScaleFactor>6.00000000e+000</ScaleFactor>\n',
#    '#       <!-- Dark output -->\n',
#    '#       <Vblank>0.0540</Vblank>\n',
#    '#     </FluoroWetlabECO_AFL_FL_Sensor>\n',
#    '#   </sensor>\n',
#    '#   <sensor Channel="9" >\n',
#    '#     <!-- A/D voltage 3, Turbidity Meter, WET Labs, ECO-NTU -->\n',
#    '#     <TurbidityMeter SensorID="67" >\n',
#    '#       <SerialNumber>FLNTURT-8441</SerialNumber>\n',
#    '#       <CalibrationDate>August 15,2023</CalibrationDate>\n',
#    '#       <ScaleFactor>2.000000</ScaleFactor>\n',
#    '#       <!-- Dark output -->\n',
#    '#       <DarkVoltage>0.066000</DarkVoltage>\n',
#    '#     </TurbidityMeter>\n',
#    '#   </sensor>\n',
#    '#   <sensor Channel="10" >\n',
#    '#     <!-- A/D voltage 4, PAR/Irradiance, Biospherical/Licor -->\n',
#    '#     <PAR_BiosphericalLicorChelseaSensor SensorID="42" >\n',
#    '#       <SerialNumber>70750</SerialNumber>\n',
#    '#       <CalibrationDate>5/2/22</CalibrationDate>\n',
#    '#       <M>1.00000000</M>\n',
#    '#       <B>0.00000000</B>\n',
#    '#       <CalibrationConstant>100000000000000.00000000</CalibrationConstant>\n',
#    '#       <ConversionUnits>1</ConversionUnits>\n',
#    '#       <Multiplier>1.00000000</Multiplier>\n',
#    '#       <Offset>-0.00001011</Offset>\n',
#    '#     </PAR_BiosphericalLicorChelseaSensor>\n',
#    '#   </sensor>\n',
#    '#   <sensor Channel="11" >\n',
#    '#     <!-- A/D voltage 5, Transmissometer, WET Labs C-Star -->\n',
#    '#     <WET_LabsCStar SensorID="71" >\n',
#    '#       <SerialNumber>CST-676PR</SerialNumber>\n',
#    '#       <CalibrationDate>May 10, 2023</CalibrationDate>\n',
#    '#       <M>21.2400</M>\n',
#    '#       <B>-0.1274</B>\n',
#    '#       <PathLength>0.250</PathLength>\n',
#    '#     </WET_LabsCStar>\n',
#    '#   </sensor>\n',
#    '#   <sensor Channel="12" >\n',
#    '#     <!-- A/D voltage 6, Free -->\n',
#    '#   </sensor>\n',
#    '#   <sensor Channel="13" >\n',
#    '#     <!-- A/D voltage 7, Free -->\n',
#    '#   </sensor>\n',
#    '# </Sensors>\n',
#    '# datcnv_date = Aug 01 2025 08:52:35, 7.26.7.129 [datcnv_vars = 10]\n',
#    '# datcnv_in = c:\\data\\ctd\\2024\\nw2401\\raw-calswap\\nw240145.hex c:\\data\\ctd\\2024\\nw2401\\raw-calswap\\nw240145.XMLCON\n',
#    '# datcnv_skipover = 0\n',
#    '# datcnv_ox_hysteresis_correction = yes\n',
#    '# wildedit_date = Aug 01 2025 08:52:37, 7.26.7.129\n',
#    '# wildedit_in = c:\\data\\ctd\\2024\\nw2401\\raw-calswap\\nw240145.cnv\n',
#    '# wildedit_pass1_nstd = 2.0\n',
#    '# wildedit_pass2_nstd = 20.0\n',
#    '# wildedit_pass2_mindelta = 0.000e+000\n',
#    '# wildedit_npoint = 100\n',
#    '# wildedit_vars = c0mS/cm c1mS/cm flECO-AFL sbeox0V sbeox1V t090C t190C par prDM\n',
#    '# wildedit_excl_bad_scans = yes\n',
#    '# alignctd_date = Aug 01 2025 08:52:37, 7.26.7.129\n',
#    '# alignctd_in = c:\\data\\ctd\\2024\\nw2401\\raw-calswap\\nw240145.cnv\n',
#    '# alignctd_adv = sbeox0V 3.000, sbeox1V 3.000                                                                                                                                                                                        \n',
#    '# celltm_date = Aug 01 2025 08:52:37, 7.26.7.129\n',
#    '# celltm_in = c:\\data\\ctd\\2024\\nw2401\\raw-calswap\\nw240145.cnv\n',
#    '# celltm_alpha = 0.0300, 0.0300\n',
#    '# celltm_tau = 7.0000, 7.0000\n',
#    '# celltm_temp_sensor_use_for_cond = primary, secondary\n',
#    '# filter_date = Aug 01 2025 08:52:38, 7.26.7.129\n',
#    '# filter_in = c:\\data\\ctd\\2024\\nw2401\\raw-calswap\\nw240145.cnv\n',
#    '# filter_low_pass_tc_A = 0.030\n',
#    '# filter_low_pass_tc_B = 0.150\n',
#    '# filter_low_pass_A_vars =\n',
#    '# filter_low_pass_B_vars = prDM\n',
#    '# loopedit_date = Aug 01 2025 08:52:38, 7.26.7.129\n',
#    '# loopedit_in = c:\\data\\ctd\\2024\\nw2401\\raw-calswap\\nw240145.cnv\n',
#    '# loopedit_percentMeanSpeed: minV = 0.250, ws = 120, percent = 20.00                                                      \n',
#    '# loopedit_surfaceSoak: minDepth = 5.0, maxDepth = 20, useDeckPress = 0                                                   \n',
#    '# loopedit_excl_bad_scans = yes\n',
#    '# Derive_date = Aug 01 2025 08:52:38, 7.26.7.129 [derive_vars = 10]\n',
#    '# Derive_in = c:\\data\\ctd\\2024\\nw2401\\raw-calswap\\nw240145.cnv c:\\data\\ctd\\2024\\nw2401\\raw-calswap\\nw240145.XMLCON\n',
#    '# derive_time_window_docdt = seconds: 2\n',
#    '# derive_ox_tau_correction = yes\n',
#    '# split_date = Aug 01 2025 08:52:39, 7.26.7.129\n',
#    '# split_in = c:\\data\\ctd\\2024\\nw2401\\raw-calswap\\nw240145.cnv\n',
#    '# split_excl_bad_scans = yes\n',
#    '# file_type = ascii\n',
#    '*END*\n'],
#   'headercount': 351,
#   'varnames': {0: 'c0mS/cm',
#    1: 'c1mS/cm',
#    2: 'flECO-AFL',
#    3: 'sbeox0V',
#    4: 'sbeox1V',
#    5: 't090C',
#    6: 't190C',
#    7: 'turbWETntu0',
#    8: 'par',
#    9: 'prDM',
#    10: 'sal00',
#    11: 'sal11',
#    12: 'sbeox0Mg/L',
#    13: 'sbeox0PS',
#    14: 'sbox0Mm/Kg',
#    15: 'sbeox1Mg/L',
#    16: 'sbeox1PS',
#    17: 'sbox1Mm/Kg',
#    18: 'sigma-t00',
#    19: 'sigma-t11',
#    20: 'flag'},
#   'SYSTEMtime': 'Sep 19 2024 00:25:03',
#   'NMEAtime': [],
#   'NMEALat': [],
#   'NMEALon': []}}

# %%
#this line adds available NMEA data to csv files for NRT/Preliminary erddap hosting... if there isn't an NMEA string, you will have to pull the locations
#  from the cast logs and output either a .nc or a more elaborate csv file furthur in to this process
NMEA_location = False
verbose = False
SYSTEMtime = True

if NMEA_location:
    
    for cast in cruise_header.keys():
        cruise_data[cast][['time','latitude','longitude','profileid']] = ('0',0,0,'0')
        cruise_data[cast][['time','latitude','longitude','profileid']] = (cruise_header[cast]['NMEAtime'],
              geotools.latlon_convert(cruise_header[cast]['NMEALat'],cruise_header[cast]['NMEALon'])[0],
              geotools.latlon_convert(cruise_header[cast]['NMEALat'],cruise_header[cast]['NMEALon'])[1],
              cast.split('.')[0])
        if verbose:
            print(cruise_header[cast]['NMEAtime'],
                  geotools.latlon_convert(cruise_header[cast]['NMEALat'],cruise_header[cast]['NMEALon'])[0],
                  geotools.latlon_convert(cruise_header[cast]['NMEALat'],cruise_header[cast]['NMEALon'])[1])
elif SYSTEMtime:
     for cast in cruise_header.keys():
        cruise_data[cast][['time','latitude','longitude','profileid']] = ('0',0,0,'0')
        cruise_data[cast][['time','latitude','longitude','profileid']] = (cruise_header[cast]['SYSTEMtime'],0,0,cast.split('.')[0])

# %%
#save downcast csv to file for viewing - really this is just a cleaned up cnv file
import pandas as pd
for cast in cruise_data.keys():
    # print(f'Processing Cast {cast}')
    cruise_data[cast]['time'] = pd.to_datetime(cruise_data[cast]['time'])
    cruise_data[cast].to_csv(sample_data_dir+cast.replace('cnv','csv'))

# %% [markdown]
# ## Post Cruise Processing with additional meta information

# %%
###############################################################
# edit to point to {cruise sepcific} raw datafiles 
datafile = sample_data_dir+'rawconverted-calswap/' #<- point to cruise and process all files within
cruise_name = 'NW2401' #no hyphens
cruise_meta_file = sample_data_dir+'logs/NW2401.yaml'
inst_meta_file = sample_data_dir+'logs/EMA_standard_CTD.yaml'
group_meta_file = ecofocipy_dir+'staticdata/institutional_meta_example_ctd.yaml'
inst_shortname = '' #keep as placeholder for now
###############################################################

#init and load data
cruise = sbe_ctd_parser.sbe9_11p()
filename_list = sorted(glob.glob(datafile + '*.cnv'))

(cruise_data,cruise_header) = cruise.parse(filename_list)

# %% [markdown]
# ## Time Properties
#
# Not traditionally dealt with for CTD files as they are likely dynamically updated via GPS feed.  However, FOCI tends to label the date/time with the ***at depth*** time-stamp
#
# ## Depth Properties and other assumptions
#
# - currently, all processing and binning (1m for FOCI) is done via seabird routines and the windows software.  This may change with the python ctd package for a few tasks

# %% [markdown]
# ## Load all external meta information

# %%
#cruise info
with open(cruise_meta_file) as file:
    cruise_config = yaml.full_load(file)

#instrument info
with open(inst_meta_file) as file:
    inst_config = yaml.full_load(file)

#institutional info
with open(group_meta_file) as file:
    group_config = yaml.full_load(file)

# %%
inst_config
# Out:
# {'time': {'epic_key': 'TIM_601',
#   'name': 'time',
#   'generic_name': 'time',
#   'standard_name': 'time',
#   'long_name': 'date and time since reference time'},
#  'depth': {'epic_key': 'D_3',
#   'generic_name': 'depth',
#   'units': 'meter',
#   'long_name': 'depth below surface (meters)',
#   'standard_name': 'depth',
#   'positive': 'down'},
#  'latitude': {'epic_key': 'LON_501',
#   'name': 'latitude',
#   'generic_name': 'latitude',
#   'units': 'degrees_north',
#   'long_name': 'latitude',
#   'standard_name': 'latitude'},
#  'longitude': {'epic_key': 'LAT_500',
#   'name': 'longitude',
#   'generic_name': 'longitude',
#   'units': 'degrees_east',
#   'long_name': 'longitude',
#   'standard_name': 'longitude'},
#  'temperature_ch1': {'epic_key': 'T_28',
#   'generic_name': 'temp channel 1',
#   'long_name': 'Sea temperature in-situ ITS-90 scale',
#   'standard_name': 'sea_water_temperature',
#   'units': 'degree_C'},
#  'temperature_ch2': {'epic_key': 'T2_35',
#   'generic_name': 'temp channel 2',
#   'long_name': 'Sea temperature in-situ ITS-90 scale',
#   'standard_name': 'sea_water_temperature',
#   'units': 'degree_C'},
#  'pressure': {'epic_key': 'P_1',
#   'generic_name': 'pres',
#   'units': 'decibar',
#   'long_name': 'Sea water pressure, equals 0 at sea-level',
#   'standard_name': 'sea_water_pressure_due_to_sea_water'},
#  'salinity_ch1': {'epic_key': 'S_41',
#   'generic_name': 'psal channel 1',
#   'units': 'PSU',
#   'long_name': 'Practical salinity in-situ PSS-78 scale',
#   'standard_name': 'sea_water_practical_salinity'},
#  'salinity_ch2': {'epic_key': 'S_42',
#   'generic_name': 'psal channel 2',
#   'units': 'PSU',
#   'long_name': 'Practical salinity in-situ PSS-78 scale',
#   'standard_name': 'sea_water_practical_salinity'},
#  'chlor_fluorescence': {'epic_key': 'F_903',
#   'generic_name': 'chlor_fluorescence',
#   'long_name': 'Mass Concdentration of chlorophyll from chlorophyll fluorescence',
#   'standard_name': 'mass_concentration_of_chlorophyll_in_sea_water',
#   'units': 'ugrams/l'},
#  'turbidity': {'epic_key': 'Trb_980',
#   'generic_name': 'Turbidity',
#   'long_name': 'Turbidity of ocean water in Nephlometric Turbidity Units',
#   'standard_name': 'sea_water_turbidity',
#   'units': 'NTU'},
#  'par': {'generic_name': 'par',
#   'epic_key': 'PAR_905',
#   'long_name': 'Photosynthetic Active Radiation',
#   'standard_name': 'omnidirectional_photosynthetic_photon_spherical_irradiance_in_sea_water',
#   'units': 'uEin cm-2 s-1',
#   'comments': 'satlantic log-PAR'},
#  'oxy_conc_ch1': {'generic_name': 'oxy_conc channel 1',
#   'epic_key': 'O_65',
#   'long_name': 'concentration of oxygen in seawater',
#   'standard_name': 'mole_concentration_of_dissolved_molecular_oxygen_in_sea_water',
#   'units': 'micromole/kg'},
#  'oxy_conc_ch2': {'generic_name': 'oxy_conc channel 2',
#   'epic_key': 'CTDOXY_4221',
#   'long_name': 'concentration of oxygen in seawater',
#   'standard_name': 'mole_concentration_of_dissolved_molecular_oxygen_in_sea_water',
#   'units': 'micromole/kg'},
#  'oxy_concM_ch1': {'generic_name': 'oxy_concM channel 1',
#   'epic_key': 'O_65',
#   'long_name': 'concentration of oxygen in seawater',
#   'standard_name': 'mole_concentration_of_dissolved_molecular_oxygen_in_sea_water',
#   'units': 'ml/l'},
#  'oxy_concM_ch2': {'generic_name': 'oxy_concM channel 2',
#   'epic_key': 'O_2060',
#   'long_name': 'concentration of oxygen in seawater',
#   'standard_name': 'mole_concentration_of_dissolved_molecular_oxygen_in_sea_water',
#   'units': 'ml/l'},
#  'oxy_percentsat_ch1': {'generic_name': 'oxy_psat channel 1',
#   'epic_key': 'OST_62',
#   'units': 'percent',
#   'long_name': 'Percent Saturation of oxygen over air',
#   'standard_name': 'fractional_saturation_of_oxygen_in_sea_water'},
#  'oxy_percentsat_ch2': {'generic_name': 'oxy_psat channel 2',
#   'epic_key': 'CTDOST_4220',
#   'units': 'percent',
#   'long_name': 'Percent Saturation of oxygen over air',
#   'standard_name': 'fractional_saturation_of_oxygen_in_sea_water'}}

# %%
cruise_config['CTDCasts']['CTD004']
# Out:
# {'id': 54818,
#  'Vessel': 'NorthWest Explorer',
#  'CruiseID': 'NW2401',
#  'Project_Leg': '',
#  'UniqueCruiseID': 'NW2401',
#  'Project': 'NBS',
#  'StationNo_altname': '4',
#  'ConsecutiveCastNo': 'CTD004',
#  'LatitudeDeg': 59,
#  'LatitudeMin': 59.916,
#  'LongitudeDeg': 170,
#  'LongitudeMin': 59.796,
#  'GMTDay': 3,
#  'GMTMonth': 'Sep',
#  'GMTYear': 2024,
#  'GMTTime': 58009,
#  'DryBulb': -99.9,
#  'RelativeHumidity': -999,
#  'WetBulb': -99.9,
#  'Pressure': '',
#  'SeaState': '',
#  'Visibility': '',
#  'WindDir': -999,
#  'WindSpd': -99.9,
#  'CloudAmt': '',
#  'CloudType': '',
#  'Weather': '',
#  'SurfaceTemp': -99.9,
#  'BottomDepth': 67,
#  'StationNameID': '60-171',
#  'MaxDepth': -9999,
#  'InstrumentSerialNos': '',
#  'Notes': '40m Niskin did not fire, very rough weather, not enough 10m water for eDNA. Secondary conductivity sensor not working',
#  'NutrientBtlNiskinNo': '',
#  'NutrientBtlNumbers': '',
#  'OxygenBtlNiskinNo': '',
#  'OxygenBtlNumbers': '',
#  'SalinityBtlNiskinNo': '',
#  'SalinityBtlNumbers': '',
#  'ChlorophyllBtlNiskinNo': '',
#  'ChlorophyllBtlVolumes': '',
#  'InstrumentType': 'SBE911plus',
#  'WaterMassCode': '',
#  'isMooringProfileCast': 'n',
#  'MooringID': '',
#  'QualityControlled': 'n',
#  'FileName': ''}

# %%
cruise_data['ctd001.cnv'].columns
# Out:
# Index(['c0mS/cm', 'c1mS/cm', 'flECO-AFL', 'sbeox0V', 'sbeox1V', 't090C',
#        't190C', 'turbWETntu0', 'par', 'sal00', 'sal11', 'sbeox0Mg/L',
#        'sbeox0PS', 'sbox0Mm/Kg', 'sbeox1Mg/L', 'sbeox1PS', 'sbox1Mm/Kg',
#        'sigma-t00', 'sigma-t11', 'nbin', 'flag'],
#       dtype='object')

# %%
for cast in cruise_data.keys():
    print(f'Processing Cast {cast}')
    try:
        #output cruise cast stats here
        #cruise_data[cast].describe()
        #cruise_data['ctd001.cnv'].hist() - seaborn may have a better summary plot than just a bunch of histograms
        #sns.pairplot(cruise_data[cast])

        cruise_data[cast] = cruise_data[cast].rename(columns={
                            't090C':'temperature_ch1',
                            't190C':'temperature_ch2',
                            'sal00':'salinity_ch1',
                            'sal11':'salinity_ch2',
                            'sbox0Mm/Kg':'oxy_conc_ch1',
                            'sbeox0ML/L':'oxy_concM_ch1',
                            'sbeox0PS':'oxy_percentsat_ch1',
                            'sbox1Mm/Kg':'oxy_conc_ch2',
                            'sbeox1ML/L':'oxy_concM_ch2',
                            'sbeox1PS':'oxy_percentsat_ch2',
                            'sigma-t00':'sigma_t_ch1',
                            'sigma-t11':'sigma_t_ch2',
                            'flECO-AFL':'chlor_fluorescence',
                            'turbWETntu0':'turbidity',
                            'cstarat0':'Attenuation',
                            'cstartr0':'Transmittance',
                            'par':'par',
                            'empty':'empty', #this will be ignored
                            'flag':'flag'})

        cruise_data[cast].index.rename('depth',inplace=True)
        #cruise_data[cast].sample()

        cruise_data_nc = ncCFsave.EcoFOCI_CFnc(df=cruise_data[cast], 
                                    instrument_yaml=inst_config, 
                                    operation_yaml=cruise_config,
                                    operation_type='ctd')
        cruise_data_nc.expand_dimensions(dim_names=['latitude','longitude','time'],geophys_sort=False)
        cruise_data_nc.variable_meta_data(variable_keys=list(cruise_data[cast].columns.values),drop_missing=True)
        cruise_data_nc.dimension_meta_data(variable_keys=['depth','latitude','longitude'])
        cruise_data_nc.temporal_geospatioal_meta_data_ctd(positiveE=False,conscastno=cast.split('.')[0])

        cruise_data_nc.var_qcflag_init(dim_names=['depth','latitude','longitude','time'])

        #interp to sfc for list of vars
        try:
            cruise_data_nc.interp2sfc(novars=['par'])
        except:
            pass

        #add global attributes
        cruise_data_nc.deployment_meta_add(conscastno=cast.upper().split('.')[0])
        cruise_data_nc.get_xdf()

        #add instituitonal global attributes
        cruise_data_nc.institution_meta_add(group_config)

        #add creation date/time - provenance data
        cruise_data_nc.provinance_meta_add()

        #provide intial qc status field
        cruise_data_nc.qc_status(qc_status='unknown')

        cast_label = cast.split('.')[0].split('d')[-1]
        cruise_data_nc.xarray2netcdf_save(xdf = cruise_data_nc.get_xdf(),
                                filename=sample_data_dir+cruise_name+'c'+cast_label.zfill(3)+'_ctd.nc',format="NETCDF3_CLASSIC")
        #generate editable csv files
        to_edit = True
        if to_edit:
            if not cast[0] in ['d','u']: #dont save editable up and downcast files, just nc files for plotting... all u/d files can be removed after final data
                cruise_data_nc.get_xdf().to_dataframe().to_csv(sample_data_dir+cruise_name+'c'+cast_label.zfill(3)+'_ctd.to_edit.csv')  
        
    except:
       print('Conversion Failed')
# Out:
# Processing Cast ctd001.cnv
# Processing Cast ctd002.cnv
# Processing Cast ctd003.cnv
# Processing Cast ctd004.cnv
# Processing Cast ctd005.cnv
# Processing Cast ctd006.cnv
# Processing Cast ctd007.cnv
# Processing Cast ctd008.cnv
# Processing Cast ctd009.cnv
# Processing Cast ctd010.cnv
# Processing Cast ctd011.cnv
# Processing Cast ctd012.cnv
# Processing Cast ctd013.cnv
# Processing Cast ctd014.cnv
# Processing Cast ctd015.cnv
# Processing Cast ctd016.cnv
# Processing Cast ctd017.cnv
# Processing Cast ctd018.cnv
# Processing Cast ctd019.cnv
# Conversion Failed
# Processing Cast ctd020.cnv
# Processing Cast ctd021.cnv
# Processing Cast ctd022.cnv
# Processing Cast ctd023.cnv
# Processing Cast ctd024.cnv
# Processing Cast ctd025.cnv
# Processing Cast ctd026.cnv
# Processing Cast ctd027.cnv
# Processing Cast ctd028.cnv
# Processing Cast ctd029.cnv
# Processing Cast ctd030.cnv
# Processing Cast ctd031.cnv
# Conversion Failed
# Processing Cast ctd032.cnv
# Processing Cast ctd033.cnv
# Processing Cast ctd034.cnv
# Processing Cast ctd035.cnv
# Processing Cast ctd036.cnv
# Processing Cast ctd037.cnv
# Processing Cast ctd038.cnv
# Processing Cast ctd039.cnv
# Processing Cast ctd040.cnv
# Processing Cast ctd041.cnv
# Processing Cast ctd042.cnv
# Processing Cast ctd043.cnv
# Conversion Failed
# Processing Cast ctd044.cnv
# Processing Cast ctd045.cnv

# %% [markdown]
# ## QC Next Steps

# %%
import EcoFOCIpy.plots.sbe_ctd_plots as sbe_ctd_plots
import os
import xarray as xa
import seaborn as sns
import numpy as np

# %%
sample_data_dir = '/Users/bell/ecoraid/2024/CTDcasts/nw2401/working/' #root path to cruise directory working repo

# %% [markdown]
# ### QC of data (plot parameters with other instruments)
# - be sure to updated the qc_status for the file and the history for future steps
# - from NRT csv files... make edits then use that to modify netcdf?
# - **Better Yet** export netcdf files with variable flags to csv and edit then reingest and modify
#     - modify netcdf in place and provide a qcflag?
#
#
# ### Likely first edits
# - research issues noted in cruise logs
# - remove failed instrument (clogs, or other challenges that arent correctable)
# - extrapolate to sfc (not par though)
# - despike depths (interpolate between depths)
# - check for common issues
#     - lags in salinity when going through interface

# %%
#test for salinity bottle run needs
for cast in sorted(os.listdir(sample_data_dir)):
    if cast.endswith('.nc'):
        try:
            cruise_data_nc = xa.load_dataset(sample_data_dir+cast)
            saldiff = cruise_data_nc.salinity_ch1 - cruise_data_nc.salinity_ch2
            print(f"{cast}: Profile Averaged Salinity Difference,STD (chan1-chan2){saldiff.mean().values},{saldiff.std().values}")        
            saldiff.plot.hist(bins=50,xlim=[-.005,.005])
        except:
            print(f"{cast}: less than two salinity channels")
# Out:
# NW2401c001_ctd.nc: Profile Averaged Salinity Difference,STD (chan1-chan2)3.0174545454545454,0.2606478811229505
# NW2401c002_ctd.nc: Profile Averaged Salinity Difference,STD (chan1-chan2)0.12567222222222224,0.04123028559951096
# NW2401c003_ctd.nc: Profile Averaged Salinity Difference,STD (chan1-chan2)-0.6748384615384613,0.6627263663063612
# NW2401c004_ctd.nc: Profile Averaged Salinity Difference,STD (chan1-chan2)-0.6096806451612902,0.7751682994863862
# NW2401c005_ctd.nc: Profile Averaged Salinity Difference,STD (chan1-chan2)-0.7797982758620685,1.3242470776192918
# NW2401c006_ctd.nc: Profile Averaged Salinity Difference,STD (chan1-chan2)-0.0259930232558141,0.10279159859649449
# NW2401c007_ctd.nc: Profile Averaged Salinity Difference,STD (chan1-chan2)0.005876470588234556,0.012450066355210156
# NW2401c008_ctd.nc: Profile Averaged Salinity Difference,STD (chan1-chan2)0.04777391304347736,0.01384671417281872
# NW2401c009_ctd.nc: Profile Averaged Salinity Difference,STD (chan1-chan2)0.9358913043478263,0.1288902563627491
# NW2401c010_ctd.nc: Profile Averaged Salinity Difference,STD (chan1-chan2)0.08093157894736903,0.0028530782326574903
# NW2401c011_ctd.nc: Profile Averaged Salinity Difference,STD (chan1-chan2)0.0063538461538452835,0.007005230505691706
# NW2401c012_ctd.nc: Profile Averaged Salinity Difference,STD (chan1-chan2)0.02635757575757548,0.008737832416290413
# NW2401c013_ctd.nc: Profile Averaged Salinity Difference,STD (chan1-chan2)-0.1751558139534883,0.19657658818978796
# NW2401c014_ctd.nc: Profile Averaged Salinity Difference,STD (chan1-chan2)-1.1329634615384614,1.676364521244714
# NW2401c015_ctd.nc: Profile Averaged Salinity Difference,STD (chan1-chan2)-0.5725872340425531,0.9544084565659979
# NW2401c016_ctd.nc: Profile Averaged Salinity Difference,STD (chan1-chan2)-0.11111627906976741,0.21756901918031682
# NW2401c017_ctd.nc: Profile Averaged Salinity Difference,STD (chan1-chan2)0.006720588235294651,0.035361276422694925
# NW2401c018_ctd.nc: Profile Averaged Salinity Difference,STD (chan1-chan2)0.06586399999999969,0.0032366501201086953
# NW2401c019_ctd.nc: less than two salinity channels
# NW2401c020_ctd.nc: Profile Averaged Salinity Difference,STD (chan1-chan2)0.04747142857142807,0.030514280698233715
# NW2401c021_ctd.nc: Profile Averaged Salinity Difference,STD (chan1-chan2)0.041119230769232226,0.006571384307432636
# NW2401c022_ctd.nc: Profile Averaged Salinity Difference,STD (chan1-chan2)-0.03786666666666624,0.0149676503017532
# NW2401c023_ctd.nc: Profile Averaged Salinity Difference,STD (chan1-chan2)-0.9345627906976742,1.6619681218815094
# NW2401c024_ctd.nc: Profile Averaged Salinity Difference,STD (chan1-chan2)-1.9303104166666667,2.4347601551316087
# NW2401c025_ctd.nc: Profile Averaged Salinity Difference,STD (chan1-chan2)-1.0406285714285717,1.698242095210685
# NW2401c026_ctd.nc: Profile Averaged Salinity Difference,STD (chan1-chan2)-1.3238942857142855,1.2444774049358704
# NW2401c027_ctd.nc: Profile Averaged Salinity Difference,STD (chan1-chan2)-0.2077066666666673,0.13227017787678175
# NW2401c028_ctd.nc: Profile Averaged Salinity Difference,STD (chan1-chan2)-0.03695555555555496,0.026182724490174995
# NW2401c029_ctd.nc: Profile Averaged Salinity Difference,STD (chan1-chan2)0.036508823529411524,0.13425057644228747
# NW2401c030_ctd.nc: Profile Averaged Salinity Difference,STD (chan1-chan2)0.05222916666666692,0.011803829857531199
# NW2401c031_ctd.nc: less than two salinity channels
# NW2401c032_ctd.nc: Profile Averaged Salinity Difference,STD (chan1-chan2)-0.02583200000000005,0.07838117488274852
# NW2401c033_ctd.nc: Profile Averaged Salinity Difference,STD (chan1-chan2)2.120924,0.8366495716989285
# NW2401c034_ctd.nc: Profile Averaged Salinity Difference,STD (chan1-chan2)-0.9382272727272726,0.6207951295657557
# NW2401c035_ctd.nc: Profile Averaged Salinity Difference,STD (chan1-chan2)-0.026534285714285285,0.05072525965775803
# NW2401c036_ctd.nc: Profile Averaged Salinity Difference,STD (chan1-chan2)0.007939393939393738,0.011370081404626848
# NW2401c037_ctd.nc: Profile Averaged Salinity Difference,STD (chan1-chan2)-0.21946428571428683,0.35357838480410614
# NW2401c038_ctd.nc: Profile Averaged Salinity Difference,STD (chan1-chan2)0.031002857142857568,0.004036652482602302
# NW2401c039_ctd.nc: Profile Averaged Salinity Difference,STD (chan1-chan2)2.4667346153846164,1.9274796137687376
# NW2401c040_ctd.nc: Profile Averaged Salinity Difference,STD (chan1-chan2)0.6852080000000005,0.8353462031612997
# NW2401c041_ctd.nc: Profile Averaged Salinity Difference,STD (chan1-chan2)-0.023827272727272857,0.020205088958841988
# NW2401c042_ctd.nc: Profile Averaged Salinity Difference,STD (chan1-chan2)0.04898181818181723,0.001971532943868804
# NW2401c043_ctd.nc: less than two salinity channels
# NW2401c044_ctd.nc: Profile Averaged Salinity Difference,STD (chan1-chan2)1.6593045454545454,1.5590443236679183
# NW2401c045_ctd.nc: Profile Averaged Salinity Difference,STD (chan1-chan2)1.3895650000000006,1.313247447084897

# %%
# Following routines will eventually get ported to ecofocipy as subroutines to be called

import seawater as sw

def sigmat_update(salinity=None,temperature=None):
    '''
    Changes to T or S (commonly to despike values or apply a salinity offset) will need corresponding changes in sigmat
    '''
    # calculate sigmaT at 0db gauge pressure (s, t, p=0)
    sigt = (sw.eos80.dens0(s=salinity, t=temperature) - 1000)
    
    return sigt

# %% [markdown]
# ## Generate Plots
#
#
# ### Make General Plots
# - 1:1 plots for paired instruments for each cast (tells if a sensor failed)
# - TS_Sigmat, Chlor/Par/Turb, Oxy,Temp
# - T/S property property plot
# - upcast/downcast plt

# %%
sample_data_dir+cast
# Out:
# '/Users/bell/ecoraid/2024/CTDcasts/nw2401/working/up_and_down'

# %%
calc_sigmat = True

for cast in sorted(os.listdir(sample_data_dir)):
    if cast.endswith('.nc'):
        cruise_data_nc = xa.load_dataset(sample_data_dir+cast)
        ctd_df = cruise_data_nc.to_dataframe()
        
        if calc_sigmat:
            #update sigmat (or calculate it I suppose)
            sigup = sigmat_update(salinity=ctd_df.salinity_ch1,
                                  temperature=ctd_df.temperature_ch1)
            ctd_df['sigma_t_ch1'] = sigup
            
            sigup2 = sigmat_update(salinity=ctd_df.salinity_ch2,
                                  temperature=ctd_df.temperature_ch2)
            ctd_df['sigma_t_ch2'] = sigup2   
        sbe_p = sbe_ctd_plots.CTDProfilePlot()
        plt,fig =sbe_p.plot3var(varname=['temperature_ch1','temperature_ch2','salinity_ch1','salinity_ch2','sigma_t_ch1','sigma_t_ch2'],
                          xdata=[ctd_df.temperature_ch1,ctd_df.temperature_ch2,ctd_df.salinity_ch1,ctd_df.salinity_ch2,ctd_df.sigma_t_ch1,ctd_df.sigma_t_ch2],
                          ydata=ctd_df.index.get_level_values('depth'),
                          secondary=True,
                          xlabel=['Temperature','Salinity','Sigma-T'])

        DefaultSize = fig.get_size_inches()
        fig.set_size_inches( (DefaultSize[0], DefaultSize[1]*3) )
        plt.savefig(sample_data_dir+cast.replace('.nc','_TempSalSigmat.png'))
        plt.close(fig)

# %%
for cast in sorted(os.listdir(sample_data_dir)):
    if cast.endswith('.nc'):
        cruise_data_nc = xa.load_dataset(sample_data_dir+cast)
        ctd_df = cruise_data_nc.to_dataframe()
        
        sbe_p = sbe_ctd_plots.CTDProfilePlot()
        plt,fig =sbe_p.plot2var(varname=['temperature_ch1','temperature_ch2','oxy_percentsat_ch1','oxy_percentsat_ch2'],
                          xdata=[ctd_df.temperature_ch1,ctd_df.temperature_ch2,ctd_df.oxy_percentsat_ch1,ctd_df.oxy_percentsat_ch2],
                          ydata=ctd_df.index.get_level_values('depth'),
                          secondary=True,
                          xlabel=['Temperature','Oxygen Saturation'])

        DefaultSize = fig.get_size_inches()
        fig.set_size_inches( (DefaultSize[0], DefaultSize[1]*3) )
        plt.savefig(sample_data_dir+cast.replace('.nc','_TempOxy.png'))
        plt.close(fig)

# %%
for cast in sorted(os.listdir(sample_data_dir)):
    if cast.endswith('.nc'):
        cruise_data_nc = xa.load_dataset(sample_data_dir+cast)
        ctd_df = cruise_data_nc.to_dataframe()
        
        sbe_p = sbe_ctd_plots.CTDProfilePlot()
        plt,fig =sbe_p.plot2var(varname=['chlor_fluorescence','','par'],
                          xdata=[ctd_df.chlor_fluorescence,np.array([]),ctd_df.par,np.array([])],
                          ydata=ctd_df.index.get_level_values('depth'),
                          secondary=False,
                          xlabel=['Fluor','Par'])

        DefaultSize = fig.get_size_inches()
        fig.set_size_inches( (DefaultSize[0], DefaultSize[1]*3) )
        plt.savefig(sample_data_dir+cast.replace('.nc','_FluorPAR.png'))
        plt.close(fig)
