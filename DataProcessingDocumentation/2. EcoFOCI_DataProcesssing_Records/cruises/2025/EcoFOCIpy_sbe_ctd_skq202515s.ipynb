# %% [markdown]
# # Using EcoFOCIpy to process raw field data - DY2504
#
# *SY2504 - Ecofoci Spring Mooring Cruise*
#
# **Processed by Shaun Bell**
#
# A duplicate column of Fluorescence shows up
# ## CTD / Profile Data
#
# Basic workflow for each instrument grouping is *(initial archive level)*:
# - SBE workflow must happen first **done (performed on seperate windows system to convert to cnv)**
# - output initial files (pandas->csv) **ERDDAP NRT** when no meta data is added.  Good for quick analysis
#
# Other than hosting on an erddap server, the above can be done at sea
#
# For furthur processing, QC and archiving, the following tasks are to be done *(working or final data level)*:
# - Add metadata from cruise yaml files created from cast logs
# - apply any calibrations or corrections
#     + field corrections
#     + offsets
#     + spike analysis
#     + some QC were available... this would be old-school simple bounds mostly
# - save as CF netcdf via xarray or potentially csv file: so many of the steps above are optional
#     + **ERDDAP NRT** if no corrections, offsets or time bounds are applied but some meta data is (can be csv as this is useful at sea)
#     + **Working and awaiting QC** has no ERDDAP representation and is a holding spot
#     + **ERDDAP Final** fully calibrated, qc'd and populated with meta information
#
# Plot for preview and QC
# - TSSigma, TOXYChlor, TurbParTrans

# %%
import yaml
import glob

import EcoFOCIpy.io.sbe_ctd_parser as sbe_ctd_parser #<- instrument specific
import EcoFOCIpy.io.ncCFsave as ncCFsave
import EcoFOCIpy.metaconfig.load_config as load_config
import EcoFOCIpy.math.geotools as geotools

# %% [markdown]
# ## At Sea NRT Processing

# %%
sample_data_dir = '/Users/bell/ecoraid/2025/CTDcasts/skq202515s/' #root path to cruise directory
ecofocipy_dir = '/Users/bell/Programs/EcoFOCIpy/'

# %%
###############################################################
# edit to point to {cruise sepcific} raw datafiles 
datafile = sample_data_dir+'rawconverted/' #<- point to cruise and process all files within
cruise_name = 'SKQ202515S' #no hyphens
inst_meta_file = sample_data_dir+'logs/FOCI_standard_CTD.yaml'
###############################################################

#init and load data
cruise = sbe_ctd_parser.sbe9_11p()
filename_list = sorted(glob.glob(datafile + '*.cnv'))

(cruise_data,cruise_header) = cruise.parse(filename_list)

# %%
filename_list
# Out:
# ['/Users/bell/ecoraid/2025/CTDcasts/skq202515s/rawconverted/skq202515s_001avg.cnv',
#  '/Users/bell/ecoraid/2025/CTDcasts/skq202515s/rawconverted/skq202515s_002avg.cnv',
#  '/Users/bell/ecoraid/2025/CTDcasts/skq202515s/rawconverted/skq202515s_003avg.cnv',
#  '/Users/bell/ecoraid/2025/CTDcasts/skq202515s/rawconverted/skq202515s_004avg.cnv',
#  '/Users/bell/ecoraid/2025/CTDcasts/skq202515s/rawconverted/skq202515s_005avg.cnv',
#  '/Users/bell/ecoraid/2025/CTDcasts/skq202515s/rawconverted/skq202515s_006avg.cnv',
#  '/Users/bell/ecoraid/2025/CTDcasts/skq202515s/rawconverted/skq202515s_007avg.cnv',
#  '/Users/bell/ecoraid/2025/CTDcasts/skq202515s/rawconverted/skq202515s_008avg.cnv',
#  '/Users/bell/ecoraid/2025/CTDcasts/skq202515s/rawconverted/skq202515s_009avg.cnv',
#  '/Users/bell/ecoraid/2025/CTDcasts/skq202515s/rawconverted/skq202515s_010avg.cnv',
#  '/Users/bell/ecoraid/2025/CTDcasts/skq202515s/rawconverted/skq202515s_011avg.cnv',
#  '/Users/bell/ecoraid/2025/CTDcasts/skq202515s/rawconverted/skq202515s_012avg.cnv',
#  '/Users/bell/ecoraid/2025/CTDcasts/skq202515s/rawconverted/skq202515s_013avg.cnv',
#  '/Users/bell/ecoraid/2025/CTDcasts/skq202515s/rawconverted/skq202515s_014avg.cnv',
#  '/Users/bell/ecoraid/2025/CTDcasts/skq202515s/rawconverted/skq202515s_015avg.cnv',
#  '/Users/bell/ecoraid/2025/CTDcasts/skq202515s/rawconverted/skq202515s_016avg.cnv',
#  '/Users/bell/ecoraid/2025/CTDcasts/skq202515s/rawconverted/skq202515s_017avg.cnv',
#  '/Users/bell/ecoraid/2025/CTDcasts/skq202515s/rawconverted/skq202515s_018avg.cnv',
#  '/Users/bell/ecoraid/2025/CTDcasts/skq202515s/rawconverted/skq202515s_019avg.cnv',
#  '/Users/bell/ecoraid/2025/CTDcasts/skq202515s/rawconverted/skq202515s_020avg.cnv',
#  '/Users/bell/ecoraid/2025/CTDcasts/skq202515s/rawconverted/skq202515s_021avg.cnv',
#  '/Users/bell/ecoraid/2025/CTDcasts/skq202515s/rawconverted/skq202515s_022avg.cnv',
#  '/Users/bell/ecoraid/2025/CTDcasts/skq202515s/rawconverted/skq202515s_023avg.cnv',
#  '/Users/bell/ecoraid/2025/CTDcasts/skq202515s/rawconverted/skq202515s_024avg.cnv',
#  '/Users/bell/ecoraid/2025/CTDcasts/skq202515s/rawconverted/skq202515s_025avg.cnv',
#  '/Users/bell/ecoraid/2025/CTDcasts/skq202515s/rawconverted/skq202515s_026avg.cnv',
#  '/Users/bell/ecoraid/2025/CTDcasts/skq202515s/rawconverted/skq202515s_027avg.cnv',
#  '/Users/bell/ecoraid/2025/CTDcasts/skq202515s/rawconverted/skq202515s_028avg.cnv',
#  '/Users/bell/ecoraid/2025/CTDcasts/skq202515s/rawconverted/skq202515s_029avg.cnv',
#  '/Users/bell/ecoraid/2025/CTDcasts/skq202515s/rawconverted/skq202515s_030avg.cnv',
#  '/Users/bell/ecoraid/2025/CTDcasts/skq202515s/rawconverted/skq202515s_031avg.cnv',
#  '/Users/bell/ecoraid/2025/CTDcasts/skq202515s/rawconverted/skq202515s_032avg.cnv',
#  '/Users/bell/ecoraid/2025/CTDcasts/skq202515s/rawconverted/skq202515s_033avg.cnv',
#  '/Users/bell/ecoraid/2025/CTDcasts/skq202515s/rawconverted/skq202515s_034avg.cnv',
#  '/Users/bell/ecoraid/2025/CTDcasts/skq202515s/rawconverted/skq202515s_035avg.cnv',
#  '/Users/bell/ecoraid/2025/CTDcasts/skq202515s/rawconverted/skq202515s_036avg.cnv',
#  '/Users/bell/ecoraid/2025/CTDcasts/skq202515s/rawconverted/skq202515s_037avg.cnv',
#  '/Users/bell/ecoraid/2025/CTDcasts/skq202515s/rawconverted/skq202515s_038avg.cnv',
#  '/Users/bell/ecoraid/2025/CTDcasts/skq202515s/rawconverted/skq202515s_039avg.cnv',
#  '/Users/bell/ecoraid/2025/CTDcasts/skq202515s/rawconverted/skq202515s_040avg.cnv',
#  '/Users/bell/ecoraid/2025/CTDcasts/skq202515s/rawconverted/skq202515s_041avg.cnv',
#  '/Users/bell/ecoraid/2025/CTDcasts/skq202515s/rawconverted/skq202515s_042avg.cnv',
#  '/Users/bell/ecoraid/2025/CTDcasts/skq202515s/rawconverted/skq202515s_043avg.cnv',
#  '/Users/bell/ecoraid/2025/CTDcasts/skq202515s/rawconverted/skq202515s_044avg.cnv',
#  '/Users/bell/ecoraid/2025/CTDcasts/skq202515s/rawconverted/skq202515s_045avg.cnv',
#  '/Users/bell/ecoraid/2025/CTDcasts/skq202515s/rawconverted/skq202515s_046avg.cnv',
#  '/Users/bell/ecoraid/2025/CTDcasts/skq202515s/rawconverted/skq202515s_047avg.cnv',
#  '/Users/bell/ecoraid/2025/CTDcasts/skq202515s/rawconverted/skq202515s_048avg.cnv',
#  '/Users/bell/ecoraid/2025/CTDcasts/skq202515s/rawconverted/skq202515s_049avg.cnv',
#  '/Users/bell/ecoraid/2025/CTDcasts/skq202515s/rawconverted/skq202515s_050avg.cnv',
#  '/Users/bell/ecoraid/2025/CTDcasts/skq202515s/rawconverted/skq202515s_051avg.cnv',
#  '/Users/bell/ecoraid/2025/CTDcasts/skq202515s/rawconverted/skq202515s_052avg.cnv',
#  '/Users/bell/ecoraid/2025/CTDcasts/skq202515s/rawconverted/skq202515s_053avg.cnv',
#  '/Users/bell/ecoraid/2025/CTDcasts/skq202515s/rawconverted/skq202515s_054avg.cnv',
#  '/Users/bell/ecoraid/2025/CTDcasts/skq202515s/rawconverted/skq202515s_055avg.cnv',
#  '/Users/bell/ecoraid/2025/CTDcasts/skq202515s/rawconverted/skq202515s_056avg.cnv',
#  '/Users/bell/ecoraid/2025/CTDcasts/skq202515s/rawconverted/skq202515s_057avg.cnv',
#  '/Users/bell/ecoraid/2025/CTDcasts/skq202515s/rawconverted/skq202515s_058avg.cnv',
#  '/Users/bell/ecoraid/2025/CTDcasts/skq202515s/rawconverted/skq202515s_059avg.cnv',
#  '/Users/bell/ecoraid/2025/CTDcasts/skq202515s/rawconverted/skq202515s_060avg.cnv',
#  '/Users/bell/ecoraid/2025/CTDcasts/skq202515s/rawconverted/skq202515s_061avg.cnv',
#  '/Users/bell/ecoraid/2025/CTDcasts/skq202515s/rawconverted/skq202515s_062avg.cnv',
#  '/Users/bell/ecoraid/2025/CTDcasts/skq202515s/rawconverted/skq202515s_063avg.cnv',
#  '/Users/bell/ecoraid/2025/CTDcasts/skq202515s/rawconverted/skq202515s_064avg.cnv',
#  '/Users/bell/ecoraid/2025/CTDcasts/skq202515s/rawconverted/skq202515s_065avg.cnv',
#  '/Users/bell/ecoraid/2025/CTDcasts/skq202515s/rawconverted/skq202515s_066avg.cnv',
#  '/Users/bell/ecoraid/2025/CTDcasts/skq202515s/rawconverted/skq202515s_067avg.cnv',
#  '/Users/bell/ecoraid/2025/CTDcasts/skq202515s/rawconverted/skq202515s_068avg.cnv',
#  '/Users/bell/ecoraid/2025/CTDcasts/skq202515s/rawconverted/skq202515s_069avg.cnv',
#  '/Users/bell/ecoraid/2025/CTDcasts/skq202515s/rawconverted/skq202515s_070avg.cnv',
#  '/Users/bell/ecoraid/2025/CTDcasts/skq202515s/rawconverted/skq202515s_071avg.cnv',
#  '/Users/bell/ecoraid/2025/CTDcasts/skq202515s/rawconverted/skq202515s_072avg.cnv']

# %%
cruise_header
# Out:
# {'skq202515s_001avg.cnv': {'header': ['* Sea-Bird SBE 9 Data File:\n',
#    '* FileName = D:\\CTD\\SKQ202515S\\raw\\SKQ202515S_001.hex\n',
#    '* Software Version Seasave V 7.26.7.121\n',
#    '* Temperature SN = 5774\n',
#    '* Conductivity SN = 4367\n',
#    '* Number of Bytes Per Scan = 45\n',
#    '* Number of Voltage Words = 4\n',
#    '* Number of Scans Averaged by the Deck Unit = 1\n',
#    '* Append System Time to Every Scan\n',
#    '* System UpLoad Time = Aug 13 2025 19:17:24\n',
#    '* NMEA Latitude = 63 36.19 N\n',
#    '* NMEA Longitude = 172 35.54 W\n',
#    '* NMEA UTC (Time) = Aug 13 2025  19:13:47\n',
#    '* Store Lat/Lon Data = Append to Every Scan\n',
#    '* SBE 11plus V 5.1b\n',
#    '* number of scans to average = 1\n',
#    '* pressure baud rate = 9600\n',
#    '* NMEA baud rate = 4800\n',
#    '* GPIB address = 1\n',
#    '* advance primary conductivity  0.073 seconds\n',
#    '* advance secondary conductivity  0.073 seconds\n',
#    '* S>\n',
#    '** Ship: R/V Sikuliaq\n',
#    '** Station Number: 001\n',
#    '** Station Name: DBO 1.10\n',
#    '** Bottom Depth [m]: 54\n',
#    '** Operator: PS\n',
#    '* System UTC = Aug 13 2025 19:17:24\n',
#    '# nquan = 23\n',
#    '# nvalues = 47                          \n',
#    '# units = specified\n',
#    '# name 0 = depSM: Depth [salt water, m]\n',
#    '# name 1 = latitude: Latitude [deg]\n',
#    '# name 2 = longitude: Longitude [deg]\n',
#    '# name 3 = prDM: Pressure, Digiquartz [db]\n',
#    '# name 4 = t090C: Temperature [ITS-90, deg C]\n',
#    '# name 5 = t190C: Temperature, 2 [ITS-90, deg C]\n',
#    '# name 6 = potemp090C: Potential Temperature [ITS-90, deg C]\n',
#    '# name 7 = sal00: Salinity, Practical [PSU]\n',
#    '# name 8 = sal11: Salinity, Practical, 2 [PSU]\n',
#    '# name 9 = density00: Density [density, kg/m^3]\n',
#    '# name 10 = sigma-00: Density [sigma-theta, kg/m^3]\n',
#    '# name 11 = sbox0Mm/Kg: Oxygen, SBE 43 [umol/kg]\n',
#    '# name 12 = oxsolMm/Kg: Oxygen Saturation, Garcia & Gordon [umol/kg]\n',
#    '# name 13 = sbeox0PS: Oxygen, SBE 43 [% saturation]\n',
#    '# name 14 = v0: Voltage 0\n',
#    '# name 15 = flECO-AFL: Fluorescence, WET Labs ECO-AFL/FL [mg/m^3]\n',
#    '# name 16 = v1: Voltage 1\n',
#    '# name 17 = CStarAt0: Beam Attenuation, WET Labs C-Star [1/m]\n',
#    '# name 18 = par: PAR/Irradiance, Biospherical/Licor\n',
#    '# name 19 = scan: Scan Count\n',
#    '# name 20 = timeM: Time, Elapsed [minutes]\n',
#    '# name 21 = nbin: number of scans per bin\n',
#    '# name 22 = flag: flag\n',
#    '# span 0 =      2.971,     48.519       \n',
#    '# span 1 =   63.60356,   63.60415       \n',
#    '# span 2 = -172.59274, -172.59271       \n',
#    '# span 3 =      3.000,     49.000       \n',
#    '# span 4 =    -0.8024,     9.4057       \n',
#    '# span 5 =    -0.8021,     9.4036       \n',
#    '# span 6 =    -0.8035,     9.4053       \n',
#    '# span 7 =    31.0118,    31.9935       \n',
#    '# span 8 =    31.0096,    31.9950       \n',
#    '# span 9 =  1023.9500,  1025.9464       \n',
#    '# span 10 =    23.9344,    25.7107      \n',
#    '# span 11 =    274.938,    376.261      \n',
#    '# span 12 =  286.27676,  364.13336      \n',
#    '# span 13 =     81.624,    108.179      \n',
#    '# span 14 =     0.0841,     0.3810      \n',
#    '# span 15 =     0.1294,     1.9111      \n',
#    '# span 16 =     0.1205,     0.5307      \n',
#    '# span 17 =     0.1694,     1.5627      \n',
#    '# span 18 = 9.5479e-02, 3.0265e+02      \n',
#    '# span 19 =        294,       5738      \n',
#    '# span 20 =     0.2036,     3.9839      \n',
#    '# span 21 =         29,       1206      \n',
#    '# span 22 = 0.0000e+00, 0.0000e+00      \n',
#    '# interval = decibars: 1                \n',
#    '# start_time = Aug 13 2025 19:17:22 [NMEA time, first data scan]\n',
#    '# bad_flag = -9.990e-29\n',
#    '# <Sensors count="13" >\n',
#    '#   <sensor Channel="1" >\n',
#    '#     <!-- Frequency 0, Temperature -->\n',
#    '#     <TemperatureSensor SensorID="55" >\n',
#    '#       <SerialNumber>5774</SerialNumber>\n',
#    '#       <CalibrationDate>03-Aug-24</CalibrationDate>\n',
#    '#       <UseG_J>1</UseG_J>\n',
#    '#       <A>0.00000000e+000</A>\n',
#    '#       <B>0.00000000e+000</B>\n',
#    '#       <C>0.00000000e+000</C>\n',
#    '#       <D>0.00000000e+000</D>\n',
#    '#       <F0_Old>0.000</F0_Old>\n',
#    '#       <G>4.33671890e-003</G>\n',
#    '#       <H>6.27175804e-004</H>\n',
#    '#       <I>1.94622760e-005</I>\n',
#    '#       <J>1.44648852e-006</J>\n',
#    '#       <F0>1000.000</F0>\n',
#    '#       <Slope>1.00000000</Slope>\n',
#    '#       <Offset>0.0000</Offset>\n',
#    '#     </TemperatureSensor>\n',
#    '#   </sensor>\n',
#    '#   <sensor Channel="2" >\n',
#    '#     <!-- Frequency 1, Conductivity -->\n',
#    '#     <ConductivitySensor SensorID="3" >\n',
#    '#       <SerialNumber>4367</SerialNumber>\n',
#    '#       <CalibrationDate>23-Jul-24</CalibrationDate>\n',
#    '#       <UseG_J>1</UseG_J>\n',
#    '#       <!-- Cell const and series R are applicable only for wide range sensors. -->\n',
#    '#       <SeriesR>0.0000</SeriesR>\n',
#    '#       <CellConst>2000.0000</CellConst>\n',
#    '#       <ConductivityType>0</ConductivityType>\n',
#    '#       <Coefficients equation="0" >\n',
#    '#         <A>0.00000000e+000</A>\n',
#    '#         <B>0.00000000e+000</B>\n',
#    '#         <C>0.00000000e+000</C>\n',
#    '#         <D>0.00000000e+000</D>\n',
#    '#         <M>0.0</M>\n',
#    '#         <CPcor>-9.57000000e-008</CPcor>\n',
#    '#       </Coefficients>\n',
#    '#       <Coefficients equation="1" >\n',
#    '#         <G>-9.81062403e+000</G>\n',
#    '#         <H>1.39213135e+000</H>\n',
#    '#         <I>-9.20358449e-004</I>\n',
#    '#         <J>1.39392598e-004</J>\n',
#    '#         <CPcor>-9.57000000e-008</CPcor>\n',
#    '#         <CTcor>3.2500e-006</CTcor>\n',
#    '#         <!-- WBOTC not applicable unless ConductivityType = 1. -->\n',
#    '#         <WBOTC>0.00000000e+000</WBOTC>\n',
#    '#       </Coefficients>\n',
#    '#       <Slope>1.00000000</Slope>\n',
#    '#       <Offset>0.00000</Offset>\n',
#    '#     </ConductivitySensor>\n',
#    '#   </sensor>\n',
#    '#   <sensor Channel="3" >\n',
#    '#     <!-- Frequency 2, Pressure, Digiquartz with TC -->\n',
#    '#     <PressureSensor SensorID="45" >\n',
#    '#       <SerialNumber>1213</SerialNumber>\n',
#    '#       <CalibrationDate>13-Mar-20</CalibrationDate>\n',
#    '#       <C1>-4.132681e+004</C1>\n',
#    '#       <C2>-4.458463e-001</C2>\n',
#    '#       <C3>1.331500e-002</C3>\n',
#    '#       <D1>3.488900e-002</D1>\n',
#    '#       <D2>0.000000e+000</D2>\n',
#    '#       <T1>3.032126e+001</T1>\n',
#    '#       <T2>-4.098790e-004</T2>\n',
#    '#       <T3>3.967810e-006</T3>\n',
#    '#       <T4>3.643750e-009</T4>\n',
#    '#       <Slope>0.99999533</Slope>\n',
#    '#       <Offset>-4.33223</Offset>\n',
#    '#       <T5>0.000000e+000</T5>\n',
#    '#       <AD590M>1.280410e-002</AD590M>\n',
#    '#       <AD590B>-9.260115e+000</AD590B>\n',
#    '#     </PressureSensor>\n',
#    '#   </sensor>\n',
#    '#   <sensor Channel="4" >\n',
#    '#     <!-- Frequency 3, Temperature, 2 -->\n',
#    '#     <TemperatureSensor SensorID="55" >\n',
#    '#       <SerialNumber>5773</SerialNumber>\n',
#    '#       <CalibrationDate>06-Aug-24</CalibrationDate>\n',
#    '#       <UseG_J>1</UseG_J>\n',
#    '#       <A>0.00000000e+000</A>\n',
#    '#       <B>0.00000000e+000</B>\n',
#    '#       <C>0.00000000e+000</C>\n',
#    '#       <D>0.00000000e+000</D>\n',
#    '#       <F0_Old>0.000</F0_Old>\n',
#    '#       <G>4.35221970e-003</G>\n',
#    '#       <H>6.29797751e-004</H>\n',
#    '#       <I>1.98679905e-005</I>\n',
#    '#       <J>1.48010526e-006</J>\n',
#    '#       <F0>1000.000</F0>\n',
#    '#       <Slope>1.00000000</Slope>\n',
#    '#       <Offset>0.0000</Offset>\n',
#    '#     </TemperatureSensor>\n',
#    '#   </sensor>\n',
#    '#   <sensor Channel="5" >\n',
#    '#     <!-- Frequency 4, Conductivity, 2 -->\n',
#    '#     <ConductivitySensor SensorID="3" >\n',
#    '#       <SerialNumber>2251</SerialNumber>\n',
#    '#       <CalibrationDate>07-Feb-23</CalibrationDate>\n',
#    '#       <UseG_J>1</UseG_J>\n',
#    '#       <!-- Cell const and series R are applicable only for wide range sensors. -->\n',
#    '#       <SeriesR>0.0000</SeriesR>\n',
#    '#       <CellConst>2000.0000</CellConst>\n',
#    '#       <ConductivityType>0</ConductivityType>\n',
#    '#       <Coefficients equation="0" >\n',
#    '#         <A>0.00000000e+000</A>\n',
#    '#         <B>0.00000000e+000</B>\n',
#    '#         <C>0.00000000e+000</C>\n',
#    '#         <D>0.00000000e+000</D>\n',
#    '#         <M>0.0</M>\n',
#    '#         <CPcor>-9.57000000e-008</CPcor>\n',
#    '#       </Coefficients>\n',
#    '#       <Coefficients equation="1" >\n',
#    '#         <G>-1.01223445e+001</G>\n',
#    '#         <H>1.33362873e+000</H>\n',
#    '#         <I>-2.37166394e-003</I>\n',
#    '#         <J>2.25323667e-004</J>\n',
#    '#         <CPcor>-9.57000000e-008</CPcor>\n',
#    '#         <CTcor>3.2500e-006</CTcor>\n',
#    '#         <!-- WBOTC not applicable unless ConductivityType = 1. -->\n',
#    '#         <WBOTC>0.00000000e+000</WBOTC>\n',
#    '#       </Coefficients>\n',
#    '#       <Slope>1.00000000</Slope>\n',
#    '#       <Offset>0.00000</Offset>\n',
#    '#     </ConductivitySensor>\n',
#    '#   </sensor>\n',
#    '#   <sensor Channel="6" >\n',
#    '#     <!-- A/D voltage 0, Fluorometer, WET Labs ECO-AFL/FL -->\n',
#    '#     <FluoroWetlabECO_AFL_FL_Sensor SensorID="20" >\n',
#    '#       <SerialNumber>5094</SerialNumber>\n',
#    '#       <CalibrationDate>30-Jul-24</CalibrationDate>\n',
#    '#       <ScaleFactor>6.00000000e+000</ScaleFactor>\n',
#    '#       <!-- Dark output -->\n',
#    '#       <Vblank>0.0625</Vblank>\n',
#    '#     </FluoroWetlabECO_AFL_FL_Sensor>\n',
#    '#   </sensor>\n',
#    '#   <sensor Channel="7" >\n',
#    '#     <!-- A/D voltage 1, Fluorometer, WET Labs ECO-AFL/FL, 2 -->\n',
#    '#     <FluoroWetlabECO_AFL_FL_Sensor SensorID="20" >\n',
#    '#       <SerialNumber>5094</SerialNumber>\n',
#    '#       <CalibrationDate>30-Jul-24</CalibrationDate>\n',
#    '#       <ScaleFactor>2.00000000e+000</ScaleFactor>\n',
#    '#       <!-- Dark output -->\n',
#    '#       <Vblank>0.0684</Vblank>\n',
#    '#     </FluoroWetlabECO_AFL_FL_Sensor>\n',
#    '#   </sensor>\n',
#    '#   <sensor Channel="8" >\n',
#    '#     <!-- A/D voltage 2, PAR/Irradiance, Biospherical/Licor -->\n',
#    '#     <PAR_BiosphericalLicorChelseaSensor SensorID="42" >\n',
#    '#       <SerialNumber>70778</SerialNumber>\n',
#    '#       <CalibrationDate>12-Mar-2025</CalibrationDate>\n',
#    '#       <M>1.00000000</M>\n',
#    '#       <B>0.00000000</B>\n',
#    '#       <CalibrationConstant>10989010989.01100000</CalibrationConstant>\n',
#    '#       <Multiplier>1.00000000</Multiplier>\n',
#    '#       <Offset>-0.09163078</Offset>\n',
#    '#     </PAR_BiosphericalLicorChelseaSensor>\n',
#    '#   </sensor>\n',
#    '#   <sensor Channel="9" >\n',
#    '#     <!-- A/D voltage 3, Altimeter -->\n',
#    '#     <AltimeterSensor SensorID="0" >\n',
#    '#       <SerialNumber>302492</SerialNumber>\n',
#    '#       <CalibrationDate>19-Sep-13</CalibrationDate>\n',
#    '#       <ScaleFactor>15.000</ScaleFactor>\n',
#    '#       <Offset>0.000</Offset>\n',
#    '#     </AltimeterSensor>\n',
#    '#   </sensor>\n',
#    '#   <sensor Channel="10" >\n',
#    '#     <!-- A/D voltage 4, Oxygen, SBE 43 -->\n',
#    '#     <OxygenSensor SensorID="38" >\n',
#    '#       <SerialNumber>3704</SerialNumber>\n',
#    '#       <CalibrationDate>12-Mar-25</CalibrationDate>\n',
#    '#       <Use2007Equation>1</Use2007Equation>\n',
#    '#       <CalibrationCoefficients equation="0" >\n',
#    '#         <!-- Coefficients for Owens-Millard equation. -->\n',
#    '#         <Boc>0.0000</Boc>\n',
#    '#         <Soc>0.0000e+000</Soc>\n',
#    '#         <offset>0.0000</offset>\n',
#    '#         <Pcor>0.00e+000</Pcor>\n',
#    '#         <Tcor>0.0000</Tcor>\n',
#    '#         <Tau>0.0</Tau>\n',
#    '#       </CalibrationCoefficients>\n',
#    '#       <CalibrationCoefficients equation="1" >\n',
#    '#         <!-- Coefficients for Sea-Bird equation - SBE calibration in 2007 and later. -->\n',
#    '#         <Soc>4.7282e-001</Soc>\n',
#    '#         <offset>-0.4883</offset>\n',
#    '#         <A>-2.7658e-003</A>\n',
#    '#         <B> 1.1023e-004</B>\n',
#    '#         <C>-1.8809e-006</C>\n',
#    '#         <D0> 2.5826e+000</D0>\n',
#    '#         <D1> 1.92634e-004</D1>\n',
#    '#         <D2>-4.64803e-002</D2>\n',
#    '#         <E> 3.6000e-002</E>\n',
#    '#         <Tau20> 1.0800</Tau20>\n',
#    '#         <H1>-3.3000e-002</H1>\n',
#    '#         <H2> 5.0000e+003</H2>\n',
#    '#         <H3> 1.4500e+003</H3>\n',
#    '#       </CalibrationCoefficients>\n',
#    '#     </OxygenSensor>\n',
#    '#   </sensor>\n',
#    '#   <sensor Channel="11" >\n',
#    '#     <!-- A/D voltage 5, Oxygen, SBE 43, 2 -->\n',
#    '#     <OxygenSensor SensorID="38" >\n',
#    '#       <SerialNumber>3706</SerialNumber>\n',
#    '#       <CalibrationDate>21-Feb-25</CalibrationDate>\n',
#    '#       <Use2007Equation>1</Use2007Equation>\n',
#    '#       <CalibrationCoefficients equation="0" >\n',
#    '#         <!-- Coefficients for Owens-Millard equation. -->\n',
#    '#         <Boc>0.0000</Boc>\n',
#    '#         <Soc>0.0000e+000</Soc>\n',
#    '#         <offset>0.0000</offset>\n',
#    '#         <Pcor>0.00e+000</Pcor>\n',
#    '#         <Tcor>0.0000</Tcor>\n',
#    '#         <Tau>0.0</Tau>\n',
#    '#       </CalibrationCoefficients>\n',
#    '#       <CalibrationCoefficients equation="1" >\n',
#    '#         <!-- Coefficients for Sea-Bird equation - SBE calibration in 2007 and later. -->\n',
#    '#         <Soc>4.4332e-001</Soc>\n',
#    '#         <offset>-0.4932</offset>\n',
#    '#         <A>-2.3244e-003</A>\n',
#    '#         <B> 1.3160e-004</B>\n',
#    '#         <C>-2.6753e-006</C>\n',
#    '#         <D0> 2.5826e+000</D0>\n',
#    '#         <D1> 1.92634e-004</D1>\n',
#    '#         <D2>-4.64803e-002</D2>\n',
#    '#         <E> 3.6000e-002</E>\n',
#    '#         <Tau20> 1.5900</Tau20>\n',
#    '#         <H1>-3.3000e-002</H1>\n',
#    '#         <H2> 5.0000e+003</H2>\n',
#    '#         <H3> 1.4500e+003</H3>\n',
#    '#       </CalibrationCoefficients>\n',
#    '#     </OxygenSensor>\n',
#    '#   </sensor>\n',
#    '#   <sensor Channel="12" >\n',
#    '#     <!-- A/D voltage 6, Transmissometer, WET Labs C-Star -->\n',
#    '#     <WET_LabsCStar SensorID="71" >\n',
#    '#       <SerialNumber>1856</SerialNumber>\n',
#    '#       <CalibrationDate>20-Aug-2024</CalibrationDate>\n',
#    '#       <M>21.2405</M>\n',
#    '#       <B>-0.0255</B>\n',
#    '#       <PathLength>0.250</PathLength>\n',
#    '#     </WET_LabsCStar>\n',
#    '#   </sensor>\n',
#    '#   <sensor Channel="13" >\n',
#    '#     <!-- A/D voltage 7, Free -->\n',
#    '#   </sensor>\n',
#    '# </Sensors>\n',
#    '# datcnv_date = Aug 13 2025 20:21:26, 7.26.7.129 [datcnv_vars = 21]\n',
#    '# datcnv_in = d:\\ctd\\SKQ202515S\\raw\\skq202515s_001.hex d:\\ctd\\SKQ202515S\\raw\\skq202515s_001.XMLCON\n',
#    '# datcnv_skipover = 0\n',
#    '# datcnv_ox_hysteresis_correction = yes\n',
#    '# datcnv_ox_tau_correction = yes\n',
#    '# binavg_date = Aug 13 2025 20:21:27, 7.26.7.129\n',
#    '# binavg_in = d:\\ctd\\SKQ202515S\\proc\\skq202515s_001.cnv\n',
#    '# binavg_bintype = decibars\n',
#    '# binavg_binsize = 1\n',
#    '# binavg_excl_bad_scans = yes\n',
#    '# binavg_skipover = 0\n',
#    '# binavg_omit = 0\n',
#    '# binavg_min_scans_bin = 1\n',
#    '# binavg_max_scans_bin = 2147483647\n',
#    '# binavg_surface_bin = no, min = 0.000, max = 0.000, value = 0.000\n',
#    '# file_type = ascii\n',
#    '*END*\n'],
#   'headercount': 344,
#   'varnames': {0: 'depSM',
#    1: 'latitude',
#    2: 'longitude',
#    3: 'prDM',
#    4: 't090C',
#    5: 't190C',
#    6: 'potemp090C',
#    7: 'sal00',
#    8: 'sal11',
#    9: 'density00',
#    10: 'sigma-00',
#    11: 'sbox0Mm/Kg',
#    12: 'oxsolMm/Kg',
#    13: 'sbeox0PS',
#    14: 'v0',
#    15: 'flECO-AFL',
#    16: 'v1',
#    17: 'CStarAt0',
#    18: 'par',
#    19: 'scan',
#    20: 'timeM',
#    21: 'nbin',
#    22: 'flag'},
#   'SYSTEMtime': 'Aug 13 2025 19:17:24',
#   'NMEAtime': 'Aug 13 2025  19:13:47',
#   'NMEALat': '63 36.19 N',
#   'NMEALon': '172 35.54 W'},
#  'skq202515s_002avg.cnv': {'header': ['* Sea-Bird SBE 9 Data File:\n',
#    '* FileName = D:\\CTD\\SKQ202515S\\raw\\SKQ202515S_002.hex\n',
#    '* Software Version Seasave V 7.26.7.121\n',
#    '* Temperature SN = 5774\n',
#    '* Conductivity SN = 4367\n',
#    '* Number of Bytes Per Scan = 45\n',
#    '* Number of Voltage Words = 4\n',
#    '* Number of Scans Averaged by the Deck Unit = 1\n',
#    '* Append System Time to Every Scan\n',
#    '* System UpLoad Time = Aug 13 2025 22:22:51\n',
#    '* NMEA Latitude = 63 16.83 N\n',
#    '* NMEA Longitude = 173 16.81 W\n',
#    '* NMEA UTC (Time) = Aug 13 2025  22:19:47\n',
#    '* Store Lat/Lon Data = Append to Every Scan\n',
#    '* SBE 11plus V 5.1b\n',
#    '* number of scans to average = 1\n',
#    '* pressure baud rate = 9600\n',
#    '* NMEA baud rate = 4800\n',
#    '* GPIB address = 1\n',
#    '* advance primary conductivity  0.073 seconds\n',
#    '* advance secondary conductivity  0.073 seconds\n',
#    '* S>\n',
#    '** Ship: R/V Sikuliaq\n',
#    '** Station Number: 002\n',
#    '** Station Name: DBO 1.9\n',
#    '** Bottom Depth [m]: 70\n',
#    '** Operator: PS\n',
#    '* System UTC = Aug 13 2025 22:22:51\n',
#    '# nquan = 23\n',
#    '# nvalues = 64                          \n',
#    '# units = specified\n',
#    '# name 0 = depSM: Depth [salt water, m]\n',
#    '# name 1 = latitude: Latitude [deg]\n',
#    '# name 2 = longitude: Longitude [deg]\n',
#    '# name 3 = prDM: Pressure, Digiquartz [db]\n',
#    '# name 4 = t090C: Temperature [ITS-90, deg C]\n',
#    '# name 5 = t190C: Temperature, 2 [ITS-90, deg C]\n',
#    '# name 6 = potemp090C: Potential Temperature [ITS-90, deg C]\n',
#    '# name 7 = sal00: Salinity, Practical [PSU]\n',
#    '# name 8 = sal11: Salinity, Practical, 2 [PSU]\n',
#    '# name 9 = density00: Density [density, kg/m^3]\n',
#    '# name 10 = sigma-00: Density [sigma-theta, kg/m^3]\n',
#    '# name 11 = sbox0Mm/Kg: Oxygen, SBE 43 [umol/kg]\n',
#    '# name 12 = oxsolMm/Kg: Oxygen Saturation, Garcia & Gordon [umol/kg]\n',
#    '# name 13 = sbeox0PS: Oxygen, SBE 43 [% saturation]\n',
#    '# name 14 = v0: Voltage 0\n',
#    '# name 15 = flECO-AFL: Fluorescence, WET Labs ECO-AFL/FL [mg/m^3]\n',
#    '# name 16 = v1: Voltage 1\n',
#    '# name 17 = CStarAt0: Beam Attenuation, WET Labs C-Star [1/m]\n',
#    '# name 18 = par: PAR/Irradiance, Biospherical/Licor\n',
#    '# name 19 = scan: Scan Count\n',
#    '# name 20 = timeM: Time, Elapsed [minutes]\n',
#    '# name 21 = nbin: number of scans per bin\n',
#    '# name 22 = flag: flag\n',
#    '# span 0 =      2.971,     65.351       \n',
#    '# span 1 =   63.28039,   63.28047       \n',
#    '# span 2 = -173.28002, -173.27990       \n',
#    '# span 3 =      3.000,     66.000       \n',
#    '# span 4 =    -1.2029,     9.5773       \n',
#    '# span 5 =    -1.2024,     9.5743       \n',
#    '# span 6 =    -1.2042,     9.5768       \n',
#    '# span 7 =    30.9225,    31.7735       \n',
#    '# span 8 =    30.9367,    31.7917       \n',
#    '# span 9 =  1023.8547,  1025.8624       \n',
#    '# span 10 =    23.8391,    25.5445      \n',
#    '# span 11 =    248.965,    374.671      \n',
#    '# span 12 =  285.38057,  368.39196      \n',
#    '# span 13 =     67.585,    106.509      \n',
#    '# span 14 =     0.0727,     0.5727      \n',
#    '# span 15 =     0.0609,     3.0615      \n',
#    '# span 16 =     0.1100,     0.8456      \n',
#    '# span 17 =     0.1455,     1.5028      \n',
#    '# span 18 = -9.165e-04, 3.5095e+02      \n',
#    '# span 19 =        307,       5406      \n',
#    '# span 20 =     0.2128,     3.7537      \n',
#    '# span 21 =         30,        374      \n',
#    '# span 22 = 0.0000e+00, 0.0000e+00      \n',
#    '# interval = decibars: 1                \n',
#    '# start_time = Aug 13 2025 22:22:49 [NMEA time, first data scan]\n',
#    '# bad_flag = -9.990e-29\n',
#    '# <Sensors count="13" >\n',
#    '#   <sensor Channel="1" >\n',
#    '#     <!-- Frequency 0, Temperature -->\n',
#    '#     <TemperatureSensor SensorID="55" >\n',
#    '#       <SerialNumber>5774</SerialNumber>\n',
#    '#       <CalibrationDate>03-Aug-24</CalibrationDate>\n',
#    '#       <UseG_J>1</UseG_J>\n',
#    '#       <A>0.00000000e+000</A>\n',
#    '#       <B>0.00000000e+000</B>\n',
#    '#       <C>0.00000000e+000</C>\n',
#    '#       <D>0.00000000e+000</D>\n',
#    '#       <F0_Old>0.000</F0_Old>\n',
#    '#       <G>4.33671890e-003</G>\n',
#    '#       <H>6.27175804e-004</H>\n',
#    '#       <I>1.94622760e-005</I>\n',
#    '#       <J>1.44648852e-006</J>\n',
#    '#       <F0>1000.000</F0>\n',
#    '#       <Slope>1.00000000</Slope>\n',
#    '#       <Offset>0.0000</Offset>\n',
#    '#     </TemperatureSensor>\n',
#    '#   </sensor>\n',
#    '#   <sensor Channel="2" >\n',
#    '#     <!-- Frequency 1, Conductivity -->\n',
#    '#     <ConductivitySensor SensorID="3" >\n',
#    '#       <SerialNumber>4367</SerialNumber>\n',
#    '#       <CalibrationDate>23-Jul-24</CalibrationDate>\n',
#    '#       <UseG_J>1</UseG_J>\n',
#    '#       <!-- Cell const and series R are applicable only for wide range sensors. -->\n',
#    '#       <SeriesR>0.0000</SeriesR>\n',
#    '#       <CellConst>2000.0000</CellConst>\n',
#    '#       <ConductivityType>0</ConductivityType>\n',
#    '#       <Coefficients equation="0" >\n',
#    '#         <A>0.00000000e+000</A>\n',
#    '#         <B>0.00000000e+000</B>\n',
#    '#         <C>0.00000000e+000</C>\n',
#    '#         <D>0.00000000e+000</D>\n',
#    '#         <M>0.0</M>\n',
#    '#         <CPcor>-9.57000000e-008</CPcor>\n',
#    '#       </Coefficients>\n',
#    '#       <Coefficients equation="1" >\n',
#    '#         <G>-9.81062403e+000</G>\n',
#    '#         <H>1.39213135e+000</H>\n',
#    '#         <I>-9.20358449e-004</I>\n',
#    '#         <J>1.39392598e-004</J>\n',
#    '#         <CPcor>-9.57000000e-008</CPcor>\n',
#    '#         <CTcor>3.2500e-006</CTcor>\n',
#    '#         <!-- WBOTC not applicable unless ConductivityType = 1. -->\n',
#    '#         <WBOTC>0.00000000e+000</WBOTC>\n',
#    '#       </Coefficients>\n',
#    '#       <Slope>1.00000000</Slope>\n',
#    '#       <Offset>0.00000</Offset>\n',
#    '#     </ConductivitySensor>\n',
#    '#   </sensor>\n',
#    '#   <sensor Channel="3" >\n',
#    '#     <!-- Frequency 2, Pressure, Digiquartz with TC -->\n',
#    '#     <PressureSensor SensorID="45" >\n',
#    '#       <SerialNumber>1213</SerialNumber>\n',
#    '#       <CalibrationDate>13-Mar-20</CalibrationDate>\n',
#    '#       <C1>-4.132681e+004</C1>\n',
#    '#       <C2>-4.458463e-001</C2>\n',
#    '#       <C3>1.331500e-002</C3>\n',
#    '#       <D1>3.488900e-002</D1>\n',
#    '#       <D2>0.000000e+000</D2>\n',
#    '#       <T1>3.032126e+001</T1>\n',
#    '#       <T2>-4.098790e-004</T2>\n',
#    '#       <T3>3.967810e-006</T3>\n',
#    '#       <T4>3.643750e-009</T4>\n',
#    '#       <Slope>0.99999533</Slope>\n',
#    '#       <Offset>-4.33223</Offset>\n',
#    '#       <T5>0.000000e+000</T5>\n',
#    '#       <AD590M>1.280410e-002</AD590M>\n',
#    '#       <AD590B>-9.260115e+000</AD590B>\n',
#    '#     </PressureSensor>\n',
#    '#   </sensor>\n',
#    '#   <sensor Channel="4" >\n',
#    '#     <!-- Frequency 3, Temperature, 2 -->\n',
#    '#     <TemperatureSensor SensorID="55" >\n',
#    '#       <SerialNumber>5773</SerialNumber>\n',
#    '#       <CalibrationDate>06-Aug-24</CalibrationDate>\n',
#    '#       <UseG_J>1</UseG_J>\n',
#    '#       <A>0.00000000e+000</A>\n',
#    '#       <B>0.00000000e+000</B>\n',
#    '#       <C>0.00000000e+000</C>\n',
#    '#       <D>0.00000000e+000</D>\n',
#    '#       <F0_Old>0.000</F0_Old>\n',
#    '#       <G>4.35221970e-003</G>\n',
#    '#       <H>6.29797751e-004</H>\n',
#    '#       <I>1.98679905e-005</I>\n',
#    '#       <J>1.48010526e-006</J>\n',
#    '#       <F0>1000.000</F0>\n',
#    '#       <Slope>1.00000000</Slope>\n',
#    '#       <Offset>0.0000</Offset>\n',
#    '#     </TemperatureSensor>\n',
#    '#   </sensor>\n',
#    '#   <sensor Channel="5" >\n',
#    '#     <!-- Frequency 4, Conductivity, 2 -->\n',
#    '#     <ConductivitySensor SensorID="3" >\n',
#    '#       <SerialNumber>2251</SerialNumber>\n',
#    '#       <CalibrationDate>07-Feb-23</CalibrationDate>\n',
#    '#       <UseG_J>1</UseG_J>\n',
#    '#       <!-- Cell const and series R are applicable only for wide range sensors. -->\n',
#    '#       <SeriesR>0.0000</SeriesR>\n',
#    '#       <CellConst>2000.0000</CellConst>\n',
#    '#       <ConductivityType>0</ConductivityType>\n',
#    '#       <Coefficients equation="0" >\n',
#    '#         <A>0.00000000e+000</A>\n',
#    '#         <B>0.00000000e+000</B>\n',
#    '#         <C>0.00000000e+000</C>\n',
#    '#         <D>0.00000000e+000</D>\n',
#    '#         <M>0.0</M>\n',
#    '#         <CPcor>-9.57000000e-008</CPcor>\n',
#    '#       </Coefficients>\n',
#    '#       <Coefficients equation="1" >\n',
#    '#         <G>-1.01223445e+001</G>\n',
#    '#         <H>1.33362873e+000</H>\n',
#    '#         <I>-2.37166394e-003</I>\n',
#    '#         <J>2.25323667e-004</J>\n',
#    '#         <CPcor>-9.57000000e-008</CPcor>\n',
#    '#         <CTcor>3.2500e-006</CTcor>\n',
#    '#         <!-- WBOTC not applicable unless ConductivityType = 1. -->\n',
#    '#         <WBOTC>0.00000000e+000</WBOTC>\n',
#    '#       </Coefficients>\n',
#    '#       <Slope>1.00000000</Slope>\n',
#    '#       <Offset>0.00000</Offset>\n',
#    '#     </ConductivitySensor>\n',
#    '#   </sensor>\n',
#    '#   <sensor Channel="6" >\n',
#    '#     <!-- A/D voltage 0, Fluorometer, WET Labs ECO-AFL/FL -->\n',
#    '#     <FluoroWetlabECO_AFL_FL_Sensor SensorID="20" >\n',
#    '#       <SerialNumber>5094</SerialNumber>\n',
#    '#       <CalibrationDate>30-Jul-24</CalibrationDate>\n',
#    '#       <ScaleFactor>6.00000000e+000</ScaleFactor>\n',
#    '#       <!-- Dark output -->\n',
#    '#       <Vblank>0.0625</Vblank>\n',
#    '#     </FluoroWetlabECO_AFL_FL_Sensor>\n',
#    '#   </sensor>\n',
#    '#   <sensor Channel="7" >\n',
#    '#     <!-- A/D voltage 1, Fluorometer, WET Labs ECO-AFL/FL, 2 -->\n',
#    '#     <FluoroWetlabECO_AFL_FL_Sensor SensorID="20" >\n',
#    '#       <SerialNumber>5094</SerialNumber>\n',
#    '#       <CalibrationDate>30-Jul-24</CalibrationDate>\n',
#    '#       <ScaleFactor>2.00000000e+000</ScaleFactor>\n',
#    '#       <!-- Dark output -->\n',
#    '#       <Vblank>0.0684</Vblank>\n',
#    '#     </FluoroWetlabECO_AFL_FL_Sensor>\n',
#    '#   </sensor>\n',
#    '#   <sensor Channel="8" >\n',
#    '#     <!-- A/D voltage 2, PAR/Irradiance, Biospherical/Licor -->\n',
#    '#     <PAR_BiosphericalLicorChelseaSensor SensorID="42" >\n',
#    '#       <SerialNumber>70778</SerialNumber>\n',
#    '#       <CalibrationDate>12-Mar-2025</CalibrationDate>\n',
#    '#       <M>1.00000000</M>\n',
#    '#       <B>0.00000000</B>\n',
#    '#       <CalibrationConstant>10989010989.01100000</CalibrationConstant>\n',
#    '#       <Multiplier>1.00000000</Multiplier>\n',
#    '#       <Offset>-0.09163078</Offset>\n',
#    '#     </PAR_BiosphericalLicorChelseaSensor>\n',
#    '#   </sensor>\n',
#    '#   <sensor Channel="9" >\n',
#    '#     <!-- A/D voltage 3, Altimeter -->\n',
#    '#     <AltimeterSensor SensorID="0" >\n',
#    '#       <SerialNumber>302492</SerialNumber>\n',
#    '#       <CalibrationDate>19-Sep-13</CalibrationDate>\n',
#    '#       <ScaleFactor>15.000</ScaleFactor>\n',
#    '#       <Offset>0.000</Offset>\n',
#    '#     </AltimeterSensor>\n',
#    '#   </sensor>\n',
#    '#   <sensor Channel="10" >\n',
#    '#     <!-- A/D voltage 4, Oxygen, SBE 43 -->\n',
#    '#     <OxygenSensor SensorID="38" >\n',
#    '#       <SerialNumber>3704</SerialNumber>\n',
#    '#       <CalibrationDate>12-Mar-25</CalibrationDate>\n',
#    '#       <Use2007Equation>1</Use2007Equation>\n',
#    '#       <CalibrationCoefficients equation="0" >\n',
#    '#         <!-- Coefficients for Owens-Millard equation. -->\n',
#    '#         <Boc>0.0000</Boc>\n',
#    '#         <Soc>0.0000e+000</Soc>\n',
#    '#         <offset>0.0000</offset>\n',
#    '#         <Pcor>0.00e+000</Pcor>\n',
#    '#         <Tcor>0.0000</Tcor>\n',
#    '#         <Tau>0.0</Tau>\n',
#    '#       </CalibrationCoefficients>\n',
#    '#       <CalibrationCoefficients equation="1" >\n',
#    '#         <!-- Coefficients for Sea-Bird equation - SBE calibration in 2007 and later. -->\n',
#    '#         <Soc>4.7282e-001</Soc>\n',
#    '#         <offset>-0.4883</offset>\n',
#    '#         <A>-2.7658e-003</A>\n',
#    '#         <B> 1.1023e-004</B>\n',
#    '#         <C>-1.8809e-006</C>\n',
#    '#         <D0> 2.5826e+000</D0>\n',
#    '#         <D1> 1.92634e-004</D1>\n',
#    '#         <D2>-4.64803e-002</D2>\n',
#    '#         <E> 3.6000e-002</E>\n',
#    '#         <Tau20> 1.0800</Tau20>\n',
#    '#         <H1>-3.3000e-002</H1>\n',
#    '#         <H2> 5.0000e+003</H2>\n',
#    '#         <H3> 1.4500e+003</H3>\n',
#    '#       </CalibrationCoefficients>\n',
#    '#     </OxygenSensor>\n',
#    '#   </sensor>\n',
#    '#   <sensor Channel="11" >\n',
#    '#     <!-- A/D voltage 5, Oxygen, SBE 43, 2 -->\n',
#    '#     <OxygenSensor SensorID="38" >\n',
#    '#       <SerialNumber>3706</SerialNumber>\n',
#    '#       <CalibrationDate>21-Feb-25</CalibrationDate>\n',
#    '#       <Use2007Equation>1</Use2007Equation>\n',
#    '#       <CalibrationCoefficients equation="0" >\n',
#    '#         <!-- Coefficients for Owens-Millard equation. -->\n',
#    '#         <Boc>0.0000</Boc>\n',
#    '#         <Soc>0.0000e+000</Soc>\n',
#    '#         <offset>0.0000</offset>\n',
#    '#         <Pcor>0.00e+000</Pcor>\n',
#    '#         <Tcor>0.0000</Tcor>\n',
#    '#         <Tau>0.0</Tau>\n',
#    '#       </CalibrationCoefficients>\n',
#    '#       <CalibrationCoefficients equation="1" >\n',
#    '#         <!-- Coefficients for Sea-Bird equation - SBE calibration in 2007 and later. -->\n',
#    '#         <Soc>4.4332e-001</Soc>\n',
#    '#         <offset>-0.4932</offset>\n',
#    '#         <A>-2.3244e-003</A>\n',
#    '#         <B> 1.3160e-004</B>\n',
#    '#         <C>-2.6753e-006</C>\n',
#    '#         <D0> 2.5826e+000</D0>\n',
#    '#         <D1> 1.92634e-004</D1>\n',
#    '#         <D2>-4.64803e-002</D2>\n',
#    '#         <E> 3.6000e-002</E>\n',
#    '#         <Tau20> 1.5900</Tau20>\n',
#    '#         <H1>-3.3000e-002</H1>\n',
#    '#         <H2> 5.0000e+003</H2>\n',
#    '#         <H3> 1.4500e+003</H3>\n',
#    '#       </CalibrationCoefficients>\n',
#    '#     </OxygenSensor>\n',
#    '#   </sensor>\n',
#    '#   <sensor Channel="12" >\n',
#    '#     <!-- A/D voltage 6, Transmissometer, WET Labs C-Star -->\n',
#    '#     <WET_LabsCStar SensorID="71" >\n',
#    '#       <SerialNumber>1856</SerialNumber>\n',
#    '#       <CalibrationDate>20-Aug-2024</CalibrationDate>\n',
#    '#       <M>21.2405</M>\n',
#    '#       <B>-0.0255</B>\n',
#    '#       <PathLength>0.250</PathLength>\n',
#    '#     </WET_LabsCStar>\n',
#    '#   </sensor>\n',
#    '#   <sensor Channel="13" >\n',
#    '#     <!-- A/D voltage 7, Free -->\n',
#    '#   </sensor>\n',
#    '# </Sensors>\n',
#    '# datcnv_date = Aug 13 2025 22:45:17, 7.26.7.129 [datcnv_vars = 21]\n',
#    '# datcnv_in = d:\\ctd\\SKQ202515S\\raw\\skq202515s_002.hex d:\\ctd\\SKQ202515S\\raw\\skq202515s_002.XMLCON\n',
#    '# datcnv_skipover = 0\n',
#    '# datcnv_ox_hysteresis_correction = yes\n',
#    '# datcnv_ox_tau_correction = yes\n',
#    '# binavg_date = Aug 13 2025 22:45:18, 7.26.7.129\n',
#    '# binavg_in = d:\\ctd\\SKQ202515S\\proc\\skq202515s_002.cnv\n',
#    '# binavg_bintype = decibars\n',
#    '# binavg_binsize = 1\n',
#    '# binavg_excl_bad_scans = yes\n',
#    '# binavg_skipover = 0\n',
#    '# binavg_omit = 0\n',
#    '# binavg_min_scans_bin = 1\n',
#    '# binavg_max_scans_bin = 2147483647\n',
#    '# binavg_surface_bin = no, min = 0.000, max = 0.000, value = 0.000\n',
#    '# file_type = ascii\n',
#    '*END*\n'],
#   'headercount': 344,
#   'varnames': {0: 'depSM',
#    1: 'latitude',
#    2: 'longitude',
#    3: 'prDM',
#    4: 't090C',
#    5: 't190C',
#    6: 'potemp090C',
#    7: 'sal00',
#    8: 'sal11',
#    9: 'density00',
#    10: 'sigma-00',
#    11: 'sbox0Mm/Kg',
#    12: 'oxsolMm/Kg',
#    13: 'sbeox0PS',
#    14: 'v0',
#    15: 'flECO-AFL',
#    16: 'v1',
#    17: 'CStarAt0',
#    18: 'par',
#    19: 'scan',
#    20: 'timeM',
#    21: 'nbin',
#    22: 'flag'},
#   'SYSTEMtime': 'Aug 13 2025 22:22:51',
#   'NMEAtime': 'Aug 13 2025  22:19:47',
#   'NMEALat': '63 16.83 N',
#   'NMEALon': '173 16.81 W'},
#  'skq202515s_003avg.cnv': {'header': ['* Sea-Bird SBE 9 Data File:\n',
#    '* FileName = D:\\CTD\\SKQ202515S\\raw\\SKQ202515S_003.hex\n',
#    '* Software Version Seasave V 7.26.7.121\n',
#    '* Temperature SN = 5774\n',
#    '* Conductivity SN = 4367\n',
#    '* Number of Bytes Per Scan = 45\n',
#    '* Number of Voltage Words = 4\n',
#    '* Number of Scans Averaged by the Deck Unit = 1\n',
#    '* Append System Time to Every Scan\n',
#    '* System UpLoad Time = Aug 14 2025 00:16:50\n',
#    '* NMEA Latitude = 63 01.79 N\n',
#    '* NMEA Longitude = 173 27.57 W\n',
#    '* NMEA UTC (Time) = Aug 14 2025  00:14:57\n',
#    '* Store Lat/Lon Data = Append to Every Scan\n',
#    '* SBE 11plus V 5.1b\n',
#    '* number of scans to average = 1\n',
#    '* pressure baud rate = 9600\n',
#    '* NMEA baud rate = 4800\n',
#    '* GPIB address = 1\n',
#    '* advance primary conductivity  0.073 seconds\n',
#    '* advance secondary conductivity  0.073 seconds\n',
#    '* S>\n',
#    '** Ship: R/V Sikuliaq\n',
#    '** Station Number: 003\n',
#    '** Station Name: DBO 1.8\n',
#    '** Bottom Depth [m]: 71\n',
#    '** Operator: PS\n',
#    '* System UTC = Aug 14 2025 00:16:50\n',
#    '# nquan = 23\n',
#    '# nvalues = 65                          \n',
#    '# units = specified\n',
#    '# name 0 = depSM: Depth [salt water, m]\n',
#    '# name 1 = latitude: Latitude [deg]\n',
#    '# name 2 = longitude: Longitude [deg]\n',
#    '# name 3 = prDM: Pressure, Digiquartz [db]\n',
#    '# name 4 = t090C: Temperature [ITS-90, deg C]\n',
#    '# name 5 = t190C: Temperature, 2 [ITS-90, deg C]\n',
#    '# name 6 = potemp090C: Potential Temperature [ITS-90, deg C]\n',
#    '# name 7 = sal00: Salinity, Practical [PSU]\n',
#    '# name 8 = sal11: Salinity, Practical, 2 [PSU]\n',
#    '# name 9 = density00: Density [density, kg/m^3]\n',
#    '# name 10 = sigma-00: Density [sigma-theta, kg/m^3]\n',
#    '# name 11 = sbox0Mm/Kg: Oxygen, SBE 43 [umol/kg]\n',
#    '# name 12 = oxsolMm/Kg: Oxygen Saturation, Garcia & Gordon [umol/kg]\n',
#    '# name 13 = sbeox0PS: Oxygen, SBE 43 [% saturation]\n',
#    '# name 14 = v0: Voltage 0\n',
#    '# name 15 = flECO-AFL: Fluorescence, WET Labs ECO-AFL/FL [mg/m^3]\n',
#    '# name 16 = v1: Voltage 1\n',
#    '# name 17 = CStarAt0: Beam Attenuation, WET Labs C-Star [1/m]\n',
#    '# name 18 = par: PAR/Irradiance, Biospherical/Licor\n',
#    '# name 19 = scan: Scan Count\n',
#    '# name 20 = timeM: Time, Elapsed [minutes]\n',
#    '# name 21 = nbin: number of scans per bin\n',
#    '# name 22 = flag: flag\n',
#    '# span 0 =      2.971,     66.342       \n',
#    '# span 1 =   63.02990,   63.02990       \n',
#    '# span 2 = -173.45958, -173.45956       \n',
#    '# span 3 =      3.000,     67.000       \n',
#    '# span 4 =    -1.3144,     9.3344       \n',
#    '# span 5 =    -1.3135,     9.3349       \n',
#    '# span 6 =    -1.3153,     9.3340       \n',
#    '# span 7 =    30.9064,    31.8788       \n',
#    '# span 8 =    30.9093,    31.8848       \n',
#    '# span 9 =  1023.8769,  1025.9521       \n',
#    '# span 10 =    23.8633,    25.6327      \n',
#    '# span 11 =    232.366,    375.001      \n',
#    '# span 12 =  286.94283,  369.20720      \n',
#    '# span 13 =     62.954,    106.268      \n',
#    '# span 14 =     0.0752,     0.4904      \n',
#    '# span 15 =     0.0761,     2.5677      \n',
#    '# span 16 =     0.1137,     0.9134      \n',
#    '# span 17 =     0.1151,     1.4280      \n',
#    '# span 18 = -2.170e-03, 4.7544e+02      \n',
#    '# span 19 =        258,       6504      \n',
#    '# span 20 =     0.1788,     4.5156      \n',
#    '# span 21 =         27,        407      \n',
#    '# span 22 = 0.0000e+00, 0.0000e+00      \n',
#    '# interval = decibars: 1                \n',
#    '# start_time = Aug 14 2025 00:16:49 [NMEA time, first data scan]\n',
#    '# bad_flag = -9.990e-29\n',
#    '# <Sensors count="13" >\n',
#    '#   <sensor Channel="1" >\n',
#    '#     <!-- Frequency 0, Temperature -->\n',
#    '#     <TemperatureSensor SensorID="55" >\n',
#    '#       <SerialNumber>5774</SerialNumber>\n',
#    '#       <CalibrationDate>03-Aug-24</CalibrationDate>\n',
#    '#       <UseG_J>1</UseG_J>\n',
#    '#       <A>0.00000000e+000</A>\n',
#    '#       <B>0.00000000e+000</B>\n',
#    '#       <C>0.00000000e+000</C>\n',
#    '#       <D>0.00000000e+000</D>\n',
#    '#       <F0_Old>0.000</F0_Old>\n',
#    '#       <G>4.33671890e-003</G>\n',
#    '#       <H>6.27175804e-004</H>\n',
#    '#       <I>1.94622760e-005</I>\n',
#    '#       <J>1.44648852e-006</J>\n',
#    '#       <F0>1000.000</F0>\n',
#    '#       <Slope>1.00000000</Slope>\n',
#    '#       <Offset>0.0000</Offset>\n',
#    '#     </TemperatureSensor>\n',
#    '#   </sensor>\n',
#    '#   <sensor Channel="2" >\n',
#    '#     <!-- Frequency 1, Conductivity -->\n',
#    '#     <ConductivitySensor SensorID="3" >\n',
#    '#       <SerialNumber>4367</SerialNumber>\n',
#    '#       <CalibrationDate>23-Jul-24</CalibrationDate>\n',
#    '#       <UseG_J>1</UseG_J>\n',
#    '#       <!-- Cell const and series R are applicable only for wide range sensors. -->\n',
#    '#       <SeriesR>0.0000</SeriesR>\n',
#    '#       <CellConst>2000.0000</CellConst>\n',
#    '#       <ConductivityType>0</ConductivityType>\n',
#    '#       <Coefficients equation="0" >\n',
#    '#         <A>0.00000000e+000</A>\n',
#    '#         <B>0.00000000e+000</B>\n',
#    '#         <C>0.00000000e+000</C>\n',
#    '#         <D>0.00000000e+000</D>\n',
#    '#         <M>0.0</M>\n',
#    '#         <CPcor>-9.57000000e-008</CPcor>\n',
#    '#       </Coefficients>\n',
#    '#       <Coefficients equation="1" >\n',
#    '#         <G>-9.81062403e+000</G>\n',
#    '#         <H>1.39213135e+000</H>\n',
#    '#         <I>-9.20358449e-004</I>\n',
#    '#         <J>1.39392598e-004</J>\n',
#    '#         <CPcor>-9.57000000e-008</CPcor>\n',
#    '#         <CTcor>3.2500e-006</CTcor>\n',
#    '#         <!-- WBOTC not applicable unless ConductivityType = 1. -->\n',
#    '#         <WBOTC>0.00000000e+000</WBOTC>\n',
#    '#       </Coefficients>\n',
#    '#       <Slope>1.00000000</Slope>\n',
#    '#       <Offset>0.00000</Offset>\n',
#    '#     </ConductivitySensor>\n',
#    '#   </sensor>\n',
#    '#   <sensor Channel="3" >\n',
#    '#     <!-- Frequency 2, Pressure, Digiquartz with TC -->\n',
#    '#     <PressureSensor SensorID="45" >\n',
#    '#       <SerialNumber>1213</SerialNumber>\n',
#    '#       <CalibrationDate>13-Mar-20</CalibrationDate>\n',
#    '#       <C1>-4.132681e+004</C1>\n',
#    '#       <C2>-4.458463e-001</C2>\n',
#    '#       <C3>1.331500e-002</C3>\n',
#    '#       <D1>3.488900e-002</D1>\n',
#    '#       <D2>0.000000e+000</D2>\n',
#    '#       <T1>3.032126e+001</T1>\n',
#    '#       <T2>-4.098790e-004</T2>\n',
#    '#       <T3>3.967810e-006</T3>\n',
#    '#       <T4>3.643750e-009</T4>\n',
#    '#       <Slope>0.99999533</Slope>\n',
#    '#       <Offset>-4.33223</Offset>\n',
#    '#       <T5>0.000000e+000</T5>\n',
#    '#       <AD590M>1.280410e-002</AD590M>\n',
#    '#       <AD590B>-9.260115e+000</AD590B>\n',
#    '#     </PressureSensor>\n',
#    '#   </sensor>\n',
#    '#   <sensor Channel="4" >\n',
#    '#     <!-- Frequency 3, Temperature, 2 -->\n',
#    '#     <TemperatureSensor SensorID="55" >\n',
#    '#       <SerialNumber>5773</SerialNumber>\n',
#    '#       <CalibrationDate>06-Aug-24</CalibrationDate>\n',
#    '#       <UseG_J>1</UseG_J>\n',
#    '#       <A>0.00000000e+000</A>\n',
#    '#       <B>0.00000000e+000</B>\n',
#    '#       <C>0.00000000e+000</C>\n',
#    '#       <D>0.00000000e+000</D>\n',
#    '#       <F0_Old>0.000</F0_Old>\n',
#    '#       <G>4.35221970e-003</G>\n',
#    '#       <H>6.29797751e-004</H>\n',
#    '#       <I>1.98679905e-005</I>\n',
#    '#       <J>1.48010526e-006</J>\n',
#    '#       <F0>1000.000</F0>\n',
#    '#       <Slope>1.00000000</Slope>\n',
#    '#       <Offset>0.0000</Offset>\n',
#    '#     </TemperatureSensor>\n',
#    '#   </sensor>\n',
#    '#   <sensor Channel="5" >\n',
#    '#     <!-- Frequency 4, Conductivity, 2 -->\n',
#    '#     <ConductivitySensor SensorID="3" >\n',
#    '#       <SerialNumber>2251</SerialNumber>\n',
#    '#       <CalibrationDate>07-Feb-23</CalibrationDate>\n',
#    '#       <UseG_J>1</UseG_J>\n',
#    '#       <!-- Cell const and series R are applicable only for wide range sensors. -->\n',
#    '#       <SeriesR>0.0000</SeriesR>\n',
#    '#       <CellConst>2000.0000</CellConst>\n',
#    '#       <ConductivityType>0</ConductivityType>\n',
#    '#       <Coefficients equation="0" >\n',
#    '#         <A>0.00000000e+000</A>\n',
#    '#         <B>0.00000000e+000</B>\n',
#    '#         <C>0.00000000e+000</C>\n',
#    '#         <D>0.00000000e+000</D>\n',
#    '#         <M>0.0</M>\n',
#    '#         <CPcor>-9.57000000e-008</CPcor>\n',
#    '#       </Coefficients>\n',
#    '#       <Coefficients equation="1" >\n',
#    '#         <G>-1.01223445e+001</G>\n',
#    '#         <H>1.33362873e+000</H>\n',
#    '#         <I>-2.37166394e-003</I>\n',
#    '#         <J>2.25323667e-004</J>\n',
#    '#         <CPcor>-9.57000000e-008</CPcor>\n',
#    '#         <CTcor>3.2500e-006</CTcor>\n',
#    '#         <!-- WBOTC not applicable unless ConductivityType = 1. -->\n',
#    '#         <WBOTC>0.00000000e+000</WBOTC>\n',
#    '#       </Coefficients>\n',
#    '#       <Slope>1.00000000</Slope>\n',
#    '#       <Offset>0.00000</Offset>\n',
#    '#     </ConductivitySensor>\n',
#    '#   </sensor>\n',
#    '#   <sensor Channel="6" >\n',
#    '#     <!-- A/D voltage 0, Fluorometer, WET Labs ECO-AFL/FL -->\n',
#    '#     <FluoroWetlabECO_AFL_FL_Sensor SensorID="20" >\n',
#    '#       <SerialNumber>5094</SerialNumber>\n',
#    '#       <CalibrationDate>30-Jul-24</CalibrationDate>\n',
#    '#       <ScaleFactor>6.00000000e+000</ScaleFactor>\n',
#    '#       <!-- Dark output -->\n',
#    '#       <Vblank>0.0625</Vblank>\n',
#    '#     </FluoroWetlabECO_AFL_FL_Sensor>\n',
#    '#   </sensor>\n',
#    '#   <sensor Channel="7" >\n',
#    '#     <!-- A/D voltage 1, Fluorometer, WET Labs ECO-AFL/FL, 2 -->\n',
#    '#     <FluoroWetlabECO_AFL_FL_Sensor SensorID="20" >\n',
#    '#       <SerialNumber>5094</SerialNumber>\n',
#    '#       <CalibrationDate>30-Jul-24</CalibrationDate>\n',
#    '#       <ScaleFactor>2.00000000e+000</ScaleFactor>\n',
#    '#       <!-- Dark output -->\n',
#    '#       <Vblank>0.0684</Vblank>\n',
#    '#     </FluoroWetlabECO_AFL_FL_Sensor>\n',
#    '#   </sensor>\n',
#    '#   <sensor Channel="8" >\n',
#    '#     <!-- A/D voltage 2, PAR/Irradiance, Biospherical/Licor -->\n',
#    '#     <PAR_BiosphericalLicorChelseaSensor SensorID="42" >\n',
#    '#       <SerialNumber>70778</SerialNumber>\n',
#    '#       <CalibrationDate>12-Mar-2025</CalibrationDate>\n',
#    '#       <M>1.00000000</M>\n',
#    '#       <B>0.00000000</B>\n',
#    '#       <CalibrationConstant>10989010989.01100000</CalibrationConstant>\n',
#    '#       <Multiplier>1.00000000</Multiplier>\n',
#    '#       <Offset>-0.09163078</Offset>\n',
#    '#     </PAR_BiosphericalLicorChelseaSensor>\n',
#    '#   </sensor>\n',
#    '#   <sensor Channel="9" >\n',
#    '#     <!-- A/D voltage 3, Altimeter -->\n',
#    '#     <AltimeterSensor SensorID="0" >\n',
#    '#       <SerialNumber>302492</SerialNumber>\n',
#    '#       <CalibrationDate>19-Sep-13</CalibrationDate>\n',
#    '#       <ScaleFactor>15.000</ScaleFactor>\n',
#    '#       <Offset>0.000</Offset>\n',
#    '#     </AltimeterSensor>\n',
#    '#   </sensor>\n',
#    '#   <sensor Channel="10" >\n',
#    '#     <!-- A/D voltage 4, Oxygen, SBE 43 -->\n',
#    '#     <OxygenSensor SensorID="38" >\n',
#    '#       <SerialNumber>3704</SerialNumber>\n',
#    '#       <CalibrationDate>12-Mar-25</CalibrationDate>\n',
#    '#       <Use2007Equation>1</Use2007Equation>\n',
#    '#       <CalibrationCoefficients equation="0" >\n',
#    '#         <!-- Coefficients for Owens-Millard equation. -->\n',
#    '#         <Boc>0.0000</Boc>\n',
#    '#         <Soc>0.0000e+000</Soc>\n',
#    '#         <offset>0.0000</offset>\n',
#    '#         <Pcor>0.00e+000</Pcor>\n',
#    '#         <Tcor>0.0000</Tcor>\n',
#    '#         <Tau>0.0</Tau>\n',
#    '#       </CalibrationCoefficients>\n',
#    '#       <CalibrationCoefficients equation="1" >\n',
#    '#         <!-- Coefficients for Sea-Bird equation - SBE calibration in 2007 and later. -->\n',
#    '#         <Soc>4.7282e-001</Soc>\n',
#    '#         <offset>-0.4883</offset>\n',
#    '#         <A>-2.7658e-003</A>\n',
#    '#         <B> 1.1023e-004</B>\n',
#    '#         <C>-1.8809e-006</C>\n',
#    '#         <D0> 2.5826e+000</D0>\n',
#    '#         <D1> 1.92634e-004</D1>\n',
#    '#         <D2>-4.64803e-002</D2>\n',
#    '#         <E> 3.6000e-002</E>\n',
#    '#         <Tau20> 1.0800</Tau20>\n',
#    '#         <H1>-3.3000e-002</H1>\n',
#    '#         <H2> 5.0000e+003</H2>\n',
#    '#         <H3> 1.4500e+003</H3>\n',
#    '#       </CalibrationCoefficients>\n',
#    '#     </OxygenSensor>\n',
#    '#   </sensor>\n',
#    '#   <sensor Channel="11" >\n',
#    '#     <!-- A/D voltage 5, Oxygen, SBE 43, 2 -->\n',
#    '#     <OxygenSensor SensorID="38" >\n',
#    '#       <SerialNumber>3706</SerialNumber>\n',
#    '#       <CalibrationDate>21-Feb-25</CalibrationDate>\n',
#    '#       <Use2007Equation>1</Use2007Equation>\n',
#    '#       <CalibrationCoefficients equation="0" >\n',
#    '#         <!-- Coefficients for Owens-Millard equation. -->\n',
#    '#         <Boc>0.0000</Boc>\n',
#    '#         <Soc>0.0000e+000</Soc>\n',
#    '#         <offset>0.0000</offset>\n',
#    '#         <Pcor>0.00e+000</Pcor>\n',
#    '#         <Tcor>0.0000</Tcor>\n',
#    '#         <Tau>0.0</Tau>\n',
#    '#       </CalibrationCoefficients>\n',
#    '#       <CalibrationCoefficients equation="1" >\n',
#    '#         <!-- Coefficients for Sea-Bird equation - SBE calibration in 2007 and later. -->\n',
#    '#         <Soc>4.4332e-001</Soc>\n',
#    '#         <offset>-0.4932</offset>\n',
#    '#         <A>-2.3244e-003</A>\n',
#    '#         <B> 1.3160e-004</B>\n',
#    '#         <C>-2.6753e-006</C>\n',
#    '#         <D0> 2.5826e+000</D0>\n',
#    '#         <D1> 1.92634e-004</D1>\n',
#    '#         <D2>-4.64803e-002</D2>\n',
#    '#         <E> 3.6000e-002</E>\n',
#    '#         <Tau20> 1.5900</Tau20>\n',
#    '#         <H1>-3.3000e-002</H1>\n',
#    '#         <H2> 5.0000e+003</H2>\n',
#    '#         <H3> 1.4500e+003</H3>\n',
#    '#       </CalibrationCoefficients>\n',
#    '#     </OxygenSensor>\n',
#    '#   </sensor>\n',
#    '#   <sensor Channel="12" >\n',
#    '#     <!-- A/D voltage 6, Transmissometer, WET Labs C-Star -->\n',
#    '#     <WET_LabsCStar SensorID="71" >\n',
#    '#       <SerialNumber>1856</SerialNumber>\n',
#    '#       <CalibrationDate>20-Aug-2024</CalibrationDate>\n',
#    '#       <M>21.2405</M>\n',
#    '#       <B>-0.0255</B>\n',
#    '#       <PathLength>0.250</PathLength>\n',
#    '#     </WET_LabsCStar>\n',
#    '#   </sensor>\n',
#    '#   <sensor Channel="13" >\n',
#    '#     <!-- A/D voltage 7, Free -->\n',
#    '#   </sensor>\n',
#    '# </Sensors>\n',
#    '# datcnv_date = Aug 14 2025 00:32:59, 7.26.7.129 [datcnv_vars = 21]\n',
#    '# datcnv_in = d:\\ctd\\SKQ202515S\\raw\\skq202515s_003.hex d:\\ctd\\SKQ202515S\\raw\\skq202515s_003.XMLCON\n',
#    '# datcnv_skipover = 0\n',
#    '# datcnv_ox_hysteresis_correction = yes\n',
#    '# datcnv_ox_tau_correction = yes\n',
#    '# binavg_date = Aug 14 2025 00:32:59, 7.26.7.129\n',
#    '# binavg_in = d:\\ctd\\SKQ202515S\\proc\\skq202515s_003.cnv\n',
#    '# binavg_bintype = decibars\n',
#    '# binavg_binsize = 1\n',
#    '# binavg_excl_bad_scans = yes\n',
#    '# binavg_skipover = 0\n',
#    '# binavg_omit = 0\n',
#    '# binavg_min_scans_bin = 1\n',
#    '# binavg_max_scans_bin = 2147483647\n',
#    '# binavg_surface_bin = no, min = 0.000, max = 0.000, value = 0.000\n',
#    '# file_type = ascii\n',
#    '*END*\n'],
#   'headercount': 344,
#   'varnames': {0: 'depSM',
#    1: 'latitude',
#    2: 'longitude',
#    3: 'prDM',
#    4: 't090C',
#    5: 't190C',
#    6: 'potemp090C',
#    7: 'sal00',
#    8: 'sal11',
#    9: 'density00',
#    10: 'sigma-00',
#    11: 'sbox0Mm/Kg',
#    12: 'oxsolMm/Kg',
#    13: 'sbeox0PS',
#    14: 'v0',
#    15: 'flECO-AFL',
#    16: 'v1',
#    17: 'CStarAt0',
#    18: 'par',
#    19: 'scan',
#    20: 'timeM',
#    21: 'nbin',
#    22: 'flag'},
#   'SYSTEMtime': 'Aug 14 2025 00:16:50',
#   'NMEAtime': 'Aug 14 2025  00:14:57',
#   'NMEALat': '63 01.79 N',
#   'NMEALon': '173 27.57 W'},
#  'skq202515s_004avg.cnv': {'header': ['* Sea-Bird SBE 9 Data File:\n',
#    '* FileName = D:\\CTD\\SKQ202515S\\raw\\SKQ202515S_004.hex\n',
#    '* Software Version Seasave V 7.26.7.121\n',
# ...
#   'NMEALat': '71 12.33 N',
#   'NMEALon': '157 58.23 W'},
#  'skq202515s_072avg.cnv': {'header': ['* Sea-Bird SBE 9 Data File:\n',
#    '* FileName = D:\\CTD\\SKQ202515S\\raw\\SKQ202515S_072.hex\n',
#    '* Software Version Seasave V 7.26.7.121\n',
#    '* Temperature SN = 5774\n',
#    '* Conductivity SN = 4367\n',
#    '* Number of Bytes Per Scan = 45\n',
#    '* Number of Voltage Words = 4\n',
#    '* Number of Scans Averaged by the Deck Unit = 1\n',
#    '* Append System Time to Every Scan\n',
#    '* System UpLoad Time = Aug 26 2025 22:04:52\n',
#    '* NMEA Latitude = 70 55.49 N\n',
#    '* NMEA Longitude = 161 14.87 W\n',
#    '* NMEA UTC (Time) = Aug 26 2025  22:01:23\n',
#    '* Store Lat/Lon Data = Append to Every Scan\n',
#    '* SBE 11plus V 5.1b\n',
#    '* number of scans to average = 1\n',
#    '* pressure baud rate = 9600\n',
#    '* NMEA baud rate = 4800\n',
#    '* GPIB address = 1\n',
#    '* advance primary conductivity  0.073 seconds\n',
#    '* advance secondary conductivity  0.073 seconds\n',
#    '* S>\n',
#    '** Ship: R/V Sikuliaq\n',
#    '** Station Number: 072\n',
#    '** Station Name: RAMSES CK4\n',
#    '** Bottom Depth [m]: 45\n',
#    '** Operator: SS\n',
#    '* System UTC = Aug 26 2025 22:04:52\n',
#    '# nquan = 23\n',
#    '# nvalues = 38                          \n',
#    '# units = specified\n',
#    '# name 0 = depSM: Depth [salt water, m]\n',
#    '# name 1 = latitude: Latitude [deg]\n',
#    '# name 2 = longitude: Longitude [deg]\n',
#    '# name 3 = prDM: Pressure, Digiquartz [db]\n',
#    '# name 4 = t090C: Temperature [ITS-90, deg C]\n',
#    '# name 5 = t190C: Temperature, 2 [ITS-90, deg C]\n',
#    '# name 6 = potemp090C: Potential Temperature [ITS-90, deg C]\n',
#    '# name 7 = sal00: Salinity, Practical [PSU]\n',
#    '# name 8 = sal11: Salinity, Practical, 2 [PSU]\n',
#    '# name 9 = density00: Density [density, kg/m^3]\n',
#    '# name 10 = sigma-00: Density [sigma-theta, kg/m^3]\n',
#    '# name 11 = sbox0Mm/Kg: Oxygen, SBE 43 [umol/kg]\n',
#    '# name 12 = oxsolMm/Kg: Oxygen Saturation, Garcia & Gordon [umol/kg]\n',
#    '# name 13 = sbeox0PS: Oxygen, SBE 43 [% saturation]\n',
#    '# name 14 = v0: Voltage 0\n',
#    '# name 15 = flECO-AFL: Fluorescence, WET Labs ECO-AFL/FL [mg/m^3]\n',
#    '# name 16 = v1: Voltage 1\n',
#    '# name 17 = CStarAt0: Beam Attenuation, WET Labs C-Star [1/m]\n',
#    '# name 18 = par: PAR/Irradiance, Biospherical/Licor\n',
#    '# name 19 = scan: Scan Count\n',
#    '# name 20 = timeM: Time, Elapsed [minutes]\n',
#    '# name 21 = nbin: number of scans per bin\n',
#    '# name 22 = flag: flag\n',
#    '# span 0 =      2.969,     39.589       \n',
#    '# span 1 =   70.92480,   70.92489       \n',
#    '# span 2 = -161.24777, -161.24741       \n',
#    '# span 3 =      3.000,     40.000       \n',
#    '# span 4 =    -0.4749,     3.6041       \n',
#    '# span 5 =    -0.4770,     3.6040       \n',
#    '# span 6 =    -0.4753,     3.6036       \n',
#    '# span 7 =    26.5911,    31.9782       \n',
#    '# span 8 =    26.5964,    31.9838       \n',
#    '# span 9 =  1021.1535,  1025.8592       \n',
#    '# span 10 =    21.1393,    25.6678      \n',
#    '# span 11 =    325.602,    544.006      \n',
#    '# span 12 =  337.68996,  361.69460      \n',
#    '# span 13 =     96.055,    152.081      \n',
#    '# span 14 =     0.0911,     0.2353      \n',
#    '# span 15 =     0.1718,     1.0371      \n',
#    '# span 16 =     0.1155,     0.5936      \n',
#    '# span 17 =     0.2066,     0.9018      \n',
#    '# span 18 = 3.5650e-01, 2.0772e+02      \n',
#    '# span 19 =        113,       4359      \n',
#    '# span 20 =     0.0776,     3.0264      \n',
#    '# span 21 =         37,        717      \n',
#    '# span 22 = 0.0000e+00, 0.0000e+00      \n',
#    '# interval = decibars: 1                \n',
#    '# start_time = Aug 26 2025 22:04:50 [NMEA time, first data scan]\n',
#    '# bad_flag = -9.990e-29\n',
#    '# <Sensors count="13" >\n',
#    '#   <sensor Channel="1" >\n',
#    '#     <!-- Frequency 0, Temperature -->\n',
#    '#     <TemperatureSensor SensorID="55" >\n',
#    '#       <SerialNumber>5774</SerialNumber>\n',
#    '#       <CalibrationDate>03-Aug-24</CalibrationDate>\n',
#    '#       <UseG_J>1</UseG_J>\n',
#    '#       <A>0.00000000e+000</A>\n',
#    '#       <B>0.00000000e+000</B>\n',
#    '#       <C>0.00000000e+000</C>\n',
#    '#       <D>0.00000000e+000</D>\n',
#    '#       <F0_Old>0.000</F0_Old>\n',
#    '#       <G>4.33671890e-003</G>\n',
#    '#       <H>6.27175804e-004</H>\n',
#    '#       <I>1.94622760e-005</I>\n',
#    '#       <J>1.44648852e-006</J>\n',
#    '#       <F0>1000.000</F0>\n',
#    '#       <Slope>1.00000000</Slope>\n',
#    '#       <Offset>0.0000</Offset>\n',
#    '#     </TemperatureSensor>\n',
#    '#   </sensor>\n',
#    '#   <sensor Channel="2" >\n',
#    '#     <!-- Frequency 1, Conductivity -->\n',
#    '#     <ConductivitySensor SensorID="3" >\n',
#    '#       <SerialNumber>4367</SerialNumber>\n',
#    '#       <CalibrationDate>23-Jul-24</CalibrationDate>\n',
#    '#       <UseG_J>1</UseG_J>\n',
#    '#       <!-- Cell const and series R are applicable only for wide range sensors. -->\n',
#    '#       <SeriesR>0.0000</SeriesR>\n',
#    '#       <CellConst>2000.0000</CellConst>\n',
#    '#       <ConductivityType>0</ConductivityType>\n',
#    '#       <Coefficients equation="0" >\n',
#    '#         <A>0.00000000e+000</A>\n',
#    '#         <B>0.00000000e+000</B>\n',
#    '#         <C>0.00000000e+000</C>\n',
#    '#         <D>0.00000000e+000</D>\n',
#    '#         <M>0.0</M>\n',
#    '#         <CPcor>-9.57000000e-008</CPcor>\n',
#    '#       </Coefficients>\n',
#    '#       <Coefficients equation="1" >\n',
#    '#         <G>-9.81062403e+000</G>\n',
#    '#         <H>1.39213135e+000</H>\n',
#    '#         <I>-9.20358449e-004</I>\n',
#    '#         <J>1.39392598e-004</J>\n',
#    '#         <CPcor>-9.57000000e-008</CPcor>\n',
#    '#         <CTcor>3.2500e-006</CTcor>\n',
#    '#         <!-- WBOTC not applicable unless ConductivityType = 1. -->\n',
#    '#         <WBOTC>0.00000000e+000</WBOTC>\n',
#    '#       </Coefficients>\n',
#    '#       <Slope>1.00000000</Slope>\n',
#    '#       <Offset>0.00000</Offset>\n',
#    '#     </ConductivitySensor>\n',
#    '#   </sensor>\n',
#    '#   <sensor Channel="3" >\n',
#    '#     <!-- Frequency 2, Pressure, Digiquartz with TC -->\n',
#    '#     <PressureSensor SensorID="45" >\n',
#    '#       <SerialNumber>1213</SerialNumber>\n',
#    '#       <CalibrationDate>13-Mar-20</CalibrationDate>\n',
#    '#       <C1>-4.132681e+004</C1>\n',
#    '#       <C2>-4.458463e-001</C2>\n',
#    '#       <C3>1.331500e-002</C3>\n',
#    '#       <D1>3.488900e-002</D1>\n',
#    '#       <D2>0.000000e+000</D2>\n',
#    '#       <T1>3.032126e+001</T1>\n',
#    '#       <T2>-4.098790e-004</T2>\n',
#    '#       <T3>3.967810e-006</T3>\n',
#    '#       <T4>3.643750e-009</T4>\n',
#    '#       <Slope>0.99999533</Slope>\n',
#    '#       <Offset>-4.33223</Offset>\n',
#    '#       <T5>0.000000e+000</T5>\n',
#    '#       <AD590M>1.280410e-002</AD590M>\n',
#    '#       <AD590B>-9.260115e+000</AD590B>\n',
#    '#     </PressureSensor>\n',
#    '#   </sensor>\n',
#    '#   <sensor Channel="4" >\n',
#    '#     <!-- Frequency 3, Temperature, 2 -->\n',
#    '#     <TemperatureSensor SensorID="55" >\n',
#    '#       <SerialNumber>5773</SerialNumber>\n',
#    '#       <CalibrationDate>06-Aug-24</CalibrationDate>\n',
#    '#       <UseG_J>1</UseG_J>\n',
#    '#       <A>0.00000000e+000</A>\n',
#    '#       <B>0.00000000e+000</B>\n',
#    '#       <C>0.00000000e+000</C>\n',
#    '#       <D>0.00000000e+000</D>\n',
#    '#       <F0_Old>0.000</F0_Old>\n',
#    '#       <G>4.35221970e-003</G>\n',
#    '#       <H>6.29797751e-004</H>\n',
#    '#       <I>1.98679905e-005</I>\n',
#    '#       <J>1.48010526e-006</J>\n',
#    '#       <F0>1000.000</F0>\n',
#    '#       <Slope>1.00000000</Slope>\n',
#    '#       <Offset>0.0000</Offset>\n',
#    '#     </TemperatureSensor>\n',
#    '#   </sensor>\n',
#    '#   <sensor Channel="5" >\n',
#    '#     <!-- Frequency 4, Conductivity, 2 -->\n',
#    '#     <ConductivitySensor SensorID="3" >\n',
#    '#       <SerialNumber>2251</SerialNumber>\n',
#    '#       <CalibrationDate>07-Feb-23</CalibrationDate>\n',
#    '#       <UseG_J>1</UseG_J>\n',
#    '#       <!-- Cell const and series R are applicable only for wide range sensors. -->\n',
#    '#       <SeriesR>0.0000</SeriesR>\n',
#    '#       <CellConst>2000.0000</CellConst>\n',
#    '#       <ConductivityType>0</ConductivityType>\n',
#    '#       <Coefficients equation="0" >\n',
#    '#         <A>0.00000000e+000</A>\n',
#    '#         <B>0.00000000e+000</B>\n',
#    '#         <C>0.00000000e+000</C>\n',
#    '#         <D>0.00000000e+000</D>\n',
#    '#         <M>0.0</M>\n',
#    '#         <CPcor>-9.57000000e-008</CPcor>\n',
#    '#       </Coefficients>\n',
#    '#       <Coefficients equation="1" >\n',
#    '#         <G>-1.01223445e+001</G>\n',
#    '#         <H>1.33362873e+000</H>\n',
#    '#         <I>-2.37166394e-003</I>\n',
#    '#         <J>2.25323667e-004</J>\n',
#    '#         <CPcor>-9.57000000e-008</CPcor>\n',
#    '#         <CTcor>3.2500e-006</CTcor>\n',
#    '#         <!-- WBOTC not applicable unless ConductivityType = 1. -->\n',
#    '#         <WBOTC>0.00000000e+000</WBOTC>\n',
#    '#       </Coefficients>\n',
#    '#       <Slope>1.00000000</Slope>\n',
#    '#       <Offset>0.00000</Offset>\n',
#    '#     </ConductivitySensor>\n',
#    '#   </sensor>\n',
#    '#   <sensor Channel="6" >\n',
#    '#     <!-- A/D voltage 0, Fluorometer, WET Labs ECO-AFL/FL -->\n',
#    '#     <FluoroWetlabECO_AFL_FL_Sensor SensorID="20" >\n',
#    '#       <SerialNumber>5094</SerialNumber>\n',
#    '#       <CalibrationDate>30-Jul-24</CalibrationDate>\n',
#    '#       <ScaleFactor>6.00000000e+000</ScaleFactor>\n',
#    '#       <!-- Dark output -->\n',
#    '#       <Vblank>0.0625</Vblank>\n',
#    '#     </FluoroWetlabECO_AFL_FL_Sensor>\n',
#    '#   </sensor>\n',
#    '#   <sensor Channel="7" >\n',
#    '#     <!-- A/D voltage 1, Fluorometer, WET Labs ECO-AFL/FL, 2 -->\n',
#    '#     <FluoroWetlabECO_AFL_FL_Sensor SensorID="20" >\n',
#    '#       <SerialNumber>5094</SerialNumber>\n',
#    '#       <CalibrationDate>30-Jul-24</CalibrationDate>\n',
#    '#       <ScaleFactor>2.00000000e+000</ScaleFactor>\n',
#    '#       <!-- Dark output -->\n',
#    '#       <Vblank>0.0684</Vblank>\n',
#    '#     </FluoroWetlabECO_AFL_FL_Sensor>\n',
#    '#   </sensor>\n',
#    '#   <sensor Channel="8" >\n',
#    '#     <!-- A/D voltage 2, PAR/Irradiance, Biospherical/Licor -->\n',
#    '#     <PAR_BiosphericalLicorChelseaSensor SensorID="42" >\n',
#    '#       <SerialNumber>70778</SerialNumber>\n',
#    '#       <CalibrationDate>12-Mar-2025</CalibrationDate>\n',
#    '#       <M>1.00000000</M>\n',
#    '#       <B>0.00000000</B>\n',
#    '#       <CalibrationConstant>10989010989.01100000</CalibrationConstant>\n',
#    '#       <Multiplier>1.00000000</Multiplier>\n',
#    '#       <Offset>-0.09163078</Offset>\n',
#    '#     </PAR_BiosphericalLicorChelseaSensor>\n',
#    '#   </sensor>\n',
#    '#   <sensor Channel="9" >\n',
#    '#     <!-- A/D voltage 3, Altimeter -->\n',
#    '#     <AltimeterSensor SensorID="0" >\n',
#    '#       <SerialNumber>302492</SerialNumber>\n',
#    '#       <CalibrationDate>19-Sep-13</CalibrationDate>\n',
#    '#       <ScaleFactor>15.000</ScaleFactor>\n',
#    '#       <Offset>0.000</Offset>\n',
#    '#     </AltimeterSensor>\n',
#    '#   </sensor>\n',
#    '#   <sensor Channel="10" >\n',
#    '#     <!-- A/D voltage 4, Oxygen, SBE 43 -->\n',
#    '#     <OxygenSensor SensorID="38" >\n',
#    '#       <SerialNumber>3704</SerialNumber>\n',
#    '#       <CalibrationDate>12-Mar-25</CalibrationDate>\n',
#    '#       <Use2007Equation>1</Use2007Equation>\n',
#    '#       <CalibrationCoefficients equation="0" >\n',
#    '#         <!-- Coefficients for Owens-Millard equation. -->\n',
#    '#         <Boc>0.0000</Boc>\n',
#    '#         <Soc>0.0000e+000</Soc>\n',
#    '#         <offset>0.0000</offset>\n',
#    '#         <Pcor>0.00e+000</Pcor>\n',
#    '#         <Tcor>0.0000</Tcor>\n',
#    '#         <Tau>0.0</Tau>\n',
#    '#       </CalibrationCoefficients>\n',
#    '#       <CalibrationCoefficients equation="1" >\n',
#    '#         <!-- Coefficients for Sea-Bird equation - SBE calibration in 2007 and later. -->\n',
#    '#         <Soc>4.7282e-001</Soc>\n',
#    '#         <offset>-0.4883</offset>\n',
#    '#         <A>-2.7658e-003</A>\n',
#    '#         <B> 1.1023e-004</B>\n',
#    '#         <C>-1.8809e-006</C>\n',
#    '#         <D0> 2.5826e+000</D0>\n',
#    '#         <D1> 1.92634e-004</D1>\n',
#    '#         <D2>-4.64803e-002</D2>\n',
#    '#         <E> 3.6000e-002</E>\n',
#    '#         <Tau20> 1.0800</Tau20>\n',
#    '#         <H1>-3.3000e-002</H1>\n',
#    '#         <H2> 5.0000e+003</H2>\n',
#    '#         <H3> 1.4500e+003</H3>\n',
#    '#       </CalibrationCoefficients>\n',
#    '#     </OxygenSensor>\n',
#    '#   </sensor>\n',
#    '#   <sensor Channel="11" >\n',
#    '#     <!-- A/D voltage 5, Oxygen, SBE 43, 2 -->\n',
#    '#     <OxygenSensor SensorID="38" >\n',
#    '#       <SerialNumber>3706</SerialNumber>\n',
#    '#       <CalibrationDate>21-Feb-25</CalibrationDate>\n',
#    '#       <Use2007Equation>1</Use2007Equation>\n',
#    '#       <CalibrationCoefficients equation="0" >\n',
#    '#         <!-- Coefficients for Owens-Millard equation. -->\n',
#    '#         <Boc>0.0000</Boc>\n',
#    '#         <Soc>0.0000e+000</Soc>\n',
#    '#         <offset>0.0000</offset>\n',
#    '#         <Pcor>0.00e+000</Pcor>\n',
#    '#         <Tcor>0.0000</Tcor>\n',
#    '#         <Tau>0.0</Tau>\n',
#    '#       </CalibrationCoefficients>\n',
#    '#       <CalibrationCoefficients equation="1" >\n',
#    '#         <!-- Coefficients for Sea-Bird equation - SBE calibration in 2007 and later. -->\n',
#    '#         <Soc>4.4332e-001</Soc>\n',
#    '#         <offset>-0.4932</offset>\n',
#    '#         <A>-2.3244e-003</A>\n',
#    '#         <B> 1.3160e-004</B>\n',
#    '#         <C>-2.6753e-006</C>\n',
#    '#         <D0> 2.5826e+000</D0>\n',
#    '#         <D1> 1.92634e-004</D1>\n',
#    '#         <D2>-4.64803e-002</D2>\n',
#    '#         <E> 3.6000e-002</E>\n',
#    '#         <Tau20> 1.5900</Tau20>\n',
#    '#         <H1>-3.3000e-002</H1>\n',
#    '#         <H2> 5.0000e+003</H2>\n',
#    '#         <H3> 1.4500e+003</H3>\n',
#    '#       </CalibrationCoefficients>\n',
#    '#     </OxygenSensor>\n',
#    '#   </sensor>\n',
#    '#   <sensor Channel="12" >\n',
#    '#     <!-- A/D voltage 6, Transmissometer, WET Labs C-Star -->\n',
#    '#     <WET_LabsCStar SensorID="71" >\n',
#    '#       <SerialNumber>1609</SerialNumber>\n',
#    '#       <CalibrationDate>18 AUG 2025</CalibrationDate>\n',
#    '#       <M>21.1630</M>\n',
#    '#       <B>-0.0254</B>\n',
#    '#       <PathLength>0.250</PathLength>\n',
#    '#     </WET_LabsCStar>\n',
#    '#   </sensor>\n',
#    '#   <sensor Channel="13" >\n',
#    '#     <!-- A/D voltage 7, Free -->\n',
#    '#   </sensor>\n',
#    '# </Sensors>\n',
#    '# datcnv_date = Aug 26 2025 22:14:59, 7.26.7.129 [datcnv_vars = 21]\n',
#    '# datcnv_in = d:\\ctd\\SKQ202515S\\raw\\skq202515s_072.hex d:\\ctd\\SKQ202515S\\raw\\skq202515s_072.XMLCON\n',
#    '# datcnv_skipover = 0\n',
#    '# datcnv_ox_hysteresis_correction = yes\n',
#    '# datcnv_ox_tau_correction = yes\n',
#    '# binavg_date = Aug 26 2025 22:14:59, 7.26.7.129\n',
#    '# binavg_in = d:\\ctd\\SKQ202515S\\proc\\skq202515s_072.cnv\n',
#    '# binavg_bintype = decibars\n',
#    '# binavg_binsize = 1\n',
#    '# binavg_excl_bad_scans = yes\n',
#    '# binavg_skipover = 0\n',
#    '# binavg_omit = 0\n',
#    '# binavg_min_scans_bin = 1\n',
#    '# binavg_max_scans_bin = 2147483647\n',
#    '# binavg_surface_bin = no, min = 0.000, max = 0.000, value = 0.000\n',
#    '# file_type = ascii\n',
#    '*END*\n'],
#   'headercount': 344,
#   'varnames': {0: 'depSM',
#    1: 'latitude',
#    2: 'longitude',
#    3: 'prDM',
#    4: 't090C',
#    5: 't190C',
#    6: 'potemp090C',
#    7: 'sal00',
#    8: 'sal11',
#    9: 'density00',
#    10: 'sigma-00',
#    11: 'sbox0Mm/Kg',
#    12: 'oxsolMm/Kg',
#    13: 'sbeox0PS',
#    14: 'v0',
#    15: 'flECO-AFL',
#    16: 'v1',
#    17: 'CStarAt0',
#    18: 'par',
#    19: 'scan',
#    20: 'timeM',
#    21: 'nbin',
#    22: 'flag'},
#   'SYSTEMtime': 'Aug 26 2025 22:04:52',
#   'NMEAtime': 'Aug 26 2025  22:01:23',
#   'NMEALat': '70 55.49 N',
#   'NMEALon': '161 14.87 W'}}

# %%
#this line adds available NMEA data to csv files for NRT/Preliminary erddap hosting... if there isn't an NMEA string, you will have to pull the locations
#  from the cast logs and output either a .nc or a more elaborate csv file furthur in to this process
NMEA_location = True
verbose = False
SYSTEMtime = False

if NMEA_location:
    
    for cast in cruise_header.keys():
        cruise_data[cast][['time','latitude','longitude','profileid']] = ('0',0,0,'0')
        cruise_data[cast][['time','latitude','longitude','profileid']] = (cruise_header[cast]['NMEAtime'],
              geotools.latlon_convert(cruise_header[cast]['NMEALat'],cruise_header[cast]['NMEALon'])[0],
              geotools.latlon_convert(cruise_header[cast]['NMEALat'],cruise_header[cast]['NMEALon'])[1],
              cast.split('.')[0])
        if verbose:
            print(cruise_header[cast]['NMEAtime'],
                  geotools.latlon_convert(cruise_header[cast]['NMEALat'],cruise_header[cast]['NMEALon'])[0],
                  geotools.latlon_convert(cruise_header[cast]['NMEALat'],cruise_header[cast]['NMEALon'])[1])
elif SYSTEMtime:
     for cast in cruise_header.keys():
        cruise_data[cast][['time','latitude','longitude','profileid']] = ('0',0,0,'0')
        cruise_data[cast][['time','latitude','longitude','profileid']] = (cruise_header[cast]['SYSTEMtime'],0,0,'0')

# %%
#save downcast csv to file for viewing - really this is just a cleaned up cnv file
import pandas as pd
for cast in cruise_data.keys():
#     print(f'Processing Cast {cast}')
    cruise_data[cast]['time'] = pd.to_datetime(cruise_data[cast]['time'])
    cruise_data[cast].to_csv(sample_data_dir+cast.replace('cnv','csv'))

# %% [markdown]
# ## Post Cruise Processing with additional meta information

# %%
###############################################################
# edit to point to {cruise sepcific} raw datafiles 
datafile = sample_data_dir+'rawconverted/' #<- point to cruise and process all files within
cruise_name = 'DY2504' #no hyphens
cruise_meta_file = sample_data_dir+'logs/DY2504.yaml'
inst_meta_file = sample_data_dir+'logs/FOCI_standard_CTD.yaml'
group_meta_file = ecofocipy_dir+'staticdata/institutional_meta_example_ctd.yaml'
inst_shortname = '' #keep as placeholder for now
###############################################################

#init and load data
cruise = sbe_ctd_parser.sbe9_11p()
filename_list = sorted(glob.glob(datafile + '*.cnv'))

(cruise_data,cruise_header) = cruise.parse(filename_list)

# %% [markdown]
# ## Time Properties
#
# Not traditionally dealt with for CTD files as they are likely dynamically updated via GPS feed.  However, FOCI tends to label the date/time with the ***at depth*** time-stamp
#
# ## Depth Properties and other assumptions
#
# - currently, all processing and binning (1m for FOCI) is done via seabird routines and the windows software.  This may change with the python ctd package for a few tasks

# %% [markdown]
# ## Load all external meta information

# %%
#cruise info
with open(cruise_meta_file) as file:
    cruise_config = yaml.full_load(file)

#instrument info
with open(inst_meta_file) as file:
    inst_config = yaml.full_load(file)

#institutional info
with open(group_meta_file) as file:
    group_config = yaml.full_load(file)

# %%
inst_config
# Out:
# {'time': {'epic_key': 'TIM_601',
#   'name': 'time',
#   'generic_name': 'time',
#   'standard_name': 'time',
#   'long_name': 'date and time since reference time'},
#  'depth': {'epic_key': 'D_3',
#   'generic_name': 'depth',
#   'units': 'meter',
#   'long_name': 'depth below surface (meters)',
#   'standard_name': 'depth',
#   'positive': 'down'},
#  'latitude': {'epic_key': 'LON_501',
#   'name': 'latitude',
#   'generic_name': 'latitude',
#   'units': 'degrees_north',
#   'long_name': 'latitude',
#   'standard_name': 'latitude'},
#  'longitude': {'epic_key': 'LAT_500',
#   'name': 'longitude',
#   'generic_name': 'longitude',
#   'units': 'degrees_east',
#   'long_name': 'longitude',
#   'standard_name': 'longitude'},
#  'temperature_ch1': {'epic_key': 'T_28',
#   'generic_name': 'temp channel 1',
#   'long_name': 'Sea temperature in-situ ITS-90 scale',
#   'standard_name': 'sea_water_temperature',
#   'units': 'degree_C'},
#  'temperature_ch2': {'epic_key': 'T2_35',
#   'generic_name': 'temp channel 2',
#   'long_name': 'Sea temperature in-situ ITS-90 scale',
#   'standard_name': 'sea_water_temperature',
#   'units': 'degree_C'},
#  'pressure': {'epic_key': 'P_1',
#   'generic_name': 'pres',
#   'units': 'decibar',
#   'long_name': 'Sea water pressure, equals 0 at sea-level',
#   'standard_name': 'sea_water_pressure_due_to_sea_water'},
#  'salinity_ch1': {'epic_key': 'S_41',
#   'generic_name': 'psal channel 1',
#   'units': 'PSU',
#   'long_name': 'Practical salinity in-situ PSS-78 scale',
#   'standard_name': 'sea_water_practical_salinity'},
#  'salinity_ch2': {'epic_key': 'S_42',
#   'generic_name': 'psal channel 2',
#   'units': 'PSU',
#   'long_name': 'Practical salinity in-situ PSS-78 scale',
#   'standard_name': 'sea_water_practical_salinity'},
#  'chlor_fluorescence': {'epic_key': 'F_903',
#   'generic_name': 'chlor_fluorescence',
#   'long_name': 'Mass Concdentration of chlorophyll from chlorophyll fluorescence',
#   'standard_name': 'mass_concentration_of_chlorophyll_in_sea_water',
#   'units': 'ugrams/l'},
#  'turbidity': {'epic_key': 'Trb_980',
#   'generic_name': 'Turbidity',
#   'long_name': 'Turbidity of ocean water in Nephlometric Turbidity Units',
#   'standard_name': 'sea_water_turbidity',
#   'units': 'NTU'},
#  'par': {'generic_name': 'par',
#   'epic_key': 'PAR_905',
#   'long_name': 'Photosynthetic Active Radiation',
#   'standard_name': 'omnidirectional_photosynthetic_photon_spherical_irradiance_in_sea_water',
#   'units': 'uEin cm-2 s-1'},
#  'oxy_conc_ch1': {'generic_name': 'oxy_conc channel 1',
#   'epic_key': 'O_65',
#   'long_name': 'concentration of oxygen in seawater',
#   'standard_name': 'mole_concentration_of_dissolved_molecular_oxygen_in_sea_water',
#   'units': 'micromole/kg'},
#  'oxy_conc_ch2': {'generic_name': 'oxy_conc channel 2',
#   'epic_key': 'CTDOXY_4221',
#   'long_name': 'concentration of oxygen in seawater',
#   'standard_name': 'mole_concentration_of_dissolved_molecular_oxygen_in_sea_water',
#   'units': 'micromole/kg'},
#  'oxy_concM_ch1': {'generic_name': 'oxy_concM channel 1',
#   'epic_key': 'O_65',
#   'long_name': 'concentration of oxygen in seawater',
#   'standard_name': 'mole_concentration_of_dissolved_molecular_oxygen_in_sea_water',
#   'units': 'ml/l'},
#  'oxy_concM_ch2': {'generic_name': 'oxy_concM channel 2',
#   'epic_key': 'O_2060',
#   'long_name': 'concentration of oxygen in seawater',
#   'standard_name': 'mole_concentration_of_dissolved_molecular_oxygen_in_sea_water',
#   'units': 'ml/l'},
#  'oxy_percentsat_ch1': {'generic_name': 'oxy_psat channel 1',
#   'epic_key': 'OST_62',
#   'units': 'percent',
#   'long_name': 'Percent Saturation of oxygen over air',
#   'standard_name': 'fractional_saturation_of_oxygen_in_sea_water'},
#  'oxy_percentsat_ch2': {'generic_name': 'oxy_psat channel 2',
#   'epic_key': 'CTDOST_4220',
#   'units': 'percent',
#   'long_name': 'Percent Saturation of oxygen over air',
#   'standard_name': 'fractional_saturation_of_oxygen_in_sea_water'}}

# %%
cruise_config['CTDCasts']['CTD001']
# Out:
# {'id': 54956,
#  'Vessel': 'NOAAS Oscar Dyson',
#  'CruiseID': 'DY2504',
#  'Project_Leg': '',
#  'UniqueCruiseID': 'DY2504',
#  'Project': 'Spring Mooring Cruise',
#  'StationNo_altname': '',
#  'ConsecutiveCastNo': 'CTD001',
#  'LatitudeDeg': 54,
#  'LatitudeMin': 4.91,
#  'LongitudeDeg': 163,
#  'LongitudeMin': 29.92,
#  'GMTDay': 26,
#  'GMTMonth': 'Apr',
#  'GMTYear': 2025,
#  'GMTTime': 65100,
#  'DryBulb': 5.0,
#  'RelativeHumidity': 94,
#  'WetBulb': -99.9,
#  'Pressure': 998,
#  'SeaState': '',
#  'Visibility': '',
#  'WindDir': 268,
#  'WindSpd': 12.0,
#  'CloudAmt': '',
#  'CloudType': '',
#  'Weather': '',
#  'SurfaceTemp': -99.9,
#  'BottomDepth': 99,
#  'StationNameID': 'UN04',
#  'MaxDepth': 95,
#  'InstrumentSerialNos': '',
#  'Notes': 'deploy AL25_AU_UN04 (mml) - test bottles',
#  'NutrientBtlNiskinNo': '1',
#  'NutrientBtlNumbers': '',
#  'OxygenBtlNiskinNo': '1',
#  'OxygenBtlNumbers': '221',
#  'SalinityBtlNiskinNo': '',
#  'SalinityBtlNumbers': '',
#  'ChlorophyllBtlNiskinNo': '1',
#  'ChlorophyllBtlVolumes': '',
#  'InstrumentType': 'SBE911plus',
#  'WaterMassCode': 'G',
#  'isMooringProfileCast': 'y',
#  'MooringID': 'AL25_AU_UN04',
#  'QualityControlled': 'n',
#  'FileName': ''}

# %%
cruise_data['CTD001.cnv'].columns
# Out:
# Index(['c0mS/cm', 'c1mS/cm', 'flECO-AFL', 'sbeox0V', 'sbeox1V', 't090C',
#        't190C', 'turbWETntu0', 'par', 'sal00', 'sal11', 'sbeox0Mg/L',
#        'sbeox0PS', 'sbox0Mm/Kg', 'sbeox1Mg/L', 'sbeox1PS', 'sbox1Mm/Kg',
#        'sigma-t00', 'sigma-t11', 'nbin', 'flag'],
#       dtype='object')

# %%
cast = 'CTD001.cnv'

cruise_data[cast] = cruise_data[cast].rename(columns={
                    't090C':'temperature_ch1',
                    't190C':'temperature_ch2',
                    'sal00':'salinity_ch1',
                    'sal11':'salinity_ch2',
                    'sbox0Mm/Kg':'oxy_conc_ch1',
                    'sbeox0ML/L':'oxy_concM_ch1',
                    'sbeox0PS':'oxy_percentsat_ch1',
                    'sbox1Mm/Kg':'oxy_conc_ch2',
                    'sbeox1ML/L':'oxy_concM_ch2',
                    'sbeox1PS':'oxy_percentsat_ch2',
                    'sigma-t00':'sigma_t_ch1',
                    'sigma-t11':'sigma_t_ch2',
                    'flECO-AFL':'chlor_fluorescence',
                    'turbWETntu0':'turbidity',
                    'cstarat0':'Attenuation',
                    'cstartr0':'Transmittance',
                    'par':'par',
                    'empty':'empty', #this will be ignored
                    'flag':'flag'})

cruise_data[cast].index.rename('depth',inplace=True)
#cruise_data[cast].sample()

cruise_data_nc = ncCFsave.EcoFOCI_CFnc(df=cruise_data[cast], 
                            instrument_yaml=inst_config, 
                            operation_yaml=cruise_config,
                            operation_type='ctd')
cruise_data_nc.expand_dimensions(dim_names=['latitude','longitude','time'],geophys_sort=False)
cruise_data_nc.variable_meta_data(variable_keys=list(cruise_data[cast].columns.values),drop_missing=True)
cruise_data_nc.dimension_meta_data(variable_keys=['depth','latitude','longitude'])
cruise_data_nc.temporal_geospatioal_meta_data_ctd(positiveE=False,conscastno=cast.split('.')[0])

cruise_data_nc.var_qcflag_init(dim_names=['depth','latitude','longitude','time'])

#interp to sfc for list of vars
try:
    cruise_data_nc.interp2sfc(novars=['par'])
except:
    pass

#add global attributes
cruise_data_nc.deployment_meta_add(conscastno=cast.upper().split('.')[0])
cruise_data_nc.get_xdf()

#add instituitonal global attributes
cruise_data_nc.institution_meta_add(group_config)

#add creation date/time - provenance data
cruise_data_nc.provinance_meta_add()

#provide intial qc status field
cruise_data_nc.qc_status(qc_status='unknown')

cast_label = cast.split('.')[0].split('d')[-1]
cruise_data_nc.xarray2netcdf_save(xdf = cruise_data_nc.get_xdf(),
                        filename=sample_data_dir+cruise_name+'c'+cast_label.zfill(3)+'_ctd.nc',format="NETCDF3_CLASSIC")
#generate editable csv files
to_edit = True
if to_edit:
    if not cast[0] in ['d','u']: #dont save editable up and downcast files, just nc files for plotting... all u/d files can be removed after final data
        cruise_data_nc.get_xdf().to_dataframe().to_csv(sample_data_dir+cruise_name+'c'+cast_label.zfill(3)+'_ctd.to_edit.csv')
# Out:
# /Users/bell/src/ecofocipy/src/EcoFOCIpy/io/ncCFsave.py:320: UserWarning: Times can't be serialized faithfully to int64 with requested units 'days since 1900-01-01'. Resolution of 'minutes' needed. Serializing times to floating point instead. Set encoding['dtype'] to integer dtype to serialize to int64. Set encoding['dtype'] to floating point dtype to silence this warning.
#   xdf.to_netcdf(filename,format=kwargs['format'],encoding={'time':{'units':'days since 1900-01-01'}})

# %%
for cast in cruise_data.keys():
    print(f'Processing Cast {cast}')
    try:
        #output cruise cast stats here
        #cruise_data[cast].describe()
        #cruise_data['ctd001.cnv'].hist() - seaborn may have a better summary plot than just a bunch of histograms
        #sns.pairplot(cruise_data[cast])

        cruise_data[cast] = cruise_data[cast].rename(columns={
                            't090C':'temperature_ch1',
                            't190C':'temperature_ch2',
                            'sal00':'salinity_ch1',
                            'sal11':'salinity_ch2',
                            'sbox0Mm/Kg':'oxy_conc_ch1',
                            'sbeox0ML/L':'oxy_concM_ch1',
                            'sbeox0PS':'oxy_percentsat_ch1',
                            'sbox1Mm/Kg':'oxy_conc_ch2',
                            'sbeox1ML/L':'oxy_concM_ch2',
                            'sbeox1PS':'oxy_percentsat_ch2',
                            'sigma-t00':'sigma_t_ch1',
                            'sigma-t11':'sigma_t_ch2',
                            'flECO-AFL':'chlor_fluorescence',
                            'turbWETntu0':'turbidity',
                            'cstarat0':'Attenuation',
                            'cstartr0':'Transmittance',
                            'par':'par',
                            'empty':'empty', #this will be ignored
                            'flag':'flag'})

        cruise_data[cast].index.rename('depth',inplace=True)
        #cruise_data[cast].sample()

        cruise_data_nc = ncCFsave.EcoFOCI_CFnc(df=cruise_data[cast], 
                                    instrument_yaml=inst_config, 
                                    operation_yaml=cruise_config,
                                    operation_type='ctd')
        cruise_data_nc.expand_dimensions(dim_names=['latitude','longitude','time'],geophys_sort=False)
        cruise_data_nc.variable_meta_data(variable_keys=list(cruise_data[cast].columns.values),drop_missing=True)
        cruise_data_nc.dimension_meta_data(variable_keys=['depth','latitude','longitude'])
        cruise_data_nc.temporal_geospatioal_meta_data_ctd(positiveE=False,conscastno=cast.split('.')[0])

        cruise_data_nc.var_qcflag_init(dim_names=['depth','latitude','longitude','time'])

        #interp to sfc for list of vars
        try:
            cruise_data_nc.interp2sfc(novars=['par'])
        except:
            pass

        #add global attributes
        cruise_data_nc.deployment_meta_add(conscastno=cast.upper().split('.')[0])
        cruise_data_nc.get_xdf()

        #add instituitonal global attributes
        cruise_data_nc.institution_meta_add(group_config)

        #add creation date/time - provenance data
        cruise_data_nc.provinance_meta_add()

        #provide intial qc status field
        cruise_data_nc.qc_status(qc_status='unknown')

        cast_label = cast.split('.')[0].split('d')[-1]
        cruise_data_nc.xarray2netcdf_save(xdf = cruise_data_nc.get_xdf(),
                                filename=sample_data_dir+cruise_name+'c'+cast_label.zfill(3)+'_ctd.nc',format="NETCDF3_CLASSIC")
        #generate editable csv files
        to_edit = True
        if to_edit:
            if not cast[0] in ['d','u']: #dont save editable up and downcast files, just nc files for plotting... all u/d files can be removed after final data
                cruise_data_nc.get_xdf().to_dataframe().to_csv(sample_data_dir+cruise_name+'c'+cast_label.zfill(3)+'_ctd.to_edit.csv')  
        
    except:
       print('Conversion Failed')
# Out:
# /Users/bell/src/ecofocipy/src/EcoFOCIpy/io/ncCFsave.py:320: UserWarning: Times can't be serialized faithfully to int64 with requested units 'days since 1900-01-01'. Resolution of 'minutes' needed. Serializing times to floating point instead. Set encoding['dtype'] to integer dtype to serialize to int64. Set encoding['dtype'] to floating point dtype to silence this warning.
#   xdf.to_netcdf(filename,format=kwargs['format'],encoding={'time':{'units':'days since 1900-01-01'}})
# /Users/bell/src/ecofocipy/src/EcoFOCIpy/io/ncCFsave.py:320: UserWarning: Times can't be serialized faithfully to int64 with requested units 'days since 1900-01-01'. Resolution of 'minutes' needed. Serializing times to floating point instead. Set encoding['dtype'] to integer dtype to serialize to int64. Set encoding['dtype'] to floating point dtype to silence this warning.
#   xdf.to_netcdf(filename,format=kwargs['format'],encoding={'time':{'units':'days since 1900-01-01'}})
# /Users/bell/src/ecofocipy/src/EcoFOCIpy/io/ncCFsave.py:320: UserWarning: Times can't be serialized faithfully to int64 with requested units 'days since 1900-01-01'. Resolution of 'minutes' needed. Serializing times to floating point instead. Set encoding['dtype'] to integer dtype to serialize to int64. Set encoding['dtype'] to floating point dtype to silence this warning.
#   xdf.to_netcdf(filename,format=kwargs['format'],encoding={'time':{'units':'days since 1900-01-01'}})
# /Users/bell/src/ecofocipy/src/EcoFOCIpy/io/ncCFsave.py:320: UserWarning: Times can't be serialized faithfully to int64 with requested units 'days since 1900-01-01'. Resolution of 'minutes' needed. Serializing times to floating point instead. Set encoding['dtype'] to integer dtype to serialize to int64. Set encoding['dtype'] to floating point dtype to silence this warning.
#   xdf.to_netcdf(filename,format=kwargs['format'],encoding={'time':{'units':'days since 1900-01-01'}})
# Processing Cast CTD001.cnv
# Processing Cast CTD002.cnv
# Processing Cast CTD003.cnv
# Processing Cast CTD004.cnv
# Processing Cast CTD005.cnv
# Processing Cast CTD006.cnv
# /Users/bell/src/ecofocipy/src/EcoFOCIpy/io/ncCFsave.py:320: UserWarning: Times can't be serialized faithfully to int64 with requested units 'days since 1900-01-01'. Resolution of 'minutes' needed. Serializing times to floating point instead. Set encoding['dtype'] to integer dtype to serialize to int64. Set encoding['dtype'] to floating point dtype to silence this warning.
#   xdf.to_netcdf(filename,format=kwargs['format'],encoding={'time':{'units':'days since 1900-01-01'}})
# /Users/bell/src/ecofocipy/src/EcoFOCIpy/io/ncCFsave.py:320: UserWarning: Times can't be serialized faithfully to int64 with requested units 'days since 1900-01-01'. Resolution of 'minutes' needed. Serializing times to floating point instead. Set encoding['dtype'] to integer dtype to serialize to int64. Set encoding['dtype'] to floating point dtype to silence this warning.
#   xdf.to_netcdf(filename,format=kwargs['format'],encoding={'time':{'units':'days since 1900-01-01'}})
# /Users/bell/src/ecofocipy/src/EcoFOCIpy/io/ncCFsave.py:320: UserWarning: Times can't be serialized faithfully to int64 with requested units 'days since 1900-01-01'. Resolution of 'minutes' needed. Serializing times to floating point instead. Set encoding['dtype'] to integer dtype to serialize to int64. Set encoding['dtype'] to floating point dtype to silence this warning.
#   xdf.to_netcdf(filename,format=kwargs['format'],encoding={'time':{'units':'days since 1900-01-01'}})
# /Users/bell/src/ecofocipy/src/EcoFOCIpy/io/ncCFsave.py:320: UserWarning: Times can't be serialized faithfully to int64 with requested units 'days since 1900-01-01'. Resolution of 'minutes' needed. Serializing times to floating point instead. Set encoding['dtype'] to integer dtype to serialize to int64. Set encoding['dtype'] to floating point dtype to silence this warning.
#   xdf.to_netcdf(filename,format=kwargs['format'],encoding={'time':{'units':'days since 1900-01-01'}})
# /Users/bell/src/ecofocipy/src/EcoFOCIpy/io/ncCFsave.py:320: UserWarning: Times can't be serialized faithfully to int64 with requested units 'days since 1900-01-01'. Resolution of 'minutes' needed. Serializing times to floating point instead. Set encoding['dtype'] to integer dtype to serialize to int64. Set encoding['dtype'] to floating point dtype to silence this warning.
#   xdf.to_netcdf(filename,format=kwargs['format'],encoding={'time':{'units':'days since 1900-01-01'}})
# /Users/bell/src/ecofocipy/src/EcoFOCIpy/io/ncCFsave.py:320: UserWarning: Times can't be serialized faithfully to int64 with requested units 'days since 1900-01-01'. Resolution of 'minutes' needed. Serializing times to floating point instead. Set encoding['dtype'] to integer dtype to serialize to int64. Set encoding['dtype'] to floating point dtype to silence this warning.
#   xdf.to_netcdf(filename,format=kwargs['format'],encoding={'time':{'units':'days since 1900-01-01'}})
# Processing Cast CTD007.cnv
# Processing Cast CTD008.cnv
# Processing Cast CTD009.cnv
# Processing Cast CTD010.cnv
# Processing Cast CTD011.cnv
# /Users/bell/src/ecofocipy/src/EcoFOCIpy/io/ncCFsave.py:320: UserWarning: Times can't be serialized faithfully to int64 with requested units 'days since 1900-01-01'. Resolution of 'minutes' needed. Serializing times to floating point instead. Set encoding['dtype'] to integer dtype to serialize to int64. Set encoding['dtype'] to floating point dtype to silence this warning.
#   xdf.to_netcdf(filename,format=kwargs['format'],encoding={'time':{'units':'days since 1900-01-01'}})
# /Users/bell/src/ecofocipy/src/EcoFOCIpy/io/ncCFsave.py:320: UserWarning: Times can't be serialized faithfully to int64 with requested units 'days since 1900-01-01'. Resolution of 'minutes' needed. Serializing times to floating point instead. Set encoding['dtype'] to integer dtype to serialize to int64. Set encoding['dtype'] to floating point dtype to silence this warning.
#   xdf.to_netcdf(filename,format=kwargs['format'],encoding={'time':{'units':'days since 1900-01-01'}})
# /Users/bell/src/ecofocipy/src/EcoFOCIpy/io/ncCFsave.py:320: UserWarning: Times can't be serialized faithfully to int64 with requested units 'days since 1900-01-01'. Resolution of 'minutes' needed. Serializing times to floating point instead. Set encoding['dtype'] to integer dtype to serialize to int64. Set encoding['dtype'] to floating point dtype to silence this warning.
#   xdf.to_netcdf(filename,format=kwargs['format'],encoding={'time':{'units':'days since 1900-01-01'}})
# /Users/bell/src/ecofocipy/src/EcoFOCIpy/io/ncCFsave.py:320: UserWarning: Times can't be serialized faithfully to int64 with requested units 'days since 1900-01-01'. Resolution of 'minutes' needed. Serializing times to floating point instead. Set encoding['dtype'] to integer dtype to serialize to int64. Set encoding['dtype'] to floating point dtype to silence this warning.
#   xdf.to_netcdf(filename,format=kwargs['format'],encoding={'time':{'units':'days since 1900-01-01'}})
# /Users/bell/src/ecofocipy/src/EcoFOCIpy/io/ncCFsave.py:320: UserWarning: Times can't be serialized faithfully to int64 with requested units 'days since 1900-01-01'. Resolution of 'minutes' needed. Serializing times to floating point instead. Set encoding['dtype'] to integer dtype to serialize to int64. Set encoding['dtype'] to floating point dtype to silence this warning.
#   xdf.to_netcdf(filename,format=kwargs['format'],encoding={'time':{'units':'days since 1900-01-01'}})
# Processing Cast CTD012.cnv
# Processing Cast CTD013.cnv
# Processing Cast CTD014.cnv
# Processing Cast CTD015.cnv
# Processing Cast CTD016.cnv
# /Users/bell/src/ecofocipy/src/EcoFOCIpy/io/ncCFsave.py:320: UserWarning: Times can't be serialized faithfully to int64 with requested units 'days since 1900-01-01'. Resolution of 'minutes' needed. Serializing times to floating point instead. Set encoding['dtype'] to integer dtype to serialize to int64. Set encoding['dtype'] to floating point dtype to silence this warning.
#   xdf.to_netcdf(filename,format=kwargs['format'],encoding={'time':{'units':'days since 1900-01-01'}})
# /Users/bell/src/ecofocipy/src/EcoFOCIpy/io/ncCFsave.py:320: UserWarning: Times can't be serialized faithfully to int64 with requested units 'days since 1900-01-01'. Resolution of 'minutes' needed. Serializing times to floating point instead. Set encoding['dtype'] to integer dtype to serialize to int64. Set encoding['dtype'] to floating point dtype to silence this warning.
#   xdf.to_netcdf(filename,format=kwargs['format'],encoding={'time':{'units':'days since 1900-01-01'}})
# /Users/bell/src/ecofocipy/src/EcoFOCIpy/io/ncCFsave.py:320: UserWarning: Times can't be serialized faithfully to int64 with requested units 'days since 1900-01-01'. Resolution of 'minutes' needed. Serializing times to floating point instead. Set encoding['dtype'] to integer dtype to serialize to int64. Set encoding['dtype'] to floating point dtype to silence this warning.
#   xdf.to_netcdf(filename,format=kwargs['format'],encoding={'time':{'units':'days since 1900-01-01'}})
# /Users/bell/src/ecofocipy/src/EcoFOCIpy/io/ncCFsave.py:320: UserWarning: Times can't be serialized faithfully to int64 with requested units 'days since 1900-01-01'. Resolution of 'minutes' needed. Serializing times to floating point instead. Set encoding['dtype'] to integer dtype to serialize to int64. Set encoding['dtype'] to floating point dtype to silence this warning.
#   xdf.to_netcdf(filename,format=kwargs['format'],encoding={'time':{'units':'days since 1900-01-01'}})
# /Users/bell/src/ecofocipy/src/EcoFOCIpy/io/ncCFsave.py:320: UserWarning: Times can't be serialized faithfully to int64 with requested units 'days since 1900-01-01'. Resolution of 'minutes' needed. Serializing times to floating point instead. Set encoding['dtype'] to integer dtype to serialize to int64. Set encoding['dtype'] to floating point dtype to silence this warning.
#   xdf.to_netcdf(filename,format=kwargs['format'],encoding={'time':{'units':'days since 1900-01-01'}})
# Processing Cast CTD017.cnv
# Processing Cast CTD018.cnv
# Processing Cast CTD019.cnv
# Processing Cast CTD020.cnv
# Processing Cast CTD021.cnv
# /Users/bell/src/ecofocipy/src/EcoFOCIpy/io/ncCFsave.py:320: UserWarning: Times can't be serialized faithfully to int64 with requested units 'days since 1900-01-01'. Resolution of 'minutes' needed. Serializing times to floating point instead. Set encoding['dtype'] to integer dtype to serialize to int64. Set encoding['dtype'] to floating point dtype to silence this warning.
#   xdf.to_netcdf(filename,format=kwargs['format'],encoding={'time':{'units':'days since 1900-01-01'}})
# /Users/bell/src/ecofocipy/src/EcoFOCIpy/io/ncCFsave.py:320: UserWarning: Times can't be serialized faithfully to int64 with requested units 'days since 1900-01-01'. Resolution of 'minutes' needed. Serializing times to floating point instead. Set encoding['dtype'] to integer dtype to serialize to int64. Set encoding['dtype'] to floating point dtype to silence this warning.
#   xdf.to_netcdf(filename,format=kwargs['format'],encoding={'time':{'units':'days since 1900-01-01'}})
# /Users/bell/src/ecofocipy/src/EcoFOCIpy/io/ncCFsave.py:320: UserWarning: Times can't be serialized faithfully to int64 with requested units 'days since 1900-01-01'. Resolution of 'minutes' needed. Serializing times to floating point instead. Set encoding['dtype'] to integer dtype to serialize to int64. Set encoding['dtype'] to floating point dtype to silence this warning.
#   xdf.to_netcdf(filename,format=kwargs['format'],encoding={'time':{'units':'days since 1900-01-01'}})
# /Users/bell/src/ecofocipy/src/EcoFOCIpy/io/ncCFsave.py:320: UserWarning: Times can't be serialized faithfully to int64 with requested units 'days since 1900-01-01'. Resolution of 'minutes' needed. Serializing times to floating point instead. Set encoding['dtype'] to integer dtype to serialize to int64. Set encoding['dtype'] to floating point dtype to silence this warning.
#   xdf.to_netcdf(filename,format=kwargs['format'],encoding={'time':{'units':'days since 1900-01-01'}})
# /Users/bell/src/ecofocipy/src/EcoFOCIpy/io/ncCFsave.py:320: UserWarning: Times can't be serialized faithfully to int64 with requested units 'days since 1900-01-01'. Resolution of 'minutes' needed. Serializing times to floating point instead. Set encoding['dtype'] to integer dtype to serialize to int64. Set encoding['dtype'] to floating point dtype to silence this warning.
#   xdf.to_netcdf(filename,format=kwargs['format'],encoding={'time':{'units':'days since 1900-01-01'}})
# Processing Cast CTD022.cnv
# Processing Cast CTD023.cnv
# Processing Cast CTD024.cnv
# Processing Cast CTD025.cnv
# Processing Cast CTD026.cnv
# /Users/bell/src/ecofocipy/src/EcoFOCIpy/io/ncCFsave.py:320: UserWarning: Times can't be serialized faithfully to int64 with requested units 'days since 1900-01-01'. Resolution of 'minutes' needed. Serializing times to floating point instead. Set encoding['dtype'] to integer dtype to serialize to int64. Set encoding['dtype'] to floating point dtype to silence this warning.
#   xdf.to_netcdf(filename,format=kwargs['format'],encoding={'time':{'units':'days since 1900-01-01'}})
# /Users/bell/src/ecofocipy/src/EcoFOCIpy/io/ncCFsave.py:320: UserWarning: Times can't be serialized faithfully to int64 with requested units 'days since 1900-01-01'. Resolution of 'minutes' needed. Serializing times to floating point instead. Set encoding['dtype'] to integer dtype to serialize to int64. Set encoding['dtype'] to floating point dtype to silence this warning.
#   xdf.to_netcdf(filename,format=kwargs['format'],encoding={'time':{'units':'days since 1900-01-01'}})
# /Users/bell/src/ecofocipy/src/EcoFOCIpy/io/ncCFsave.py:320: UserWarning: Times can't be serialized faithfully to int64 with requested units 'days since 1900-01-01'. Resolution of 'minutes' needed. Serializing times to floating point instead. Set encoding['dtype'] to integer dtype to serialize to int64. Set encoding['dtype'] to floating point dtype to silence this warning.
#   xdf.to_netcdf(filename,format=kwargs['format'],encoding={'time':{'units':'days since 1900-01-01'}})
# /Users/bell/src/ecofocipy/src/EcoFOCIpy/io/ncCFsave.py:320: UserWarning: Times can't be serialized faithfully to int64 with requested units 'days since 1900-01-01'. Resolution of 'minutes' needed. Serializing times to floating point instead. Set encoding['dtype'] to integer dtype to serialize to int64. Set encoding['dtype'] to floating point dtype to silence this warning.
#   xdf.to_netcdf(filename,format=kwargs['format'],encoding={'time':{'units':'days since 1900-01-01'}})
# /Users/bell/src/ecofocipy/src/EcoFOCIpy/io/ncCFsave.py:320: UserWarning: Times can't be serialized faithfully to int64 with requested units 'days since 1900-01-01'. Resolution of 'minutes' needed. Serializing times to floating point instead. Set encoding['dtype'] to integer dtype to serialize to int64. Set encoding['dtype'] to floating point dtype to silence this warning.
#   xdf.to_netcdf(filename,format=kwargs['format'],encoding={'time':{'units':'days since 1900-01-01'}})
# Processing Cast CTD027.cnv
# Processing Cast CTD028.cnv
# Processing Cast CTD029.cnv
# Processing Cast CTD030.cnv
# Processing Cast CTD031.cnv
# /Users/bell/src/ecofocipy/src/EcoFOCIpy/io/ncCFsave.py:320: UserWarning: Times can't be serialized faithfully to int64 with requested units 'days since 1900-01-01'. Resolution of 'minutes' needed. Serializing times to floating point instead. Set encoding['dtype'] to integer dtype to serialize to int64. Set encoding['dtype'] to floating point dtype to silence this warning.
#   xdf.to_netcdf(filename,format=kwargs['format'],encoding={'time':{'units':'days since 1900-01-01'}})
# /Users/bell/src/ecofocipy/src/EcoFOCIpy/io/ncCFsave.py:320: UserWarning: Times can't be serialized faithfully to int64 with requested units 'days since 1900-01-01'. Resolution of 'minutes' needed. Serializing times to floating point instead. Set encoding['dtype'] to integer dtype to serialize to int64. Set encoding['dtype'] to floating point dtype to silence this warning.
#   xdf.to_netcdf(filename,format=kwargs['format'],encoding={'time':{'units':'days since 1900-01-01'}})
# /Users/bell/src/ecofocipy/src/EcoFOCIpy/io/ncCFsave.py:320: UserWarning: Times can't be serialized faithfully to int64 with requested units 'days since 1900-01-01'. Resolution of 'minutes' needed. Serializing times to floating point instead. Set encoding['dtype'] to integer dtype to serialize to int64. Set encoding['dtype'] to floating point dtype to silence this warning.
#   xdf.to_netcdf(filename,format=kwargs['format'],encoding={'time':{'units':'days since 1900-01-01'}})
# /Users/bell/src/ecofocipy/src/EcoFOCIpy/io/ncCFsave.py:320: UserWarning: Times can't be serialized faithfully to int64 with requested units 'days since 1900-01-01'. Resolution of 'minutes' needed. Serializing times to floating point instead. Set encoding['dtype'] to integer dtype to serialize to int64. Set encoding['dtype'] to floating point dtype to silence this warning.
#   xdf.to_netcdf(filename,format=kwargs['format'],encoding={'time':{'units':'days since 1900-01-01'}})
# Processing Cast CTD032.cnv
# Processing Cast CTD033.cnv
# Processing Cast CTD034.cnv
# Processing Cast CTD035.cnv
# Processing Cast CTD036.cnv
# /Users/bell/src/ecofocipy/src/EcoFOCIpy/io/ncCFsave.py:320: UserWarning: Times can't be serialized faithfully to int64 with requested units 'days since 1900-01-01'. Resolution of 'minutes' needed. Serializing times to floating point instead. Set encoding['dtype'] to integer dtype to serialize to int64. Set encoding['dtype'] to floating point dtype to silence this warning.
#   xdf.to_netcdf(filename,format=kwargs['format'],encoding={'time':{'units':'days since 1900-01-01'}})
# /Users/bell/src/ecofocipy/src/EcoFOCIpy/io/ncCFsave.py:320: UserWarning: Times can't be serialized faithfully to int64 with requested units 'days since 1900-01-01'. Resolution of 'minutes' needed. Serializing times to floating point instead. Set encoding['dtype'] to integer dtype to serialize to int64. Set encoding['dtype'] to floating point dtype to silence this warning.
#   xdf.to_netcdf(filename,format=kwargs['format'],encoding={'time':{'units':'days since 1900-01-01'}})
# /Users/bell/src/ecofocipy/src/EcoFOCIpy/io/ncCFsave.py:320: UserWarning: Times can't be serialized faithfully to int64 with requested units 'days since 1900-01-01'. Resolution of 'minutes' needed. Serializing times to floating point instead. Set encoding['dtype'] to integer dtype to serialize to int64. Set encoding['dtype'] to floating point dtype to silence this warning.
#   xdf.to_netcdf(filename,format=kwargs['format'],encoding={'time':{'units':'days since 1900-01-01'}})
# /Users/bell/src/ecofocipy/src/EcoFOCIpy/io/ncCFsave.py:320: UserWarning: Times can't be serialized faithfully to int64 with requested units 'days since 1900-01-01'. Resolution of 'minutes' needed. Serializing times to floating point instead. Set encoding['dtype'] to integer dtype to serialize to int64. Set encoding['dtype'] to floating point dtype to silence this warning.
#   xdf.to_netcdf(filename,format=kwargs['format'],encoding={'time':{'units':'days since 1900-01-01'}})
# /Users/bell/src/ecofocipy/src/EcoFOCIpy/io/ncCFsave.py:320: UserWarning: Times can't be serialized faithfully to int64 with requested units 'days since 1900-01-01'. Resolution of 'minutes' needed. Serializing times to floating point instead. Set encoding['dtype'] to integer dtype to serialize to int64. Set encoding['dtype'] to floating point dtype to silence this warning.
#   xdf.to_netcdf(filename,format=kwargs['format'],encoding={'time':{'units':'days since 1900-01-01'}})
# Processing Cast CTD037.cnv
# Processing Cast CTD038.cnv
# Processing Cast CTD039.cnv
# Processing Cast CTD040.cnv
# Processing Cast CTD041.cnv
# /Users/bell/src/ecofocipy/src/EcoFOCIpy/io/ncCFsave.py:320: UserWarning: Times can't be serialized faithfully to int64 with requested units 'days since 1900-01-01'. Resolution of 'minutes' needed. Serializing times to floating point instead. Set encoding['dtype'] to integer dtype to serialize to int64. Set encoding['dtype'] to floating point dtype to silence this warning.
#   xdf.to_netcdf(filename,format=kwargs['format'],encoding={'time':{'units':'days since 1900-01-01'}})
# /Users/bell/src/ecofocipy/src/EcoFOCIpy/io/ncCFsave.py:320: UserWarning: Times can't be serialized faithfully to int64 with requested units 'days since 1900-01-01'. Resolution of 'minutes' needed. Serializing times to floating point instead. Set encoding['dtype'] to integer dtype to serialize to int64. Set encoding['dtype'] to floating point dtype to silence this warning.
#   xdf.to_netcdf(filename,format=kwargs['format'],encoding={'time':{'units':'days since 1900-01-01'}})
# /Users/bell/src/ecofocipy/src/EcoFOCIpy/io/ncCFsave.py:320: UserWarning: Times can't be serialized faithfully to int64 with requested units 'days since 1900-01-01'. Resolution of 'minutes' needed. Serializing times to floating point instead. Set encoding['dtype'] to integer dtype to serialize to int64. Set encoding['dtype'] to floating point dtype to silence this warning.
#   xdf.to_netcdf(filename,format=kwargs['format'],encoding={'time':{'units':'days since 1900-01-01'}})
# /Users/bell/src/ecofocipy/src/EcoFOCIpy/io/ncCFsave.py:320: UserWarning: Times can't be serialized faithfully to int64 with requested units 'days since 1900-01-01'. Resolution of 'minutes' needed. Serializing times to floating point instead. Set encoding['dtype'] to integer dtype to serialize to int64. Set encoding['dtype'] to floating point dtype to silence this warning.
#   xdf.to_netcdf(filename,format=kwargs['format'],encoding={'time':{'units':'days since 1900-01-01'}})
# /Users/bell/src/ecofocipy/src/EcoFOCIpy/io/ncCFsave.py:320: UserWarning: Times can't be serialized faithfully to int64 with requested units 'days since 1900-01-01'. Resolution of 'minutes' needed. Serializing times to floating point instead. Set encoding['dtype'] to integer dtype to serialize to int64. Set encoding['dtype'] to floating point dtype to silence this warning.
#   xdf.to_netcdf(filename,format=kwargs['format'],encoding={'time':{'units':'days since 1900-01-01'}})
# Processing Cast CTD042.cnv
# Processing Cast CTD043.cnv
# Processing Cast CTD044.cnv
# Processing Cast CTD045.cnv
# Processing Cast CTD046.cnv
# /Users/bell/src/ecofocipy/src/EcoFOCIpy/io/ncCFsave.py:320: UserWarning: Times can't be serialized faithfully to int64 with requested units 'days since 1900-01-01'. Resolution of 'minutes' needed. Serializing times to floating point instead. Set encoding['dtype'] to integer dtype to serialize to int64. Set encoding['dtype'] to floating point dtype to silence this warning.
#   xdf.to_netcdf(filename,format=kwargs['format'],encoding={'time':{'units':'days since 1900-01-01'}})
# /Users/bell/src/ecofocipy/src/EcoFOCIpy/io/ncCFsave.py:320: UserWarning: Times can't be serialized faithfully to int64 with requested units 'days since 1900-01-01'. Resolution of 'minutes' needed. Serializing times to floating point instead. Set encoding['dtype'] to integer dtype to serialize to int64. Set encoding['dtype'] to floating point dtype to silence this warning.
#   xdf.to_netcdf(filename,format=kwargs['format'],encoding={'time':{'units':'days since 1900-01-01'}})
# /Users/bell/src/ecofocipy/src/EcoFOCIpy/io/ncCFsave.py:320: UserWarning: Times can't be serialized faithfully to int64 with requested units 'days since 1900-01-01'. Resolution of 'minutes' needed. Serializing times to floating point instead. Set encoding['dtype'] to integer dtype to serialize to int64. Set encoding['dtype'] to floating point dtype to silence this warning.
#   xdf.to_netcdf(filename,format=kwargs['format'],encoding={'time':{'units':'days since 1900-01-01'}})
# /Users/bell/src/ecofocipy/src/EcoFOCIpy/io/ncCFsave.py:320: UserWarning: Times can't be serialized faithfully to int64 with requested units 'days since 1900-01-01'. Resolution of 'minutes' needed. Serializing times to floating point instead. Set encoding['dtype'] to integer dtype to serialize to int64. Set encoding['dtype'] to floating point dtype to silence this warning.
#   xdf.to_netcdf(filename,format=kwargs['format'],encoding={'time':{'units':'days since 1900-01-01'}})
# /Users/bell/src/ecofocipy/src/EcoFOCIpy/io/ncCFsave.py:320: UserWarning: Times can't be serialized faithfully to int64 with requested units 'days since 1900-01-01'. Resolution of 'minutes' needed. Serializing times to floating point instead. Set encoding['dtype'] to integer dtype to serialize to int64. Set encoding['dtype'] to floating point dtype to silence this warning.
#   xdf.to_netcdf(filename,format=kwargs['format'],encoding={'time':{'units':'days since 1900-01-01'}})
# Processing Cast CTD047.cnv
# Processing Cast CTD048.cnv
# Processing Cast CTD049.cnv
# Processing Cast CTD050.cnv
# Processing Cast CTD051.cnv
# /Users/bell/src/ecofocipy/src/EcoFOCIpy/io/ncCFsave.py:320: UserWarning: Times can't be serialized faithfully to int64 with requested units 'days since 1900-01-01'. Resolution of 'minutes' needed. Serializing times to floating point instead. Set encoding['dtype'] to integer dtype to serialize to int64. Set encoding['dtype'] to floating point dtype to silence this warning.
#   xdf.to_netcdf(filename,format=kwargs['format'],encoding={'time':{'units':'days since 1900-01-01'}})
# /Users/bell/src/ecofocipy/src/EcoFOCIpy/io/ncCFsave.py:320: UserWarning: Times can't be serialized faithfully to int64 with requested units 'days since 1900-01-01'. Resolution of 'minutes' needed. Serializing times to floating point instead. Set encoding['dtype'] to integer dtype to serialize to int64. Set encoding['dtype'] to floating point dtype to silence this warning.
#   xdf.to_netcdf(filename,format=kwargs['format'],encoding={'time':{'units':'days since 1900-01-01'}})
# /Users/bell/src/ecofocipy/src/EcoFOCIpy/io/ncCFsave.py:320: UserWarning: Times can't be serialized faithfully to int64 with requested units 'days since 1900-01-01'. Resolution of 'minutes' needed. Serializing times to floating point instead. Set encoding['dtype'] to integer dtype to serialize to int64. Set encoding['dtype'] to floating point dtype to silence this warning.
#   xdf.to_netcdf(filename,format=kwargs['format'],encoding={'time':{'units':'days since 1900-01-01'}})
# /Users/bell/src/ecofocipy/src/EcoFOCIpy/io/ncCFsave.py:320: UserWarning: Times can't be serialized faithfully to int64 with requested units 'days since 1900-01-01'. Resolution of 'minutes' needed. Serializing times to floating point instead. Set encoding['dtype'] to integer dtype to serialize to int64. Set encoding['dtype'] to floating point dtype to silence this warning.
#   xdf.to_netcdf(filename,format=kwargs['format'],encoding={'time':{'units':'days since 1900-01-01'}})
# /Users/bell/src/ecofocipy/src/EcoFOCIpy/io/ncCFsave.py:320: UserWarning: Times can't be serialized faithfully to int64 with requested units 'days since 1900-01-01'. Resolution of 'minutes' needed. Serializing times to floating point instead. Set encoding['dtype'] to integer dtype to serialize to int64. Set encoding['dtype'] to floating point dtype to silence this warning.
#   xdf.to_netcdf(filename,format=kwargs['format'],encoding={'time':{'units':'days since 1900-01-01'}})
# Processing Cast CTD052.cnv
# Processing Cast CTD053.cnv
# Processing Cast CTD054.cnv
# Processing Cast CTD055.cnv
# Processing Cast CTD056.cnv
# /Users/bell/src/ecofocipy/src/EcoFOCIpy/io/ncCFsave.py:320: UserWarning: Times can't be serialized faithfully to int64 with requested units 'days since 1900-01-01'. Resolution of 'minutes' needed. Serializing times to floating point instead. Set encoding['dtype'] to integer dtype to serialize to int64. Set encoding['dtype'] to floating point dtype to silence this warning.
#   xdf.to_netcdf(filename,format=kwargs['format'],encoding={'time':{'units':'days since 1900-01-01'}})
# /Users/bell/src/ecofocipy/src/EcoFOCIpy/io/ncCFsave.py:320: UserWarning: Times can't be serialized faithfully to int64 with requested units 'days since 1900-01-01'. Resolution of 'hours' needed. Serializing times to floating point instead. Set encoding['dtype'] to integer dtype to serialize to int64. Set encoding['dtype'] to floating point dtype to silence this warning.
#   xdf.to_netcdf(filename,format=kwargs['format'],encoding={'time':{'units':'days since 1900-01-01'}})
# /Users/bell/src/ecofocipy/src/EcoFOCIpy/io/ncCFsave.py:320: UserWarning: Times can't be serialized faithfully to int64 with requested units 'days since 1900-01-01'. Resolution of 'minutes' needed. Serializing times to floating point instead. Set encoding['dtype'] to integer dtype to serialize to int64. Set encoding['dtype'] to floating point dtype to silence this warning.
#   xdf.to_netcdf(filename,format=kwargs['format'],encoding={'time':{'units':'days since 1900-01-01'}})
# /Users/bell/src/ecofocipy/src/EcoFOCIpy/io/ncCFsave.py:320: UserWarning: Times can't be serialized faithfully to int64 with requested units 'days since 1900-01-01'. Resolution of 'minutes' needed. Serializing times to floating point instead. Set encoding['dtype'] to integer dtype to serialize to int64. Set encoding['dtype'] to floating point dtype to silence this warning.
#   xdf.to_netcdf(filename,format=kwargs['format'],encoding={'time':{'units':'days since 1900-01-01'}})
# /Users/bell/src/ecofocipy/src/EcoFOCIpy/io/ncCFsave.py:320: UserWarning: Times can't be serialized faithfully to int64 with requested units 'days since 1900-01-01'. Resolution of 'minutes' needed. Serializing times to floating point instead. Set encoding['dtype'] to integer dtype to serialize to int64. Set encoding['dtype'] to floating point dtype to silence this warning.
#   xdf.to_netcdf(filename,format=kwargs['format'],encoding={'time':{'units':'days since 1900-01-01'}})
# Processing Cast CTD057.cnv
# Processing Cast CTD058.cnv
# Processing Cast CTD059.cnv
# Processing Cast CTD060.cnv
# Processing Cast CTD061.cnv
# /Users/bell/src/ecofocipy/src/EcoFOCIpy/io/ncCFsave.py:320: UserWarning: Times can't be serialized faithfully to int64 with requested units 'days since 1900-01-01'. Resolution of 'minutes' needed. Serializing times to floating point instead. Set encoding['dtype'] to integer dtype to serialize to int64. Set encoding['dtype'] to floating point dtype to silence this warning.
#   xdf.to_netcdf(filename,format=kwargs['format'],encoding={'time':{'units':'days since 1900-01-01'}})
# /Users/bell/src/ecofocipy/src/EcoFOCIpy/io/ncCFsave.py:320: UserWarning: Times can't be serialized faithfully to int64 with requested units 'days since 1900-01-01'. Resolution of 'minutes' needed. Serializing times to floating point instead. Set encoding['dtype'] to integer dtype to serialize to int64. Set encoding['dtype'] to floating point dtype to silence this warning.
#   xdf.to_netcdf(filename,format=kwargs['format'],encoding={'time':{'units':'days since 1900-01-01'}})
# /Users/bell/src/ecofocipy/src/EcoFOCIpy/io/ncCFsave.py:320: UserWarning: Times can't be serialized faithfully to int64 with requested units 'days since 1900-01-01'. Resolution of 'minutes' needed. Serializing times to floating point instead. Set encoding['dtype'] to integer dtype to serialize to int64. Set encoding['dtype'] to floating point dtype to silence this warning.
#   xdf.to_netcdf(filename,format=kwargs['format'],encoding={'time':{'units':'days since 1900-01-01'}})
# /Users/bell/src/ecofocipy/src/EcoFOCIpy/io/ncCFsave.py:320: UserWarning: Times can't be serialized faithfully to int64 with requested units 'days since 1900-01-01'. Resolution of 'minutes' needed. Serializing times to floating point instead. Set encoding['dtype'] to integer dtype to serialize to int64. Set encoding['dtype'] to floating point dtype to silence this warning.
#   xdf.to_netcdf(filename,format=kwargs['format'],encoding={'time':{'units':'days since 1900-01-01'}})
# /Users/bell/src/ecofocipy/src/EcoFOCIpy/io/ncCFsave.py:320: UserWarning: Times can't be serialized faithfully to int64 with requested units 'days since 1900-01-01'. Resolution of 'minutes' needed. Serializing times to floating point instead. Set encoding['dtype'] to integer dtype to serialize to int64. Set encoding['dtype'] to floating point dtype to silence this warning.
#   xdf.to_netcdf(filename,format=kwargs['format'],encoding={'time':{'units':'days since 1900-01-01'}})
# Processing Cast CTD062.cnv
# Processing Cast CTD063.cnv
# Processing Cast CTD064.cnv
# Processing Cast CTD065.cnv
# Processing Cast CTD066.cnv
# /Users/bell/src/ecofocipy/src/EcoFOCIpy/io/ncCFsave.py:320: UserWarning: Times can't be serialized faithfully to int64 with requested units 'days since 1900-01-01'. Resolution of 'minutes' needed. Serializing times to floating point instead. Set encoding['dtype'] to integer dtype to serialize to int64. Set encoding['dtype'] to floating point dtype to silence this warning.
#   xdf.to_netcdf(filename,format=kwargs['format'],encoding={'time':{'units':'days since 1900-01-01'}})
# /Users/bell/src/ecofocipy/src/EcoFOCIpy/io/ncCFsave.py:320: UserWarning: Times can't be serialized faithfully to int64 with requested units 'days since 1900-01-01'. Resolution of 'minutes' needed. Serializing times to floating point instead. Set encoding['dtype'] to integer dtype to serialize to int64. Set encoding['dtype'] to floating point dtype to silence this warning.
#   xdf.to_netcdf(filename,format=kwargs['format'],encoding={'time':{'units':'days since 1900-01-01'}})
# /Users/bell/src/ecofocipy/src/EcoFOCIpy/io/ncCFsave.py:320: UserWarning: Times can't be serialized faithfully to int64 with requested units 'days since 1900-01-01'. Resolution of 'minutes' needed. Serializing times to floating point instead. Set encoding['dtype'] to integer dtype to serialize to int64. Set encoding['dtype'] to floating point dtype to silence this warning.
#   xdf.to_netcdf(filename,format=kwargs['format'],encoding={'time':{'units':'days since 1900-01-01'}})
# /Users/bell/src/ecofocipy/src/EcoFOCIpy/io/ncCFsave.py:320: UserWarning: Times can't be serialized faithfully to int64 with requested units 'days since 1900-01-01'. Resolution of 'minutes' needed. Serializing times to floating point instead. Set encoding['dtype'] to integer dtype to serialize to int64. Set encoding['dtype'] to floating point dtype to silence this warning.
#   xdf.to_netcdf(filename,format=kwargs['format'],encoding={'time':{'units':'days since 1900-01-01'}})
# /Users/bell/src/ecofocipy/src/EcoFOCIpy/io/ncCFsave.py:320: UserWarning: Times can't be serialized faithfully to int64 with requested units 'days since 1900-01-01'. Resolution of 'minutes' needed. Serializing times to floating point instead. Set encoding['dtype'] to integer dtype to serialize to int64. Set encoding['dtype'] to floating point dtype to silence this warning.
#   xdf.to_netcdf(filename,format=kwargs['format'],encoding={'time':{'units':'days since 1900-01-01'}})
# Processing Cast CTD067.cnv
# Processing Cast CTD068.cnv
# Processing Cast CTD069.cnv
# Processing Cast CTD070.cnv
# Processing Cast CTD071.cnv
# /Users/bell/src/ecofocipy/src/EcoFOCIpy/io/ncCFsave.py:320: UserWarning: Times can't be serialized faithfully to int64 with requested units 'days since 1900-01-01'. Resolution of 'minutes' needed. Serializing times to floating point instead. Set encoding['dtype'] to integer dtype to serialize to int64. Set encoding['dtype'] to floating point dtype to silence this warning.
#   xdf.to_netcdf(filename,format=kwargs['format'],encoding={'time':{'units':'days since 1900-01-01'}})
# /Users/bell/src/ecofocipy/src/EcoFOCIpy/io/ncCFsave.py:320: UserWarning: Times can't be serialized faithfully to int64 with requested units 'days since 1900-01-01'. Resolution of 'minutes' needed. Serializing times to floating point instead. Set encoding['dtype'] to integer dtype to serialize to int64. Set encoding['dtype'] to floating point dtype to silence this warning.
#   xdf.to_netcdf(filename,format=kwargs['format'],encoding={'time':{'units':'days since 1900-01-01'}})
# /Users/bell/src/ecofocipy/src/EcoFOCIpy/io/ncCFsave.py:320: UserWarning: Times can't be serialized faithfully to int64 with requested units 'days since 1900-01-01'. Resolution of 'minutes' needed. Serializing times to floating point instead. Set encoding['dtype'] to integer dtype to serialize to int64. Set encoding['dtype'] to floating point dtype to silence this warning.
#   xdf.to_netcdf(filename,format=kwargs['format'],encoding={'time':{'units':'days since 1900-01-01'}})
# /Users/bell/src/ecofocipy/src/EcoFOCIpy/io/ncCFsave.py:320: UserWarning: Times can't be serialized faithfully to int64 with requested units 'days since 1900-01-01'. Resolution of 'minutes' needed. Serializing times to floating point instead. Set encoding['dtype'] to integer dtype to serialize to int64. Set encoding['dtype'] to floating point dtype to silence this warning.
#   xdf.to_netcdf(filename,format=kwargs['format'],encoding={'time':{'units':'days since 1900-01-01'}})
# /Users/bell/src/ecofocipy/src/EcoFOCIpy/io/ncCFsave.py:320: UserWarning: Times can't be serialized faithfully to int64 with requested units 'days since 1900-01-01'. Resolution of 'minutes' needed. Serializing times to floating point instead. Set encoding['dtype'] to integer dtype to serialize to int64. Set encoding['dtype'] to floating point dtype to silence this warning.
#   xdf.to_netcdf(filename,format=kwargs['format'],encoding={'time':{'units':'days since 1900-01-01'}})
# Processing Cast CTD072.cnv
# Processing Cast CTD073.cnv
# Processing Cast CTD074.cnv
# Processing Cast CTD075.cnv
# Processing Cast CTD076.cnv
# /Users/bell/src/ecofocipy/src/EcoFOCIpy/io/ncCFsave.py:320: UserWarning: Times can't be serialized faithfully to int64 with requested units 'days since 1900-01-01'. Resolution of 'minutes' needed. Serializing times to floating point instead. Set encoding['dtype'] to integer dtype to serialize to int64. Set encoding['dtype'] to floating point dtype to silence this warning.
#   xdf.to_netcdf(filename,format=kwargs['format'],encoding={'time':{'units':'days since 1900-01-01'}})
# /Users/bell/src/ecofocipy/src/EcoFOCIpy/io/ncCFsave.py:320: UserWarning: Times can't be serialized faithfully to int64 with requested units 'days since 1900-01-01'. Resolution of 'minutes' needed. Serializing times to floating point instead. Set encoding['dtype'] to integer dtype to serialize to int64. Set encoding['dtype'] to floating point dtype to silence this warning.
#   xdf.to_netcdf(filename,format=kwargs['format'],encoding={'time':{'units':'days since 1900-01-01'}})
# /Users/bell/src/ecofocipy/src/EcoFOCIpy/io/ncCFsave.py:320: UserWarning: Times can't be serialized faithfully to int64 with requested units 'days since 1900-01-01'. Resolution of 'minutes' needed. Serializing times to floating point instead. Set encoding['dtype'] to integer dtype to serialize to int64. Set encoding['dtype'] to floating point dtype to silence this warning.
#   xdf.to_netcdf(filename,format=kwargs['format'],encoding={'time':{'units':'days since 1900-01-01'}})
# /Users/bell/src/ecofocipy/src/EcoFOCIpy/io/ncCFsave.py:320: UserWarning: Times can't be serialized faithfully to int64 with requested units 'days since 1900-01-01'. Resolution of 'minutes' needed. Serializing times to floating point instead. Set encoding['dtype'] to integer dtype to serialize to int64. Set encoding['dtype'] to floating point dtype to silence this warning.
#   xdf.to_netcdf(filename,format=kwargs['format'],encoding={'time':{'units':'days since 1900-01-01'}})
# /Users/bell/src/ecofocipy/src/EcoFOCIpy/io/ncCFsave.py:320: UserWarning: Times can't be serialized faithfully to int64 with requested units 'days since 1900-01-01'. Resolution of 'minutes' needed. Serializing times to floating point instead. Set encoding['dtype'] to integer dtype to serialize to int64. Set encoding['dtype'] to floating point dtype to silence this warning.
#   xdf.to_netcdf(filename,format=kwargs['format'],encoding={'time':{'units':'days since 1900-01-01'}})
# Processing Cast CTD077.cnv
# Processing Cast CTD078.cnv
# Processing Cast CTD079.cnv
# Processing Cast CTD080.cnv
# /Users/bell/src/ecofocipy/src/EcoFOCIpy/io/ncCFsave.py:320: UserWarning: Times can't be serialized faithfully to int64 with requested units 'days since 1900-01-01'. Resolution of 'minutes' needed. Serializing times to floating point instead. Set encoding['dtype'] to integer dtype to serialize to int64. Set encoding['dtype'] to floating point dtype to silence this warning.
#   xdf.to_netcdf(filename,format=kwargs['format'],encoding={'time':{'units':'days since 1900-01-01'}})
# /Users/bell/src/ecofocipy/src/EcoFOCIpy/io/ncCFsave.py:320: UserWarning: Times can't be serialized faithfully to int64 with requested units 'days since 1900-01-01'. Resolution of 'minutes' needed. Serializing times to floating point instead. Set encoding['dtype'] to integer dtype to serialize to int64. Set encoding['dtype'] to floating point dtype to silence this warning.
#   xdf.to_netcdf(filename,format=kwargs['format'],encoding={'time':{'units':'days since 1900-01-01'}})
# /Users/bell/src/ecofocipy/src/EcoFOCIpy/io/ncCFsave.py:320: UserWarning: Times can't be serialized faithfully to int64 with requested units 'days since 1900-01-01'. Resolution of 'minutes' needed. Serializing times to floating point instead. Set encoding['dtype'] to integer dtype to serialize to int64. Set encoding['dtype'] to floating point dtype to silence this warning.
#   xdf.to_netcdf(filename,format=kwargs['format'],encoding={'time':{'units':'days since 1900-01-01'}})
# Processing Cast CTD081.cnv
# Processing Cast CTD082.cnv
# Processing Cast CTD083.cnv
# Processing Cast CTD084.cnv
# /Users/bell/src/ecofocipy/src/EcoFOCIpy/io/ncCFsave.py:320: UserWarning: Times can't be serialized faithfully to int64 with requested units 'days since 1900-01-01'. Resolution of 'minutes' needed. Serializing times to floating point instead. Set encoding['dtype'] to integer dtype to serialize to int64. Set encoding['dtype'] to floating point dtype to silence this warning.
#   xdf.to_netcdf(filename,format=kwargs['format'],encoding={'time':{'units':'days since 1900-01-01'}})
# /Users/bell/src/ecofocipy/src/EcoFOCIpy/io/ncCFsave.py:320: UserWarning: Times can't be serialized faithfully to int64 with requested units 'days since 1900-01-01'. Resolution of 'minutes' needed. Serializing times to floating point instead. Set encoding['dtype'] to integer dtype to serialize to int64. Set encoding['dtype'] to floating point dtype to silence this warning.
#   xdf.to_netcdf(filename,format=kwargs['format'],encoding={'time':{'units':'days since 1900-01-01'}})
# /Users/bell/src/ecofocipy/src/EcoFOCIpy/io/ncCFsave.py:320: UserWarning: Times can't be serialized faithfully to int64 with requested units 'days since 1900-01-01'. Resolution of 'minutes' needed. Serializing times to floating point instead. Set encoding['dtype'] to integer dtype to serialize to int64. Set encoding['dtype'] to floating point dtype to silence this warning.
#   xdf.to_netcdf(filename,format=kwargs['format'],encoding={'time':{'units':'days since 1900-01-01'}})
# /Users/bell/src/ecofocipy/src/EcoFOCIpy/io/ncCFsave.py:320: UserWarning: Times can't be serialized faithfully to int64 with requested units 'days since 1900-01-01'. Resolution of 'minutes' needed. Serializing times to floating point instead. Set encoding['dtype'] to integer dtype to serialize to int64. Set encoding['dtype'] to floating point dtype to silence this warning.
#   xdf.to_netcdf(filename,format=kwargs['format'],encoding={'time':{'units':'days since 1900-01-01'}})
# Processing Cast CTD085.cnv
# Processing Cast CTD086.cnv
# Processing Cast CTD087.cnv
# Processing Cast CTD088.cnv
# /Users/bell/src/ecofocipy/src/EcoFOCIpy/io/ncCFsave.py:320: UserWarning: Times can't be serialized faithfully to int64 with requested units 'days since 1900-01-01'. Resolution of 'minutes' needed. Serializing times to floating point instead. Set encoding['dtype'] to integer dtype to serialize to int64. Set encoding['dtype'] to floating point dtype to silence this warning.
#   xdf.to_netcdf(filename,format=kwargs['format'],encoding={'time':{'units':'days since 1900-01-01'}})
# /Users/bell/src/ecofocipy/src/EcoFOCIpy/io/ncCFsave.py:320: UserWarning: Times can't be serialized faithfully to int64 with requested units 'days since 1900-01-01'. Resolution of 'minutes' needed. Serializing times to floating point instead. Set encoding['dtype'] to integer dtype to serialize to int64. Set encoding['dtype'] to floating point dtype to silence this warning.
#   xdf.to_netcdf(filename,format=kwargs['format'],encoding={'time':{'units':'days since 1900-01-01'}})
# /Users/bell/src/ecofocipy/src/EcoFOCIpy/io/ncCFsave.py:320: UserWarning: Times can't be serialized faithfully to int64 with requested units 'days since 1900-01-01'. Resolution of 'minutes' needed. Serializing times to floating point instead. Set encoding['dtype'] to integer dtype to serialize to int64. Set encoding['dtype'] to floating point dtype to silence this warning.
#   xdf.to_netcdf(filename,format=kwargs['format'],encoding={'time':{'units':'days since 1900-01-01'}})
# /Users/bell/src/ecofocipy/src/EcoFOCIpy/io/ncCFsave.py:320: UserWarning: Times can't be serialized faithfully to int64 with requested units 'days since 1900-01-01'. Resolution of 'minutes' needed. Serializing times to floating point instead. Set encoding['dtype'] to integer dtype to serialize to int64. Set encoding['dtype'] to floating point dtype to silence this warning.
#   xdf.to_netcdf(filename,format=kwargs['format'],encoding={'time':{'units':'days since 1900-01-01'}})
# Processing Cast CTD089.cnv
# Processing Cast CTD090.cnv
# Processing Cast CTD091.cnv
# Processing Cast CTD092.cnv
# Processing Cast CTD093.cnv
# /Users/bell/src/ecofocipy/src/EcoFOCIpy/io/ncCFsave.py:320: UserWarning: Times can't be serialized faithfully to int64 with requested units 'days since 1900-01-01'. Resolution of 'minutes' needed. Serializing times to floating point instead. Set encoding['dtype'] to integer dtype to serialize to int64. Set encoding['dtype'] to floating point dtype to silence this warning.
#   xdf.to_netcdf(filename,format=kwargs['format'],encoding={'time':{'units':'days since 1900-01-01'}})
# /Users/bell/src/ecofocipy/src/EcoFOCIpy/io/ncCFsave.py:320: UserWarning: Times can't be serialized faithfully to int64 with requested units 'days since 1900-01-01'. Resolution of 'minutes' needed. Serializing times to floating point instead. Set encoding['dtype'] to integer dtype to serialize to int64. Set encoding['dtype'] to floating point dtype to silence this warning.
#   xdf.to_netcdf(filename,format=kwargs['format'],encoding={'time':{'units':'days since 1900-01-01'}})
# /Users/bell/src/ecofocipy/src/EcoFOCIpy/io/ncCFsave.py:320: UserWarning: Times can't be serialized faithfully to int64 with requested units 'days since 1900-01-01'. Resolution of 'minutes' needed. Serializing times to floating point instead. Set encoding['dtype'] to integer dtype to serialize to int64. Set encoding['dtype'] to floating point dtype to silence this warning.
#   xdf.to_netcdf(filename,format=kwargs['format'],encoding={'time':{'units':'days since 1900-01-01'}})
# /Users/bell/src/ecofocipy/src/EcoFOCIpy/io/ncCFsave.py:320: UserWarning: Times can't be serialized faithfully to int64 with requested units 'days since 1900-01-01'. Resolution of 'minutes' needed. Serializing times to floating point instead. Set encoding['dtype'] to integer dtype to serialize to int64. Set encoding['dtype'] to floating point dtype to silence this warning.
#   xdf.to_netcdf(filename,format=kwargs['format'],encoding={'time':{'units':'days since 1900-01-01'}})
# /Users/bell/src/ecofocipy/src/EcoFOCIpy/io/ncCFsave.py:320: UserWarning: Times can't be serialized faithfully to int64 with requested units 'days since 1900-01-01'. Resolution of 'minutes' needed. Serializing times to floating point instead. Set encoding['dtype'] to integer dtype to serialize to int64. Set encoding['dtype'] to floating point dtype to silence this warning.
#   xdf.to_netcdf(filename,format=kwargs['format'],encoding={'time':{'units':'days since 1900-01-01'}})
# Processing Cast CTD094.cnv
# Processing Cast CTD095.cnv
# Processing Cast CTD097.cnv
# Processing Cast CTD098.cnv
# /Users/bell/src/ecofocipy/src/EcoFOCIpy/io/ncCFsave.py:320: UserWarning: Times can't be serialized faithfully to int64 with requested units 'days since 1900-01-01'. Resolution of 'minutes' needed. Serializing times to floating point instead. Set encoding['dtype'] to integer dtype to serialize to int64. Set encoding['dtype'] to floating point dtype to silence this warning.
#   xdf.to_netcdf(filename,format=kwargs['format'],encoding={'time':{'units':'days since 1900-01-01'}})
# Processing Cast CTD099.cnv
# Processing Cast CTD100.cnv
# /Users/bell/src/ecofocipy/src/EcoFOCIpy/io/ncCFsave.py:320: UserWarning: Times can't be serialized faithfully to int64 with requested units 'days since 1900-01-01'. Resolution of 'minutes' needed. Serializing times to floating point instead. Set encoding['dtype'] to integer dtype to serialize to int64. Set encoding['dtype'] to floating point dtype to silence this warning.
#   xdf.to_netcdf(filename,format=kwargs['format'],encoding={'time':{'units':'days since 1900-01-01'}})
# /Users/bell/src/ecofocipy/src/EcoFOCIpy/io/ncCFsave.py:320: UserWarning: Times can't be serialized faithfully to int64 with requested units 'days since 1900-01-01'. Resolution of 'minutes' needed. Serializing times to floating point instead. Set encoding['dtype'] to integer dtype to serialize to int64. Set encoding['dtype'] to floating point dtype to silence this warning.
#   xdf.to_netcdf(filename,format=kwargs['format'],encoding={'time':{'units':'days since 1900-01-01'}})

# %% [markdown]
# ## QC Next Steps

# %%
import EcoFOCIpy.plots.sbe_ctd_plots as sbe_ctd_plots
import os
import xarray as xa
import seaborn as sns
import numpy as np

# %%
sample_data_dir = '/Users/bell/ecoraid/2025/CTDcasts/dy2504/working/' #root path to cruise directory working repo

# %% [markdown]
# ### QC of data (plot parameters with other instruments)
# - be sure to updated the qc_status for the file and the history for future steps
# - from NRT csv files... make edits then use that to modify netcdf?
# - **Better Yet** export netcdf files with variable flags to csv and edit then reingest and modify
#     - modify netcdf in place and provide a qcflag?
#
#
# ### Likely first edits
# - research issues noted in cruise logs
# - remove failed instrument (clogs, or other challenges that arent correctable)
# - extrapolate to sfc (not par though)
# - despike depths (interpolate between depths)
# - check for common issues
#     - lags in salinity when going through interface

# %%
#test for salinity bottle run needs
for cast in sorted(os.listdir(sample_data_dir)):
    if cast.endswith('.nc'):
        try:
            cruise_data_nc = xa.load_dataset(sample_data_dir+cast)
            saldiff = cruise_data_nc.salinity_ch1 - cruise_data_nc.salinity_ch2
            print(f"{cast}: Profile Averaged Salinity Difference,STD (chan1-chan2){saldiff.mean().values},{saldiff.std().values}")        
            saldiff.plot.hist(bins=50,xlim=[-.005,.005])
        except:
            print(f"{cast}: less than two salinity channels")
# Out:
# DY2504cCTD001_ctd.nc: Profile Averaged Salinity Difference,STD (chan1-chan2)0.0009927835051547062,0.0010157773340181502
# DY2504cCTD002_ctd.nc: Profile Averaged Salinity Difference,STD (chan1-chan2)0.0006986111111106671,0.001588106232064341
# DY2504cCTD003_ctd.nc: Profile Averaged Salinity Difference,STD (chan1-chan2)0.0009276595744680396,0.00186064529273757
# DY2504cCTD004_ctd.nc: Profile Averaged Salinity Difference,STD (chan1-chan2)0.000985714285713992,0.0011145074003500216
# DY2504cCTD005_ctd.nc: Profile Averaged Salinity Difference,STD (chan1-chan2)0.000455487804878547,0.001456409427524908
# DY2504cCTD006_ctd.nc: Profile Averaged Salinity Difference,STD (chan1-chan2)0.000509999999999972,0.0007914332989374176
# DY2504cCTD007_ctd.nc: Profile Averaged Salinity Difference,STD (chan1-chan2)0.0003726708074534744,0.0008157599495922084
# DY2504cCTD008_ctd.nc: Profile Averaged Salinity Difference,STD (chan1-chan2)0.0008070796460176888,0.0005206729502194083
# DY2504cCTD009_ctd.nc: Profile Averaged Salinity Difference,STD (chan1-chan2)0.0006594444444446641,0.0017410096226538306
# DY2504cCTD010_ctd.nc: Profile Averaged Salinity Difference,STD (chan1-chan2)0.0007364077669903428,0.00040252203550332044
# DY2504cCTD011_ctd.nc: Profile Averaged Salinity Difference,STD (chan1-chan2)0.0006498281786941453,0.0006105247909015798
# DY2504cCTD012_ctd.nc: Profile Averaged Salinity Difference,STD (chan1-chan2)0.0008336405529953807,0.0008600300711790775
# DY2504cCTD013_ctd.nc: Profile Averaged Salinity Difference,STD (chan1-chan2)0.0005846625766874322,0.0005463299551441606
# DY2504cCTD014_ctd.nc: Profile Averaged Salinity Difference,STD (chan1-chan2)0.0008744680851062599,0.001036798417341295
# DY2504cCTD015_ctd.nc: Profile Averaged Salinity Difference,STD (chan1-chan2)0.0004991999999994334,0.0009266279512296522
# DY2504cCTD016_ctd.nc: Profile Averaged Salinity Difference,STD (chan1-chan2)0.0008504347826086599,0.0006676856736442209
# DY2504cCTD017_ctd.nc: Profile Averaged Salinity Difference,STD (chan1-chan2)0.0002810810810815142,0.00197919419008708
# DY2504cCTD018_ctd.nc: Profile Averaged Salinity Difference,STD (chan1-chan2)0.00040555555555587354,0.001822596506276523
# DY2504cCTD019_ctd.nc: Profile Averaged Salinity Difference,STD (chan1-chan2)0.0007520547945204012,0.00047975724142130144
# DY2504cCTD020_ctd.nc: Profile Averaged Salinity Difference,STD (chan1-chan2)0.0008904761904767374,0.00047899176044690684
# DY2504cCTD021_ctd.nc: Profile Averaged Salinity Difference,STD (chan1-chan2)0.0010405797101448193,0.00021623848923309934
# DY2504cCTD022_ctd.nc: Profile Averaged Salinity Difference,STD (chan1-chan2)0.0015826086956529136,0.0014620767958712104
# DY2504cCTD023_ctd.nc: Profile Averaged Salinity Difference,STD (chan1-chan2)0.0011238805970149573,0.00030375242876655233
# DY2504cCTD024_ctd.nc: Profile Averaged Salinity Difference,STD (chan1-chan2)0.06407164179104477,0.06872907834925032
# DY2504cCTD025_ctd.nc: Profile Averaged Salinity Difference,STD (chan1-chan2)-1.4925373134346599e-05,0.0020247906640540447
# DY2504cCTD026_ctd.nc: Profile Averaged Salinity Difference,STD (chan1-chan2)0.0006410958904106328,0.0002778762987018098
# DY2504cCTD027_ctd.nc: Profile Averaged Salinity Difference,STD (chan1-chan2)0.0009972972972979016,0.0013481692263826895
# DY2504cCTD028_ctd.nc: Profile Averaged Salinity Difference,STD (chan1-chan2)0.0008930555555548558,0.002146141653506461
# DY2504cCTD029_ctd.nc: Profile Averaged Salinity Difference,STD (chan1-chan2)0.000965277777777946,0.0002729263851819792
# DY2504cCTD030_ctd.nc: Profile Averaged Salinity Difference,STD (chan1-chan2)0.0011661971830990762,0.00048699818143873127
# DY2504cCTD031_ctd.nc: Profile Averaged Salinity Difference,STD (chan1-chan2)0.0005630136986313069,0.00023612560467236698
# DY2504cCTD032_ctd.nc: Profile Averaged Salinity Difference,STD (chan1-chan2)0.0007185714285711242,0.00026741773482325616
# DY2504cCTD033_ctd.nc: Profile Averaged Salinity Difference,STD (chan1-chan2)0.0006971014492752308,0.0002007024002756152
# DY2504cCTD034_ctd.nc: Profile Averaged Salinity Difference,STD (chan1-chan2)0.0007294117647056453,0.00014658747993499523
# DY2504cCTD035_ctd.nc: Profile Averaged Salinity Difference,STD (chan1-chan2)0.00038153846153954,0.00016997041162537634
# DY2504cCTD036_ctd.nc: Profile Averaged Salinity Difference,STD (chan1-chan2)0.0004298507462681852,0.00017278657819428346
# DY2504cCTD037_ctd.nc: Profile Averaged Salinity Difference,STD (chan1-chan2)0.0003985074626857975,0.0003093047269657197
# DY2504cCTD038_ctd.nc: Profile Averaged Salinity Difference,STD (chan1-chan2)0.000985294117646957,0.0017236473559324589
# DY2504cCTD039_ctd.nc: Profile Averaged Salinity Difference,STD (chan1-chan2)0.0014579710144921876,0.009181620042664412
# DY2504cCTD040_ctd.nc: Profile Averaged Salinity Difference,STD (chan1-chan2)0.0005072463768117507,0.0010712743110163306
# DY2504cCTD041_ctd.nc: Profile Averaged Salinity Difference,STD (chan1-chan2)0.0001956521739134113,0.003063030363782111
# DY2504cCTD042_ctd.nc: Profile Averaged Salinity Difference,STD (chan1-chan2)0.00038428571428603673,0.0023519982819654364
# DY2504cCTD043_ctd.nc: Profile Averaged Salinity Difference,STD (chan1-chan2)0.00034142857142868926,0.0009543124461614036
# DY2504cCTD044_ctd.nc: Profile Averaged Salinity Difference,STD (chan1-chan2)0.0002855072463765066,0.0007265713331264076
# DY2504cCTD045_ctd.nc: Profile Averaged Salinity Difference,STD (chan1-chan2)0.00018955223880632376,0.0016024360492848473
# DY2504cCTD046_ctd.nc: Profile Averaged Salinity Difference,STD (chan1-chan2)0.00113999999999983,0.001630021910457803
# DY2504cCTD047_ctd.nc: Profile Averaged Salinity Difference,STD (chan1-chan2)0.0008899999999995499,0.0014886379200946568
# DY2504cCTD048_ctd.nc: Profile Averaged Salinity Difference,STD (chan1-chan2)0.0005594202898553134,0.0021403181966186016
# DY2504cCTD049_ctd.nc: Profile Averaged Salinity Difference,STD (chan1-chan2)0.0007800000000006183,0.0019792928029983966
# DY2504cCTD050_ctd.nc: Profile Averaged Salinity Difference,STD (chan1-chan2)0.000588732394367327,0.002031758365344567
# DY2504cCTD051_ctd.nc: Profile Averaged Salinity Difference,STD (chan1-chan2)0.00028875739644970385,0.0005027065153264103
# DY2504cCTD052_ctd.nc: Profile Averaged Salinity Difference,STD (chan1-chan2)8.869565217401526e-05,0.0008369473743144704
# DY2504cCTD053_ctd.nc: Profile Averaged Salinity Difference,STD (chan1-chan2)0.00033857142857135003,0.00014371882980639315
# DY2504cCTD054_ctd.nc: Profile Averaged Salinity Difference,STD (chan1-chan2)0.00012794117647070801,0.0011670533013981863
# DY2504cCTD055_ctd.nc: Profile Averaged Salinity Difference,STD (chan1-chan2)0.0031684210526309264,0.014886502280203188
# DY2504cCTD056_ctd.nc: Profile Averaged Salinity Difference,STD (chan1-chan2)0.0013536231884057318,0.0020653511271213885
# DY2504cCTD057_ctd.nc: Profile Averaged Salinity Difference,STD (chan1-chan2)0.0007014705882352266,0.002522807297614771
# DY2504cCTD058_ctd.nc: Profile Averaged Salinity Difference,STD (chan1-chan2)0.0008985507246369772,0.002250828688207809
# DY2504cCTD059_ctd.nc: Profile Averaged Salinity Difference,STD (chan1-chan2)0.0007478260869574048,0.0016614651030323626
# DY2504cCTD060_ctd.nc: Profile Averaged Salinity Difference,STD (chan1-chan2)0.0006362318840584962,0.0008423519548231427
# DY2504cCTD061_ctd.nc: Profile Averaged Salinity Difference,STD (chan1-chan2)0.000794285714285335,0.0016319913965359579
# DY2504cCTD062_ctd.nc: Profile Averaged Salinity Difference,STD (chan1-chan2)0.0017579710144932906,0.003515572223284851
# DY2504cCTD063_ctd.nc: Profile Averaged Salinity Difference,STD (chan1-chan2)0.0001308823529414984,0.002793914466296827
# DY2504cCTD064_ctd.nc: Profile Averaged Salinity Difference,STD (chan1-chan2)0.0011528571428566384,0.0017386136865387525
# DY2504cCTD065_ctd.nc: Profile Averaged Salinity Difference,STD (chan1-chan2)0.00043676470588316363,0.003071639934271743
# DY2504cCTD066_ctd.nc: Profile Averaged Salinity Difference,STD (chan1-chan2)0.0007028985507245957,0.002392922596935455
# DY2504cCTD067_ctd.nc: Profile Averaged Salinity Difference,STD (chan1-chan2)0.0008102941176475737,0.0009613317518028123
# DY2504cCTD068_ctd.nc: Profile Averaged Salinity Difference,STD (chan1-chan2)0.0014246376811591895,0.0029004950000882644
# DY2504cCTD069_ctd.nc: Profile Averaged Salinity Difference,STD (chan1-chan2)0.0013058823529406409,0.005429328914032325
# DY2504cCTD070_ctd.nc: Profile Averaged Salinity Difference,STD (chan1-chan2)0.0006461538461547087,0.0001919483822801304
# DY2504cCTD071_ctd.nc: Profile Averaged Salinity Difference,STD (chan1-chan2)0.0004534883720919664,0.00013951550252963433
# DY2504cCTD072_ctd.nc: Profile Averaged Salinity Difference,STD (chan1-chan2)0.0003240740740740425,0.0006039791464344201
# DY2504cCTD073_ctd.nc: Profile Averaged Salinity Difference,STD (chan1-chan2)0.0007685483870965015,0.0024652215412937694
# DY2504cCTD074_ctd.nc: Profile Averaged Salinity Difference,STD (chan1-chan2)0.0005719696969694675,0.0005124679434086197
# DY2504cCTD075_ctd.nc: Profile Averaged Salinity Difference,STD (chan1-chan2)0.0005104477611940599,0.001134155524931567
# DY2504cCTD076_ctd.nc: Profile Averaged Salinity Difference,STD (chan1-chan2)0.00044370370370348545,0.0006393987230385001
# DY2504cCTD077_ctd.nc: Profile Averaged Salinity Difference,STD (chan1-chan2)0.00024132653061209936,0.000471943739631822
# DY2504cCTD078_ctd.nc: Profile Averaged Salinity Difference,STD (chan1-chan2)0.0007653543307089058,0.00047261676518421496
# DY2504cCTD079_ctd.nc: Profile Averaged Salinity Difference,STD (chan1-chan2)0.0007283942108890217,0.0003160644432096657
# DY2504cCTD080_ctd.nc: Profile Averaged Salinity Difference,STD (chan1-chan2)0.0007546838407493987,0.0002846507878146129
# DY2504cCTD081_ctd.nc: Profile Averaged Salinity Difference,STD (chan1-chan2)0.0007246464646464445,0.00036072125596881097
# DY2504cCTD082_ctd.nc: Profile Averaged Salinity Difference,STD (chan1-chan2)0.0006820904286554351,0.00036716667474431775
# DY2504cCTD083_ctd.nc: Profile Averaged Salinity Difference,STD (chan1-chan2)0.0006442307692308202,0.00031337500772007844
# DY2504cCTD084_ctd.nc: Profile Averaged Salinity Difference,STD (chan1-chan2)0.0008448571428569299,0.0005685212468881955
# DY2504cCTD085_ctd.nc: Profile Averaged Salinity Difference,STD (chan1-chan2)0.000658162700608887,0.0002711114880281729
# DY2504cCTD086_ctd.nc: Profile Averaged Salinity Difference,STD (chan1-chan2)0.0008325145442791494,0.0002687981323506445
# DY2504cCTD087_ctd.nc: Profile Averaged Salinity Difference,STD (chan1-chan2)0.0007169444444444888,0.0002777020730172898
# DY2504cCTD088_ctd.nc: Profile Averaged Salinity Difference,STD (chan1-chan2)0.0007137593552100357,0.00027313100836777514
# DY2504cCTD089_ctd.nc: Profile Averaged Salinity Difference,STD (chan1-chan2)0.0004083597883597953,0.000435979657881658
# DY2504cCTD090_ctd.nc: Profile Averaged Salinity Difference,STD (chan1-chan2)0.00022790697674404046,0.0009337327559659075
# DY2504cCTD091_ctd.nc: Profile Averaged Salinity Difference,STD (chan1-chan2)0.000270779220779351,0.0024429311041916524
# DY2504cCTD092_ctd.nc: Profile Averaged Salinity Difference,STD (chan1-chan2)0.0008967032967037836,0.0009097095961512314
# DY2504cCTD093_ctd.nc: Profile Averaged Salinity Difference,STD (chan1-chan2)0.001015384615384286,0.002339455070501927
# DY2504cCTD094_ctd.nc: Profile Averaged Salinity Difference,STD (chan1-chan2)0.0007894491129785326,0.0003038667317117358
# DY2504cCTD095_ctd.nc: Profile Averaged Salinity Difference,STD (chan1-chan2)0.0007598365807667864,0.00028083958428240914
# DY2504cCTD097_ctd.nc: Profile Averaged Salinity Difference,STD (chan1-chan2)0.000647568389057856,0.00038049142240867184
# DY2504cCTD098_ctd.nc: Profile Averaged Salinity Difference,STD (chan1-chan2)0.0006560240963855899,0.0012048654107635177
# DY2504cCTD099_ctd.nc: Profile Averaged Salinity Difference,STD (chan1-chan2)0.0007005247376310139,0.0002155318944240667
# DY2504cCTD100_ctd.nc: Profile Averaged Salinity Difference,STD (chan1-chan2)0.0005456310679611352,0.0010712280131338712

# %%
# Following routines will eventually get ported to ecofocipy as subroutines to be called

import seawater as sw

def sigmat_update(salinity=None,temperature=None):
    '''
    Changes to T or S (commonly to despike values or apply a salinity offset) will need corresponding changes in sigmat
    '''
    # calculate sigmaT at 0db gauge pressure (s, t, p=0)
    sigt = (sw.eos80.dens0(s=salinity, t=temperature) - 1000)
    
    return sigt

# %% [markdown]
# ## Generate Plots
#
#
# ### Make General Plots
# - 1:1 plots for paired instruments for each cast (tells if a sensor failed)
# - TS_Sigmat, Chlor/Par/Turb, Oxy,Temp
# - T/S property property plot
# - upcast/downcast plt

# %%
calc_sigmat = True

for cast in sorted(os.listdir(sample_data_dir)):
    if cast.endswith('.nc'):
        cruise_data_nc = xa.load_dataset(sample_data_dir+cast)
        ctd_df = cruise_data_nc.to_dataframe()
        
        if calc_sigmat:
            #update sigmat (or calculate it I suppose)
            sigup = sigmat_update(salinity=ctd_df.salinity_ch1,
                                  temperature=ctd_df.temperature_ch1)
            ctd_df['sigma_t_ch1'] = sigup
            
            sigup2 = sigmat_update(salinity=ctd_df.salinity_ch2,
                                  temperature=ctd_df.temperature_ch2)
            ctd_df['sigma_t_ch2'] = sigup2   
        sbe_p = sbe_ctd_plots.CTDProfilePlot()
        plt,fig =sbe_p.plot3var(varname=['temperature_ch1','temperature_ch2','salinity_ch1','salinity_ch2','sigma_t_ch1','sigma_t_ch2'],
                          xdata=[ctd_df.temperature_ch1,ctd_df.temperature_ch2,ctd_df.salinity_ch1,ctd_df.salinity_ch2,ctd_df.sigma_t_ch1,ctd_df.sigma_t_ch2],
                          ydata=ctd_df.index.get_level_values('depth'),
                          secondary=True,
                          xlabel=['Temperature','Salinity','Sigma-T'])

        DefaultSize = fig.get_size_inches()
        fig.set_size_inches( (DefaultSize[0], DefaultSize[1]*3) )
        plt.savefig(sample_data_dir+cast.replace('.nc','_TempSalSigmat.png'))
        plt.close(fig)

# %%
for cast in sorted(os.listdir(sample_data_dir)):
    if cast.endswith('.nc'):
        cruise_data_nc = xa.load_dataset(sample_data_dir+cast)
        ctd_df = cruise_data_nc.to_dataframe()
        
        sbe_p = sbe_ctd_plots.CTDProfilePlot()
        plt,fig =sbe_p.plot2var(varname=['temperature_ch1','temperature_ch2','oxy_percentsat_ch1','oxy_percentsat_ch2'],
                          xdata=[ctd_df.temperature_ch1,ctd_df.temperature_ch2,ctd_df.oxy_percentsat_ch1,ctd_df.oxy_percentsat_ch2],
                          ydata=ctd_df.index.get_level_values('depth'),
                          secondary=True,
                          xlabel=['Temperature','Oxygen Saturation'])

        DefaultSize = fig.get_size_inches()
        fig.set_size_inches( (DefaultSize[0], DefaultSize[1]*3) )
        plt.savefig(sample_data_dir+cast.replace('.nc','_TempOxy.png'))
        plt.close(fig)

# %%
for cast in sorted(os.listdir(sample_data_dir)):
    if cast.endswith('.nc'):
        cruise_data_nc = xa.load_dataset(sample_data_dir+cast)
        ctd_df = cruise_data_nc.to_dataframe()
        
        sbe_p = sbe_ctd_plots.CTDProfilePlot()
        plt,fig =sbe_p.plot2var(varname=['chlor_fluorescence','','par'],
                          xdata=[ctd_df.chlor_fluorescence,np.array([]),ctd_df.par,np.array([])],
                          ydata=ctd_df.index.get_level_values('depth'),
                          secondary=False,
                          xlabel=['Fluor','Par'])

        DefaultSize = fig.get_size_inches()
        fig.set_size_inches( (DefaultSize[0], DefaultSize[1]*3) )
        plt.savefig(sample_data_dir+cast.replace('.nc','_TurbFluorPAR.png'))
        plt.close(fig)
